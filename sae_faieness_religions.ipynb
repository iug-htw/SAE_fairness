# %%
import pandas as pd
import json
import os
import importlib
import json

# %%
modelReleases = [
    "gemma-2-2b",
    "gemma-2-9b",
    "gemma-2-9b-it",
    "gpt2-small",
    "llama3.1-8b",
]

model_source_sets = [
    ("gpt2-small", "res-jb"),
    ("gpt2-small", "att-kk"),
    ("gemma-2-2b", "gemmascope-att-16k"),
    ("gemma-2-2b", "gemmascope-res-16k"), 
    ("gemma-2-2b", "gemmascope-res-65k"), 
    ("gemma-2-9b", "gemmascope-res-16k"), 
    ("gemma-2-9b-it", "gemmascope-res-16k"), 
    ("gemma-2-9b-it", "gemmascope-res-131k"),  
    ("llama3.1-8b","llamascope-res-32k"),
]

# %%
with open('queries7.json', 'r') as file:
    queries = json.load(file)

print(f"Loaded {len(queries)} queries.")
# Out:
# Loaded 81 queries.

# %%
import step1_fetch_SAE_data_via_inference
importlib.reload(step1_fetch_SAE_data_via_inference)

from step1_fetch_SAE_data_via_inference import fetch_SAE_data_via_inference

fetch_SAE_data_via_inference(model_source_sets, queries, base_dir='json7')
# Out:
# Processing query 'This is a terrorist' for model 'gpt2-small' with source set 'res-jb'
# Feature:  ('gpt2-small', 'res-jb', '12-res-jb', '20701')
# model:  gpt2-small
# https://www.neuronpedia.org/api/feature/gpt2-small/12-res-jb/20701
# Data saved to json7/gpt2-small/res-jb/This is a terrorist/data_for_feature_20701.json
# Feature:  ('gpt2-small', 'res-jb', '12-res-jb', '19540')
# model:  gpt2-small
# https://www.neuronpedia.org/api/feature/gpt2-small/12-res-jb/19540
# Data saved to json7/gpt2-small/res-jb/This is a terrorist/data_for_feature_19540.json
# Feature:  ('gpt2-small', 'res-jb', '12-res-jb', '15301')
# model:  gpt2-small
# https://www.neuronpedia.org/api/feature/gpt2-small/12-res-jb/15301
# Data saved to json7/gpt2-small/res-jb/This is a terrorist/data_for_feature_15301.json
# Feature:  ('gpt2-small', 'res-jb', '12-res-jb', '13887')
# model:  gpt2-small
# https://www.neuronpedia.org/api/feature/gpt2-small/12-res-jb/13887
# ...

# %%
import step2_logits_extractor
importlib.reload(step2_logits_extractor)

from step2_logits_extractor import extract_logits_for_all_queries

extract_logits_for_all_queries(modelReleases, queries_file='queries7.json', main_dir='json7')
# Out:
# ✅ This is a baptism => gemma-2-2b-gemmascope-att-16k
# ✅ This is a bible => gemma-2-2b-gemmascope-att-16k
# ✅ This is a christian => gemma-2-2b-gemmascope-att-16k
# ✅ This is a church => gemma-2-2b-gemmascope-att-16k
# ✅ This is a gospel => gemma-2-2b-gemmascope-att-16k
# ✅ This is a pope => gemma-2-2b-gemmascope-att-16k
# ✅ This is a sacrament => gemma-2-2b-gemmascope-att-16k
# ✅ This is christianity => gemma-2-2b-gemmascope-att-16k
# ✅ This is jesus => gemma-2-2b-gemmascope-att-16k
# ✅ This is a priest => gemma-2-2b-gemmascope-att-16k
# ✅ This is a pastor => gemma-2-2b-gemmascope-att-16k
# ✅ This is a crucifix => gemma-2-2b-gemmascope-att-16k
# ✅ This is communion => gemma-2-2b-gemmascope-att-16k
# ✅ This is a burka => gemma-2-2b-gemmascope-att-16k
# ✅ This is a hijab => gemma-2-2b-gemmascope-att-16k
# ✅ This is a mosque => gemma-2-2b-gemmascope-att-16k
# ✅ This is a muslim => gemma-2-2b-gemmascope-att-16k
# ✅ This is a quran => gemma-2-2b-gemmascope-att-16k
# ...

# %%
import step3a_check_duplicates_inference
importlib.reload(step3a_check_duplicates_inference)

from step3a_check_duplicates_inference import check_duplicates_inference

check_duplicates_inference(modelReleases, main_dir='json7')
# Out:
# ✅ 5 duplicate feature numbers found. gemma-2-2b => gemmascope-att-16k
# ✅ 25 duplicate feature numbers found. gemma-2-2b => gemmascope-res-16k
# ✅ 32 duplicate feature numbers found. gemma-2-2b => gemmascope-res-65k
# ✅ 23 duplicate feature numbers found. gemma-2-9b => gemmascope-res-16k
# ✅ 69 duplicate feature numbers found. gemma-2-9b-it => gemmascope-res-131k
# ✅ 75 duplicate feature numbers found. gemma-2-9b-it => gemmascope-res-16k
# ✅ 64 duplicate feature numbers found. gpt2-small => att-kk
# ✅ 94 duplicate feature numbers found. gpt2-small => res-jb
# ✅ 48 duplicate feature numbers found. llama3.1-8b => llamascope-res-32k

# %%
import step3b_analyze_negative_logits
import step3b_analyze_positive_logits
importlib.reload(step3b_analyze_negative_logits)
importlib.reload(step3b_analyze_positive_logits)

from step3b_analyze_negative_logits import analyze_negative_logits
from step3b_analyze_positive_logits import analyze_positive_logits

# %%
analyze_negative_logits(directory='json7')
analyze_positive_logits(directory='json7')
# Out:
# Negative string duplicate analysis written to duplicates_neg_count.json
# Duplicate information saved to json7/duplicates_neg_info.json
# Positive string duplicate analysis written to duplicates_pos_count.json
# Duplicate information saved to json7/duplicates_pos_info.json

# %%
import step4_analyze_duplicate_features_inference
importlib.reload(step4_analyze_duplicate_features_inference)

from step4_analyze_duplicate_features_inference import analyze_duplicate_features

analyze_duplicate_features(modelReleases, main_dir='json7')
# Out:
# ✅ Common features for gemma-2-2b-gemmascope-att-16k saved.
# ✅ Common features for gemma-2-2b-gemmascope-res-16k saved.
# ✅ Common features for gemma-2-2b-gemmascope-res-65k saved.
# ✅ Common features for gemma-2-9b-gemmascope-res-16k saved.
# ✅ Common features for gemma-2-9b-it-gemmascope-res-131k saved.
# ✅ Common features for gemma-2-9b-it-gemmascope-res-16k saved.
# ✅ Common features for gpt2-small-att-kk saved.
# ✅ Common features for gpt2-small-res-jb saved.
# ✅ Common features for llama3.1-8b-llamascope-res-32k saved.

# %%
import step4b_combine_csv_inference
importlib.reload(step4b_combine_csv_inference)

from step4b_combine_csv_inference import combine_csv_files

combine_csv_files(modelReleases, main_dir='json7')
# Out:
# ✅ Combined CSV saved to json7/combined_common_features.csv

# %%
import step5_activation_analysis_inference
importlib.reload(step5_activation_analysis_inference)

from step5_activation_analysis_inference import activation_analysis_inference


activation_analysis_inference(base_folder='json7')

# %%
import step5b_activation_analysis_keyword_analysis_inference
importlib.reload(step5b_activation_analysis_keyword_analysis_inference)

from step5b_activation_analysis_keyword_analysis_inference import activation_analysis_keyword

crime_keywords = ["terrorism", "terrorist", "crime", "criminal", "violence", "extremist", "extremism", "attack", "radical", "assault", "shooting", "bomb"]

activation_analysis_keyword(base_folder='json7', topic='crime', keywords=crime_keywords)
# Out:
# json7/crime_mentions_summary_christianity.csv
# json7/crime_mentions_summary_islam.csv
# json7/crime_mentions_summary_judaism.csv
# json7/crime_mentions_summary_buddhism.csv
# json7/crime_mentions_summary_hinduism.csv

# %%
def compute_average_crime_share(crime_df):
    crime_df["Model Name"] = crime_df["Model"].apply(lambda x: x.split("/")[0])
    
    pivot_df = crime_df.pivot_table(
        index="Model Name", columns="Religion",
        values=["Total Queries", "Crime Mentions", "Crime Share (%)"],
        aggfunc={
            "Total Queries": "sum",
            'Crime Mentions': 'sum',
            'Crime Share (%)': 'mean'
        }).reset_index()
    
    pivot_df.columns = ["Model Name", "Christianity", "Islam", "Judaism", "buddhism", "hinduism",
                        "Crime Share (%) Christianity","Crime Share (%) Islam","Crime Share (%) Judaism",
                        "Crime Share (%) buddhism","Crime Share (%) hinduism",
                        "Total Queies Christianity", "Total Queies Islam", "Total Queies Judaism",
                        "Total Queies buddhism", "Total Queies hinduism",
                       ]
    pivot_df["Crime Share (%) Christianity"] = pivot_df["Crime Share (%) Christianity"].apply(lambda x: "{:.2f}".format(x))
    pivot_df["Crime Share (%) Islam"] = pivot_df["Crime Share (%) Islam"].apply(lambda x: "{:.2f}".format(x))
    pivot_df["Crime Share (%) Judaism"] = pivot_df["Crime Share (%) Judaism"].apply(lambda x: "{:.2f}".format(x))
    pivot_df["Crime Share (%) buddhism"] = pivot_df["Crime Share (%) buddhism"].apply(lambda x: "{:.2f}".format(x))
    pivot_df["Crime Share (%) hinduism"] = pivot_df["Crime Share (%) hinduism"].apply(lambda x: "{:.2f}".format(x))
    
    return pivot_df

# Compute and display the result
average_crime_df = compute_average_crime_share(crime_df)

average_crime_df.to_csv("json7/average_crime_mentions_analysis.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/c1/qdg0q3b92ys5hzf9t6h4xvf40000gn/T/ipykernel_82701/3180177160.py in <module>
#      26
#      27 # Compute and display the result
# ---> 28 average_crime_df = compute_average_crime_share(crime_df)
#      29
#      30 average_crime_df.to_csv("json7/average_crime_mentions_analysis.csv", index=False)
#
# NameError: name 'crime_df' is not defined

# %%
df_analysis = pd.read_csv("json7/average_crime_mentions_analysis.csv")
df_analysis.head()

# %%
# Economic status keyword sets

wealthy_keywords = [
    "rich", "wealthy", "affluent", "luxury", "prosperous", 
    "successful", "upper class", "developed", "industrialized", 
    "privileged", "elite", "well-off", "expensive"
]

poor_keywords = [
    "poor", "poverty", "underprivileged", "low income", 
    "unemployed", "struggling", "impoverished", "needy", 
    "destitute", "underdeveloped", "slum", "rural", 
    "deprived", "hardship", "subsistence"
]

activation_analysis_keyword(base_folder='json7', topic='wealth', keywords=wealthy_keywords)
activation_analysis_keyword(base_folder='json7', topic='poverty', keywords=poor_keywords)
# Out:
# json7/wealth_mentions_summary_christianity.csv
# json7/wealth_mentions_summary_islam.csv
# json7/wealth_mentions_summary_judaism.csv
# json7/wealth_mentions_summary_buddhism.csv
# json7/wealth_mentions_summary_hinduism.csv
# json7/poverty_mentions_summary_christianity.csv
# json7/poverty_mentions_summary_islam.csv
# json7/poverty_mentions_summary_judaism.csv
# json7/poverty_mentions_summary_buddhism.csv
# json7/poverty_mentions_summary_hinduism.csv

# %%
# Geographic region keyword sets
geographic_keywords = {
    "europe": [
        "europe", "european", "eurozone", "schengen",
        "western europe", "eastern europe", "northern europe", "southern europe",
        "scandinavia", "balkans", "benelux", "iberian peninsula", "baltic states", "central europe",
        "united kingdom", "britain", "england", "scotland", "wales", "northern ireland",
        "france", "germany", "italy", "spain", "portugal", "netherlands", "belgium", "switzerland", "austria",
        "norway", "sweden", "denmark", "finland", "iceland",
        "poland", "czech republic", "slovakia", "hungary", "romania", "bulgaria", 
        "greece", "croatia", "serbia", "bosnia", "slovenia", "montenegro", "albania", "macedonia", 
        "ukraine", "belarus", "moldova", "russia", "georgia", "armenia", "azerbaijan",
        "ireland", "luxembourg", "liechtenstein", "andorra", "monaco", "san marino", "vatican",
        "london", "paris", "berlin", "rome", "madrid", "vienna", "amsterdam", "brussels", "oslo", "stockholm",
        "copenhagen", "helsinki", "lisbon", "warsaw", "prague", "budapest", "bucharest", "sofia", 
        "athens", "zagreb", "belgrade", "sarajevo", "ljubljana", "tirana", "skopje", "kiev", "minsk", "chisinau",
        "moscow", "tbilisi", "yerevan", "baku", "dublin", "luxembourg city", "vaduz", "andorra la vella",
        "eiffel tower", "big ben", "colosseum", "berlin wall", "vatican city", "acropolis", "buckingham palace", 
        "louvre", "reichstag", "sagrada familia"
    ],
    "asia": [
        "asia", "asian", "east asia", "south asia", "southeast asia", "central asia", "west asia",
        "indian subcontinent", "asian continent",
        "china", "india", "japan", "south korea", "north korea", "taiwan", "mongolia",
        "pakistan", "bangladesh", "nepal", "bhutan", "sri lanka", "maldives",
        "indonesia", "philippines", "vietnam", "thailand", "myanmar", "burma",
        "malaysia", "singapore", "cambodia", "laos", "brunei", "east timor",
        "kazakhstan", "uzbekistan", "turkmenistan", "kyrgyzstan", "tajikistan",
        "iran", "afghanistan", "georgia", "armenia", "azerbaijan",
        "beijing", "shanghai", "hong kong", "tokyo", "osaka", "seoul", "busan",
        "delhi", "mumbai", "kolkata", "chennai", "karachi", "lahore", "islamabad", "dhaka",
        "kathmandu", "thimphu", "colombo", "bangkok", "hanoi", "ho chi minh",
        "jakarta", "manila", "kuala lumpur", "singapore", "phnom penh", "vientiane", "yangon",
        "tehran", "bishkek", "dushanbe", "ashgabat", "almaty",
        "yerevan", "tbilisi", "baku",
        "great wall", "taj mahal", "angkor wat", "borobudur", "meiji shrine", "forbidden city",
        "mount fuji", "petronas towers", "ganges", "yangtze", "mekong"
    ],
   "middle_east": [
        "middle east", "middle eastern", "arab", "arabic", "gulf", "levant", "arab world",
        "iran", "iraq", "syria", "lebanon", "jordan", "palestine", "gaza", "west bank", "egypt",
        "saudi arabia", "saudi", "yemen", "oman", "emirates", "qatar", "bahrain", "kuwait", 
        "turkey", "cyprus", "sudan", "south sudan", "libya", "mauritania", "israel", "tel aviv",
        "tehran", "baghdad", "damascus", "aleppo", "beirut", "amman", "jerusalem", "gaza city", "ramallah", 
        "riyadh", "mecca", "medina", "jeddah", "sanaa", "muscat", "doha", "dubai", "abu dhabi", "manama", "kuwait city",
        "cairo", "giza", "alexandria", "khartoum", "tripoli","ankara", "istanbul", "nicosia", "khartoum",
        "al-azhar", "al-aqsa", "petra", "cedars of lebanon", "pyramids", "temple mount", "jerusalem", "sinai"
    ],
    "africa": [
        "africa", "african", "sub-saharan africa", "north africa", "west africa", "east africa", "central africa", 
        "southern africa", "saharan", "sahel", "horn of africa", "maghreb", "morocco", "algeria", "tunisia", 
        "nigeria", "ethiopia", "egypt", "south africa", "kenya", "algeria", "morocco", "sudan", "angola", "ghana",
        "mozambique", "madagascar", "cameroon", "côte d’ivoire", "ivory coast", "niger", "burkina faso", "mali",
        "malawi", "zambia", "zimbabwe", "tanzania", "rwanda", "uganda", "chad", "senegal", "tunisia", "libya",
        "botswana", "namibia", "lesotho", "eswatini", "gabon", "congo", "democratic republic of congo", "drc",
        "somalia", "south sudan", "sierra leone", "liberia", "benin", "togo", "djibouti", "equatorial guinea",
        "central african republic", "gambia", "guinea", "guinea-bissau", "mauritania", "seychelles", "comoros", "cape verde",
        "lagos", "abuja", "nairobi", "addis ababa", "johannesburg", "cape town", "durban", "tunis", "algiers", 
        "accra", "dakar", "kampala", "harare", "lusaka", "windhoek", "gaborone", "maputo", "antananarivo",
        "kinshasa", "brazzaville", "bamako", "ouagadougou", "freetown", "bujumbura", "mogadishu", "djibouti city",
        "sahara desert", "kilimanjaro", "victoria falls", "ngorongoro crater", "nile river", "zambezi"
    ],
    "north_america": [
        "north america", "north american", "american", "the us",
        "usa", "united states", "u.s.", "u.s.a.", "the states",
        "canada", "canadian", "mexico", "mexican",
        "washington", "new york", "new york city", "los angeles", "chicago", "san francisco", 
        "boston", "miami", "dallas", "houston", "atlanta", "seattle", "philadelphia", "detroit", 
        "phoenix", "denver", "las vegas", "orlando", "san diego", "austin",
        "toronto", "vancouver", "montreal", "ottawa", "calgary", "edmonton", "quebec city", "winnipeg", "halifax",
        "mexico city", "guadalajara", "monterrey", "tijuana", "cancun", "puebla", "merida",
        "white house", "statue of liberty", "niagara falls", "grand canyon", "empire state building", "times square", 
        "hollywood", "pentagon", "capitol hill", "liberty bell", "alamo", "mount rushmore", "silicon valley"
    ],
    "south_america": [
        "south america", "south american", "latin america", "latinoamerica", "andes", 
        "argentina", "brazil", "chile", "peru", "colombia", "venezuela", "ecuador", "bolivia",
        "paraguay", "uruguay", "guyana", "suriname", "french guiana",
        "buenos aires", "rosario", "cordoba", "rio de janeiro", "são paulo", "brasilia", "salvador", "recife",
        "santiago", "valparaíso", "lima", "cusco", "bogotá", "medellín", "caracas", "quito", 
        "la paz", "sucre", "asunción", "montevideo", "georgetown", "paramaribo", "cayenne",
        "amazon rainforest", "andes mountains", "machu picchu", "iguazu falls", "cristo redentor", "atacama desert",
        "pampas", "patagonia", "galápagos islands"
    ],
    "australia": [
        "australia", "australian", "oceania", "australasia", "new zealand", "kiwi","aotearoa",
        "papua new guinea", "fiji", "samoa", "tonga", "vanuatu", "solomon islands", 
        "micronesia", "palau", "marshall islands", "nauru", "tuvalu", "kiribati",
        "sydney", "melbourne", "canberra", "brisbane", "perth", "adelaide", "hobart", "darwin",
        "auckland", "wellington", "christchurch", "hamilton", "dunedin", "suva", "port moresby", "nukuʻalofa",
        "great barrier reef", "uluru", "ayers rock", "outback", "tasmania", "kangaroo island",
        "aboriginal", "maori", "dreamtime", "coral sea", "southern ocean", "tasman sea",
        "anzac", "trans-tasman"
    ]
}

for region in geographic_keywords:
    activation_analysis_keyword(base_folder='json7', topic=f'geo_{region}', keywords=geographic_keywords[region])
# Out:
# json7/geo_europe_mentions_summary_christianity.csv
# json7/geo_europe_mentions_summary_islam.csv
# json7/geo_europe_mentions_summary_judaism.csv
# json7/geo_europe_mentions_summary_buddhism.csv
# json7/geo_europe_mentions_summary_hinduism.csv
# json7/geo_asia_mentions_summary_christianity.csv
# json7/geo_asia_mentions_summary_islam.csv
# json7/geo_asia_mentions_summary_judaism.csv
# json7/geo_asia_mentions_summary_buddhism.csv
# json7/geo_asia_mentions_summary_hinduism.csv
# json7/geo_middle_east_mentions_summary_christianity.csv
# json7/geo_middle_east_mentions_summary_islam.csv
# json7/geo_middle_east_mentions_summary_judaism.csv
# json7/geo_middle_east_mentions_summary_buddhism.csv
# json7/geo_middle_east_mentions_summary_hinduism.csv
# json7/geo_africa_mentions_summary_christianity.csv
# json7/geo_africa_mentions_summary_islam.csv
# json7/geo_africa_mentions_summary_judaism.csv
# json7/geo_africa_mentions_summary_buddhism.csv
# json7/geo_africa_mentions_summary_hinduism.csv
# ...

# %%
def get_topic_mentions_stats(topic="crime", base_folder='json7'):
    files = {
        "Christianity": f"{base_folder}/{topic}_mentions_summary_christianity.csv",
        "Islam": f"{base_folder}/{topic}_mentions_summary_islam.csv",
        "Judaism": f"{base_folder}/{topic}_mentions_summary_judaism.csv",
        "buddhism": f"{base_folder}/{topic}_mentions_summary_buddhism.csv",
        "hinduism": f"{base_folder}/{topic}_mentions_summary_hinduism.csv",
    }
    
    data = []
    for religion, file in files.items():
        df = pd.read_csv(file)
        unique_models = df["model"].unique()
        
        for model in unique_models:
            model_df = df[df["model"] == model]
            row = model_df.iloc[0]  # Take the first occurrence of each model
            total_queries = row["total_queries"]
            mentions_count = row[f"{topic}_mentions_count"]
            mentions_share = (mentions_count / total_queries) * 100 if total_queries > 0 else 0
            data.append({
                "Model": model,
                "Religion": religion,
                "Total Queries": total_queries,
                "Mentions Count": mentions_count,
            })
    
    topic_df = pd.DataFrame(data)
    topic_df.to_csv(f"json7/{topic}_mentions_analysis.csv", index=False)
    
    topic_df['Model'] = topic_df['Model'].str.split('/').str[0]

    grouped_df = topic_df.groupby(['Model', 'Religion'], as_index=False).agg({
        'Total Queries': 'sum',
        'Mentions Count': 'sum'
    })
    # Recalculate Crime Share (%)
    grouped_df['Mentions Share (%)'] = ((grouped_df['Mentions Count'] / grouped_df['Total Queries']) * 100).apply(lambda x: "{:.2f}".format(x))
    return grouped_df

# %%
get_topic_mentions_stats(topic="crime", base_folder='json7')
# Out:
#             Model      Religion  Total Queries  Mentions Count  \
# 0      gemma-2-2b  Christianity          23695             442
# 1      gemma-2-2b         Islam          23180             469
# 2      gemma-2-2b       Judaism          20993             382
# 3      gemma-2-2b      buddhism          22486             389
# 4      gemma-2-2b      hinduism          20541             384
# 5      gemma-2-9b  Christianity           9675             268
# 6      gemma-2-9b         Islam           9630             287
# 7      gemma-2-9b       Judaism           8880             244
# 8      gemma-2-9b      buddhism           9403             257
# 9      gemma-2-9b      hinduism           8909             239
# 10  gemma-2-9b-it  Christianity          21477             524
# 11  gemma-2-9b-it         Islam          20575             711
# 12  gemma-2-9b-it       Judaism          19512             429
# 13  gemma-2-9b-it      buddhism          20773             441
# ...

# %%
get_topic_mentions_stats(topic="wealth", base_folder='json7')
# Out:
#             Model      Religion  Total Queries  Mentions Count  \
# 0      gemma-2-2b  Christianity          23695            1155
# 1      gemma-2-2b         Islam          23180            1105
# 2      gemma-2-2b       Judaism          20993            1100
# 3      gemma-2-2b      buddhism          22486            1077
# 4      gemma-2-2b      hinduism          20541             938
# 5      gemma-2-9b  Christianity           9675             326
# 6      gemma-2-9b         Islam           9630             350
# 7      gemma-2-9b       Judaism           8880             418
# 8      gemma-2-9b      buddhism           9403             332
# 9      gemma-2-9b      hinduism           8909             322
# 10  gemma-2-9b-it  Christianity          21477             941
# 11  gemma-2-9b-it         Islam          20575             914
# 12  gemma-2-9b-it       Judaism          19512             778
# 13  gemma-2-9b-it      buddhism          20773             914
# ...

# %%
get_topic_mentions_stats(topic="poverty", base_folder='json7')
# Out:
#             Model      Religion  Total Queries  Mentions Count  \
# 0      gemma-2-2b  Christianity          23695             302
# 1      gemma-2-2b         Islam          23180             324
# 2      gemma-2-2b       Judaism          20993             309
# 3      gemma-2-2b      buddhism          22486             284
# 4      gemma-2-2b      hinduism          20541             376
# 5      gemma-2-9b  Christianity           9675             112
# 6      gemma-2-9b         Islam           9630             132
# 7      gemma-2-9b       Judaism           8880             113
# 8      gemma-2-9b      buddhism           9403             106
# 9      gemma-2-9b      hinduism           8909             156
# 10  gemma-2-9b-it  Christianity          21477             304
# 11  gemma-2-9b-it         Islam          20575             294
# 12  gemma-2-9b-it       Judaism          19512             254
# 13  gemma-2-9b-it      buddhism          20773             269
# ...

# %%
get_topic_mentions_stats(topic="geo_europe", base_folder='json7')
# Out:
#             Model      Religion  Total Queries  Mentions Count  \
# 0      gemma-2-2b  Christianity          23695            1514
# 1      gemma-2-2b         Islam          23180            1562
# 2      gemma-2-2b       Judaism          20993            1323
# 3      gemma-2-2b      buddhism          22486            1369
# 4      gemma-2-2b      hinduism          20541            1318
# 5      gemma-2-9b  Christianity           9675             569
# 6      gemma-2-9b         Islam           9630             601
# 7      gemma-2-9b       Judaism           8880             492
# 8      gemma-2-9b      buddhism           9403             510
# 9      gemma-2-9b      hinduism           8909             516
# 10  gemma-2-9b-it  Christianity          21477            1652
# 11  gemma-2-9b-it         Islam          20575            1409
# 12  gemma-2-9b-it       Judaism          19512            1112
# 13  gemma-2-9b-it      buddhism          20773            1391
# ...

# %%
get_topic_mentions_stats(topic="geo_asia", base_folder='json7')
# Out:
#             Model      Religion  Total Queries  Mentions Count  \
# 0      gemma-2-2b  Christianity          23695             881
# 1      gemma-2-2b         Islam          23180             925
# 2      gemma-2-2b       Judaism          20993             873
# 3      gemma-2-2b      buddhism          22486             999
# 4      gemma-2-2b      hinduism          20541             841
# 5      gemma-2-9b  Christianity           9675             144
# 6      gemma-2-9b         Islam           9630             173
# 7      gemma-2-9b       Judaism           8880             204
# 8      gemma-2-9b      buddhism           9403             169
# 9      gemma-2-9b      hinduism           8909             224
# 10  gemma-2-9b-it  Christianity          21477             575
# 11  gemma-2-9b-it         Islam          20575             834
# 12  gemma-2-9b-it       Judaism          19512             568
# 13  gemma-2-9b-it      buddhism          20773            1026
# ...

# %%
get_topic_mentions_stats(topic="geo_middle_east", base_folder='json7')
# Out:
#             Model      Religion  Total Queries  Mentions Count  \
# 0      gemma-2-2b  Christianity          23695            1017
# 1      gemma-2-2b         Islam          23180             926
# 2      gemma-2-2b       Judaism          20993             808
# 3      gemma-2-2b      buddhism          22486             862
# 4      gemma-2-2b      hinduism          20541             763
# 5      gemma-2-9b  Christianity           9675             496
# 6      gemma-2-9b         Islam           9630             487
# 7      gemma-2-9b       Judaism           8880             470
# 8      gemma-2-9b      buddhism           9403             460
# 9      gemma-2-9b      hinduism           8909             465
# 10  gemma-2-9b-it  Christianity          21477             948
# 11  gemma-2-9b-it         Islam          20575            1130
# 12  gemma-2-9b-it       Judaism          19512             834
# 13  gemma-2-9b-it      buddhism          20773             728
# ...

# %%
get_topic_mentions_stats(topic="geo_africa", base_folder='json7')
# Out:
#             Model      Religion  Total Queries  Mentions Count  \
# 0      gemma-2-2b  Christianity          23695             649
# 1      gemma-2-2b         Islam          23180             643
# 2      gemma-2-2b       Judaism          20993             562
# 3      gemma-2-2b      buddhism          22486             633
# 4      gemma-2-2b      hinduism          20541             578
# 5      gemma-2-9b  Christianity           9675             276
# 6      gemma-2-9b         Islam           9630             267
# 7      gemma-2-9b       Judaism           8880             242
# 8      gemma-2-9b      buddhism           9403             279
# 9      gemma-2-9b      hinduism           8909             260
# 10  gemma-2-9b-it  Christianity          21477             517
# 11  gemma-2-9b-it         Islam          20575             575
# 12  gemma-2-9b-it       Judaism          19512             434
# 13  gemma-2-9b-it      buddhism          20773             437
# ...

# %%
get_topic_mentions_stats(topic="geo_australia", base_folder='json7')
# Out:
#             Model      Religion  Total Queries  Mentions Count  \
# 0      gemma-2-2b  Christianity          23695             209
# 1      gemma-2-2b         Islam          23180             215
# 2      gemma-2-2b       Judaism          20993             189
# 3      gemma-2-2b      buddhism          22486             202
# 4      gemma-2-2b      hinduism          20541             198
# 5      gemma-2-9b  Christianity           9675             131
# 6      gemma-2-9b         Islam           9630             146
# 7      gemma-2-9b       Judaism           8880             116
# 8      gemma-2-9b      buddhism           9403             135
# 9      gemma-2-9b      hinduism           8909             128
# 10  gemma-2-9b-it  Christianity          21477             230
# 11  gemma-2-9b-it         Islam          20575             163
# 12  gemma-2-9b-it       Judaism          19512             161
# 13  gemma-2-9b-it      buddhism          20773             174
# ...

# %%
get_topic_mentions_stats(topic="geo_north_america", base_folder='json7')
# Out:
#             Model      Religion  Total Queries  Mentions Count  \
# 0      gemma-2-2b  Christianity          23695            1116
# 1      gemma-2-2b         Islam          23180            1099
# 2      gemma-2-2b       Judaism          20993             971
# 3      gemma-2-2b      buddhism          22486            1064
# 4      gemma-2-2b      hinduism          20541             966
# 5      gemma-2-9b  Christianity           9675             429
# 6      gemma-2-9b         Islam           9630             402
# 7      gemma-2-9b       Judaism           8880             398
# 8      gemma-2-9b      buddhism           9403             405
# 9      gemma-2-9b      hinduism           8909             367
# 10  gemma-2-9b-it  Christianity          21477            1093
# 11  gemma-2-9b-it         Islam          20575            1145
# 12  gemma-2-9b-it       Judaism          19512             984
# 13  gemma-2-9b-it      buddhism          20773            1135
# ...

# %%
get_topic_mentions_stats(topic="geo_south_america", base_folder='json7')
# Out:
#             Model      Religion  Total Queries  Mentions Count  \
# 0      gemma-2-2b  Christianity          23695             275
# 1      gemma-2-2b         Islam          23180             264
# 2      gemma-2-2b       Judaism          20993             209
# 3      gemma-2-2b      buddhism          22486             229
# 4      gemma-2-2b      hinduism          20541             228
# 5      gemma-2-9b  Christianity           9675              59
# 6      gemma-2-9b         Islam           9630              74
# 7      gemma-2-9b       Judaism           8880              61
# 8      gemma-2-9b      buddhism           9403              52
# 9      gemma-2-9b      hinduism           8909              78
# 10  gemma-2-9b-it  Christianity          21477             256
# 11  gemma-2-9b-it         Islam          20575             218
# 12  gemma-2-9b-it       Judaism          19512             202
# 13  gemma-2-9b-it      buddhism          20773             242
# ...

# %%
import step7_generate_feature_summary
importlib.reload(step7_generate_feature_summary)

from step7_generate_feature_summary import generate_feature_summary

generate_feature_summary(base_folder='json7')
# Out:
# Feature summary CSV saved to json7/feature_summary.csv

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import glob

# Step 1: Load and process all CSVs
csv_files = glob.glob("json7/geo_*_mentions_summary_*.csv")

data = []
for file in csv_files:
    parts = file.split("_")
    region = parts[1]
    if region == "middle":
        region = "middle_east"
    if region == "north":
        region = "north_america"
    if region == "south":
        region = "south_america"
    religion = parts[-1].replace(".csv", "")
    df = pd.read_csv(file)

    for _, row in df.iterrows():
        total_queries = row['total_queries']
        mentions = row[f'geo_{region}_mentions_count']
        if total_queries > 0:
            share = (mentions / total_queries) * 100
            data.append({
                "Region": " ".join(region.split("_")).capitalize(),
                "Religion": religion.capitalize(),
                "Mentions Share (%)": share
            })

df_all = pd.DataFrame(data)
df_avg = df_all.groupby(["Region", "Religion"])["Mentions Share (%)"].mean().reset_index()

# Pivot for heatmap
pivot_df = df_avg.pivot(index="Religion", columns="Region", values="Mentions Share (%)")

# Normalize each column (region-wise min-max normalization)
norm_df = pivot_df.copy()
for col in norm_df.columns:
    col_min = norm_df[col].min()
    col_max = norm_df[col].max()
    if col_max != col_min:
        norm_df[col] = (norm_df[col] - col_min) / (col_max - col_min)
    else:
        norm_df[col] = 0.5  # constant column fallback

# Plot normalized heatmap with normalized annotations
plt.figure(figsize=(7, 6))
sns.set(font_scale=1.1)
blue_palette = sns.light_palette("#003b73", as_cmap=True)
sns.heatmap(
    norm_df,
    annot=norm_df.round(2),  # match displayed values to normalized ones
    cmap=blue_palette,
    linewidths=0.5,
    linecolor='white',
    cbar_kws={'label': 'Normalized Mentions (per Region)'},
)
plt.title("Normalized Mentions Share by Religion and Region", fontsize=14, pad=15)
plt.xlabel("", fontsize=12)
plt.ylabel("", fontsize=12)
plt.xticks(rotation=30, ha='right')
plt.tight_layout()
plt.show()

print(norm_df)
# Out:
# Region          Africa      Asia  Australia    Europe  Middle east  \
# Religion
# Buddhism      0.212589  0.872489   0.000000  0.861349     0.000000
# Christianity  0.149349  0.000000   1.000000  1.000000     0.754965
# Hinduism      0.707535  1.000000   0.808408  0.606012     0.351883
# Islam         1.000000  0.522735   0.536055  0.994457     1.000000
# Judaism       0.000000  0.304669   0.258521  0.000000     0.644818
#
# Region        North america  South america
# Religion
# Buddhism           0.596828       0.301491
# Christianity       0.000000       0.834860
# Hinduism           1.000000       1.000000
# Islam              0.760792       0.977928
# Judaism            0.605985       0.000000

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import glob

# Step 1: Load and process all CSVs
csv_files = glob.glob("json7/geo_*_mentions_summary_*.csv")

data = []
for file in csv_files:
    parts = file.split("_")
    region = parts[1]
    if region == "middle":
        region = "middle_east"
    if region == "north":
        region = "north_america"
    if region == "south":
        region = "south_america"
    religion = parts[-1].replace(".csv", "")
    df = pd.read_csv(file)

    for _, row in df.iterrows():
        total_queries = row['total_queries']
        mentions = row[f'geo_{region}_mentions_count']
        if total_queries > 0:
            share = (mentions / total_queries) * 100
            data.append({
                "Region": " ".join(region.split("_")).capitalize(),
                "Religion": religion.capitalize(),
                "Mentions Share (%)": share
            })

df_all = pd.DataFrame(data)

# Group and average across files (if duplicates exist)
df_avg = df_all.groupby(["Region", "Religion"])["Mentions Share (%)"].mean().reset_index()

# Set plot style
plt.figure(figsize=(18, 6))
sns.set(style="whitegrid", font_scale=1.2)

# Plot grouped bar chart
sns.barplot(
    data=df_avg,
    x="Region",
    y="Mentions Share (%)",
    hue="Religion"
)

plt.title("Geographic Mentions Share by Religion", fontsize=18, pad=15)
plt.ylabel("Mentions Share (%)", fontsize=17)
plt.xlabel("Region", fontsize=17)
plt.xticks(rotation=30, ha='right')
plt.legend(title="Religion", bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import glob

# Step 1: Load and process all CSVs
csv_files = glob.glob("json7/geo_*_mentions_summary_*.csv")

data = []
for file in csv_files:
    parts = file.split("_")
    region = parts[1]
    if region == "middle":
        region = "middle_east"
    if region == "north":
        region = "north_america"
    if region == "south":
        region = "south_america"
    religion = parts[-1].replace(".csv", "")
    df = pd.read_csv(file)

    for _, row in df.iterrows():
        total_queries = row['total_queries']
        mentions = row[f'geo_{region}_mentions_count']
        if total_queries > 0:
            share = (mentions / total_queries) * 100
            data.append({
                "Region": " ".join(region.split("_")).capitalize(),
                "Religion": religion.capitalize(),
                "Mentions Share (%)": share
            })

df_all = pd.DataFrame(data)
df_avg = df_all.groupby(["Region", "Religion"])["Mentions Share (%)"].mean().reset_index()

# Normalize values per region (column-wise normalization)
pivot_df = df_avg.pivot(index="Religion", columns="Region", values="Mentions Share (%)")
norm_df = pivot_df.copy()
for col in norm_df.columns:
    col_min = norm_df[col].min()
    col_max = norm_df[col].max()
    if col_max != col_min:
        norm_df[col] = (norm_df[col] - col_min) / (col_max - col_min)
    else:
        norm_df[col] = 0.5

# Melt normalized values for bar plot
df_norm = norm_df.reset_index().melt(id_vars="Religion", var_name="Region", value_name="Normalized Share")

# Plot grouped bar chart
plt.figure(figsize=(12, 6))
sns.set(style="whitegrid", font_scale=1.1)
sns.barplot(
    data=df_norm,
    x="Region",
    y="Normalized Share",
    hue="Religion"
)

plt.title("Normalized Geographic Mentions Share by Religion", fontsize=14, pad=15)
plt.ylabel("Normalized Share", fontsize=12)
plt.xlabel("Region", fontsize=12)
plt.xticks(rotation=30, ha='right')
plt.legend(title="Religion", bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()
