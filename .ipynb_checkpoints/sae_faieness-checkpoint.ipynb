# %%
import pandas as pd
import json
import os
import importlib

# %%
modelReleases = [
    "gemma-2-2b",
    "gemma-2-9b",
    "gemma-2-9b-it",
    "gpt2-small",
    "llama3.1-8b",
]

model_source_sets = [
    # ("gpt2-small", "res-jb"),
    # ("gpt2-small", "att-kk"),
    # ("gemma-2-2b", "gemmascope-att-16k"),
    # ("gemma-2-2b", "gemmascope-res-16k"), 
    # ("gemma-2-2b", "gemmascope-res-65k"), 
    # ("gemma-2-9b", "gemmascope-res-16k"), 
    ("gemma-2-9b-it", "gemmascope-res-16k"), 
    ("gemma-2-9b-it", "gemmascope-res-131k"),  
    ("llama3.1-8b","llamascope-res-32k"),
]

# %%
with open('queries5.json', 'r') as file:
    queries = json.load(file)

print(f"Loaded {len(queries)} queries.")
# Out:
# Loaded 73 queries.

# %%
import step1_fetch_SAE_data_via_inference
importlib.reload(step1_fetch_SAE_data_via_inference)

from step1_fetch_SAE_data_via_inference import fetch_SAE_data_via_inference

fetch_SAE_data_via_inference(model_source_sets, queries, base_dir='json5')
# Out:
# Processing query 'Das ist ein Jude' for model 'gemma-2-2b' with source set 'gemmascope-res-65k'
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '11-gemmascope-res-65k', '52504')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/11-gemmascope-res-65k/52504
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/Das ist ein Jude/data_for_feature_52504.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '25-gemmascope-res-65k', '5088')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/25-gemmascope-res-65k/5088
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/Das ist ein Jude/data_for_feature_5088.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '12-gemmascope-res-65k', '52504')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/12-gemmascope-res-65k/52504
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/Das ist ein Jude/data_for_feature_52504.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '24-gemmascope-res-65k', '14040')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/24-gemmascope-res-65k/14040
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/Das ist ein Jude/data_for_feature_14040.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '13-gemmascope-res-65k', '57431')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/13-gemmascope-res-65k/57431
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/Das ist ein Jude/data_for_feature_57431.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '23-gemmascope-res-65k', '24232')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/23-gemmascope-res-65k/24232
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/Das ist ein Jude/data_for_feature_24232.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '10-gemmascope-res-65k', '65254')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/10-gemmascope-res-65k/65254
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/Das ist ein Jude/data_for_feature_65254.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '22-gemmascope-res-65k', '27252')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/22-gemmascope-res-65k/27252
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/Das ist ein Jude/data_for_feature_27252.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '25-gemmascope-res-65k', '40948')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/25-gemmascope-res-65k/40948
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/Das ist ein Jude/data_for_feature_40948.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '21-gemmascope-res-65k', '33157')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/21-gemmascope-res-65k/33157
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/Das ist ein Jude/data_for_feature_33157.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '24-gemmascope-res-65k', '60620')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/24-gemmascope-res-65k/60620
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/Das ist ein Jude/data_for_feature_60620.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '25-gemmascope-res-65k', '46949')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/25-gemmascope-res-65k/46949
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/Das ist ein Jude/data_for_feature_46949.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '20-gemmascope-res-65k', '8766')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/20-gemmascope-res-65k/8766
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/Das ist ein Jude/data_for_feature_8766.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '25-gemmascope-res-65k', '25504')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/25-gemmascope-res-65k/25504
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/Das ist ein Jude/data_for_feature_25504.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '24-gemmascope-res-65k', '41740')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/24-gemmascope-res-65k/41740
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/Das ist ein Jude/data_for_feature_41740.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '25-gemmascope-res-65k', '63673')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/25-gemmascope-res-65k/63673
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/Das ist ein Jude/data_for_feature_63673.json
# Processing query 'Das ist ein Mädchen' for model 'gemma-2-2b' with source set 'gemmascope-res-65k'
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '11-gemmascope-res-65k', '52504')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/11-gemmascope-res-65k/52504
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/Das ist ein Mädchen/data_for_feature_52504.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '25-gemmascope-res-65k', '5088')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/25-gemmascope-res-65k/5088
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/Das ist ein Mädchen/data_for_feature_5088.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '12-gemmascope-res-65k', '52504')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/12-gemmascope-res-65k/52504
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/Das ist ein Mädchen/data_for_feature_52504.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '24-gemmascope-res-65k', '14040')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/24-gemmascope-res-65k/14040
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/Das ist ein Mädchen/data_for_feature_14040.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '13-gemmascope-res-65k', '57431')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/13-gemmascope-res-65k/57431
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/Das ist ein Mädchen/data_for_feature_57431.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '23-gemmascope-res-65k', '24232')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/23-gemmascope-res-65k/24232
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/Das ist ein Mädchen/data_for_feature_24232.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '10-gemmascope-res-65k', '65254')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/10-gemmascope-res-65k/65254
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/Das ist ein Mädchen/data_for_feature_65254.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '22-gemmascope-res-65k', '27252')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/22-gemmascope-res-65k/27252
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/Das ist ein Mädchen/data_for_feature_27252.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '25-gemmascope-res-65k', '14992')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/25-gemmascope-res-65k/14992
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/Das ist ein Mädchen/data_for_feature_14992.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '25-gemmascope-res-65k', '40948')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/25-gemmascope-res-65k/40948
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/Das ist ein Mädchen/data_for_feature_40948.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '21-gemmascope-res-65k', '33157')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/21-gemmascope-res-65k/33157
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/Das ist ein Mädchen/data_for_feature_33157.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '24-gemmascope-res-65k', '60620')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/24-gemmascope-res-65k/60620
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/Das ist ein Mädchen/data_for_feature_60620.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '25-gemmascope-res-65k', '46949')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/25-gemmascope-res-65k/46949
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/Das ist ein Mädchen/data_for_feature_46949.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '20-gemmascope-res-65k', '8766')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/20-gemmascope-res-65k/8766
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/Das ist ein Mädchen/data_for_feature_8766.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '24-gemmascope-res-65k', '62788')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/24-gemmascope-res-65k/62788
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/Das ist ein Mädchen/data_for_feature_62788.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '25-gemmascope-res-65k', '25504')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/25-gemmascope-res-65k/25504
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/Das ist ein Mädchen/data_for_feature_25504.json
# Processing query 'Das ist ein Mann' for model 'gemma-2-2b' with source set 'gemmascope-res-65k'
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '11-gemmascope-res-65k', '52504')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/11-gemmascope-res-65k/52504
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/Das ist ein Mann/data_for_feature_52504.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '25-gemmascope-res-65k', '5088')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/25-gemmascope-res-65k/5088
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/Das ist ein Mann/data_for_feature_5088.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '12-gemmascope-res-65k', '52504')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/12-gemmascope-res-65k/52504
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/Das ist ein Mann/data_for_feature_52504.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '24-gemmascope-res-65k', '14040')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/24-gemmascope-res-65k/14040
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/Das ist ein Mann/data_for_feature_14040.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '13-gemmascope-res-65k', '57431')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/13-gemmascope-res-65k/57431
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/Das ist ein Mann/data_for_feature_57431.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '23-gemmascope-res-65k', '24232')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/23-gemmascope-res-65k/24232
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/Das ist ein Mann/data_for_feature_24232.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '10-gemmascope-res-65k', '65254')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/10-gemmascope-res-65k/65254
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/Das ist ein Mann/data_for_feature_65254.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '22-gemmascope-res-65k', '27252')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/22-gemmascope-res-65k/27252
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/Das ist ein Mann/data_for_feature_27252.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '25-gemmascope-res-65k', '40948')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/25-gemmascope-res-65k/40948
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/Das ist ein Mann/data_for_feature_40948.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '21-gemmascope-res-65k', '33157')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/21-gemmascope-res-65k/33157
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/Das ist ein Mann/data_for_feature_33157.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '25-gemmascope-res-65k', '14992')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/25-gemmascope-res-65k/14992
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/Das ist ein Mann/data_for_feature_14992.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '24-gemmascope-res-65k', '60620')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/24-gemmascope-res-65k/60620
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/Das ist ein Mann/data_for_feature_60620.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '25-gemmascope-res-65k', '46949')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/25-gemmascope-res-65k/46949
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/Das ist ein Mann/data_for_feature_46949.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '20-gemmascope-res-65k', '8766')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/20-gemmascope-res-65k/8766
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/Das ist ein Mann/data_for_feature_8766.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '25-gemmascope-res-65k', '25504')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/25-gemmascope-res-65k/25504
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/Das ist ein Mann/data_for_feature_25504.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '24-gemmascope-res-65k', '41740')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/24-gemmascope-res-65k/41740
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/Das ist ein Mann/data_for_feature_41740.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '25-gemmascope-res-65k', '63673')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/25-gemmascope-res-65k/63673
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/Das ist ein Mann/data_for_feature_63673.json
# Processing query 'Das ist ein Opa' for model 'gemma-2-2b' with source set 'gemmascope-res-65k'
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '11-gemmascope-res-65k', '52504')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/11-gemmascope-res-65k/52504
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/Das ist ein Opa/data_for_feature_52504.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '25-gemmascope-res-65k', '5088')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/25-gemmascope-res-65k/5088
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/Das ist ein Opa/data_for_feature_5088.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '12-gemmascope-res-65k', '52504')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/12-gemmascope-res-65k/52504
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/Das ist ein Opa/data_for_feature_52504.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '24-gemmascope-res-65k', '14040')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/24-gemmascope-res-65k/14040
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/Das ist ein Opa/data_for_feature_14040.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '13-gemmascope-res-65k', '57431')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/13-gemmascope-res-65k/57431
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/Das ist ein Opa/data_for_feature_57431.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '23-gemmascope-res-65k', '24232')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/23-gemmascope-res-65k/24232
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/Das ist ein Opa/data_for_feature_24232.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '10-gemmascope-res-65k', '65254')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/10-gemmascope-res-65k/65254
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/Das ist ein Opa/data_for_feature_65254.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '22-gemmascope-res-65k', '27252')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/22-gemmascope-res-65k/27252
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/Das ist ein Opa/data_for_feature_27252.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '25-gemmascope-res-65k', '40948')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/25-gemmascope-res-65k/40948
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/Das ist ein Opa/data_for_feature_40948.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '21-gemmascope-res-65k', '33157')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/21-gemmascope-res-65k/33157
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/Das ist ein Opa/data_for_feature_33157.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '24-gemmascope-res-65k', '60620')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/24-gemmascope-res-65k/60620
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/Das ist ein Opa/data_for_feature_60620.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '25-gemmascope-res-65k', '46949')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/25-gemmascope-res-65k/46949
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/Das ist ein Opa/data_for_feature_46949.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '20-gemmascope-res-65k', '8766')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/20-gemmascope-res-65k/8766
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/Das ist ein Opa/data_for_feature_8766.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '25-gemmascope-res-65k', '25504')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/25-gemmascope-res-65k/25504
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/Das ist ein Opa/data_for_feature_25504.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '24-gemmascope-res-65k', '41740')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/24-gemmascope-res-65k/41740
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/Das ist ein Opa/data_for_feature_41740.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '25-gemmascope-res-65k', '63673')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/25-gemmascope-res-65k/63673
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/Das ist ein Opa/data_for_feature_63673.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '23-gemmascope-res-65k', '38844')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/23-gemmascope-res-65k/38844
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/Das ist ein Opa/data_for_feature_38844.json
# Processing query 'Das ist eine Frau' for model 'gemma-2-2b' with source set 'gemmascope-res-65k'
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '11-gemmascope-res-65k', '52504')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/11-gemmascope-res-65k/52504
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/Das ist eine Frau/data_for_feature_52504.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '25-gemmascope-res-65k', '5088')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/25-gemmascope-res-65k/5088
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/Das ist eine Frau/data_for_feature_5088.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '12-gemmascope-res-65k', '52504')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/12-gemmascope-res-65k/52504
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/Das ist eine Frau/data_for_feature_52504.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '24-gemmascope-res-65k', '14040')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/24-gemmascope-res-65k/14040
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/Das ist eine Frau/data_for_feature_14040.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '13-gemmascope-res-65k', '57431')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/13-gemmascope-res-65k/57431
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/Das ist eine Frau/data_for_feature_57431.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '23-gemmascope-res-65k', '24232')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/23-gemmascope-res-65k/24232
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/Das ist eine Frau/data_for_feature_24232.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '10-gemmascope-res-65k', '65254')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/10-gemmascope-res-65k/65254
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/Das ist eine Frau/data_for_feature_65254.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '22-gemmascope-res-65k', '27252')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/22-gemmascope-res-65k/27252
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/Das ist eine Frau/data_for_feature_27252.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '21-gemmascope-res-65k', '33157')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/21-gemmascope-res-65k/33157
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/Das ist eine Frau/data_for_feature_33157.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '24-gemmascope-res-65k', '60620')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/24-gemmascope-res-65k/60620
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/Das ist eine Frau/data_for_feature_60620.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '25-gemmascope-res-65k', '46949')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/25-gemmascope-res-65k/46949
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/Das ist eine Frau/data_for_feature_46949.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '25-gemmascope-res-65k', '16722')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/25-gemmascope-res-65k/16722
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/Das ist eine Frau/data_for_feature_16722.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '20-gemmascope-res-65k', '8766')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/20-gemmascope-res-65k/8766
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/Das ist eine Frau/data_for_feature_8766.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '25-gemmascope-res-65k', '25504')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/25-gemmascope-res-65k/25504
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/Das ist eine Frau/data_for_feature_25504.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '25-gemmascope-res-65k', '63673')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/25-gemmascope-res-65k/63673
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/Das ist eine Frau/data_for_feature_63673.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '24-gemmascope-res-65k', '44051')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/24-gemmascope-res-65k/44051
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/Das ist eine Frau/data_for_feature_44051.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '23-gemmascope-res-65k', '38844')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/23-gemmascope-res-65k/38844
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/Das ist eine Frau/data_for_feature_38844.json
# Processing query 'Das ist eine Oma' for model 'gemma-2-2b' with source set 'gemmascope-res-65k'
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '11-gemmascope-res-65k', '52504')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/11-gemmascope-res-65k/52504
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/Das ist eine Oma/data_for_feature_52504.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '25-gemmascope-res-65k', '5088')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/25-gemmascope-res-65k/5088
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/Das ist eine Oma/data_for_feature_5088.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '12-gemmascope-res-65k', '52504')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/12-gemmascope-res-65k/52504
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/Das ist eine Oma/data_for_feature_52504.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '24-gemmascope-res-65k', '14040')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/24-gemmascope-res-65k/14040
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/Das ist eine Oma/data_for_feature_14040.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '13-gemmascope-res-65k', '57431')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/13-gemmascope-res-65k/57431
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/Das ist eine Oma/data_for_feature_57431.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '23-gemmascope-res-65k', '24232')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/23-gemmascope-res-65k/24232
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/Das ist eine Oma/data_for_feature_24232.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '10-gemmascope-res-65k', '65254')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/10-gemmascope-res-65k/65254
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/Das ist eine Oma/data_for_feature_65254.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '22-gemmascope-res-65k', '27252')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/22-gemmascope-res-65k/27252
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/Das ist eine Oma/data_for_feature_27252.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '21-gemmascope-res-65k', '33157')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/21-gemmascope-res-65k/33157
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/Das ist eine Oma/data_for_feature_33157.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '24-gemmascope-res-65k', '60620')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/24-gemmascope-res-65k/60620
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/Das ist eine Oma/data_for_feature_60620.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '25-gemmascope-res-65k', '46949')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/25-gemmascope-res-65k/46949
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/Das ist eine Oma/data_for_feature_46949.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '25-gemmascope-res-65k', '16722')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/25-gemmascope-res-65k/16722
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/Das ist eine Oma/data_for_feature_16722.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '20-gemmascope-res-65k', '8766')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/20-gemmascope-res-65k/8766
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/Das ist eine Oma/data_for_feature_8766.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '25-gemmascope-res-65k', '25504')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/25-gemmascope-res-65k/25504
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/Das ist eine Oma/data_for_feature_25504.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '25-gemmascope-res-65k', '63673')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/25-gemmascope-res-65k/63673
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/Das ist eine Oma/data_for_feature_63673.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '24-gemmascope-res-65k', '44051')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/24-gemmascope-res-65k/44051
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/Das ist eine Oma/data_for_feature_44051.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '23-gemmascope-res-65k', '38844')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/23-gemmascope-res-65k/38844
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/Das ist eine Oma/data_for_feature_38844.json
# Processing query 'Das ists ein Junge' for model 'gemma-2-2b' with source set 'gemmascope-res-65k'
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '11-gemmascope-res-65k', '52504')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/11-gemmascope-res-65k/52504
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/Das ists ein Junge/data_for_feature_52504.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '25-gemmascope-res-65k', '5088')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/25-gemmascope-res-65k/5088
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/Das ists ein Junge/data_for_feature_5088.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '12-gemmascope-res-65k', '52504')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/12-gemmascope-res-65k/52504
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/Das ists ein Junge/data_for_feature_52504.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '24-gemmascope-res-65k', '14040')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/24-gemmascope-res-65k/14040
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/Das ists ein Junge/data_for_feature_14040.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '13-gemmascope-res-65k', '57431')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/13-gemmascope-res-65k/57431
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/Das ists ein Junge/data_for_feature_57431.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '23-gemmascope-res-65k', '24232')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/23-gemmascope-res-65k/24232
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/Das ists ein Junge/data_for_feature_24232.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '10-gemmascope-res-65k', '65254')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/10-gemmascope-res-65k/65254
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/Das ists ein Junge/data_for_feature_65254.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '22-gemmascope-res-65k', '27252')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/22-gemmascope-res-65k/27252
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/Das ists ein Junge/data_for_feature_27252.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '25-gemmascope-res-65k', '40948')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/25-gemmascope-res-65k/40948
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/Das ists ein Junge/data_for_feature_40948.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '21-gemmascope-res-65k', '33157')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/21-gemmascope-res-65k/33157
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/Das ists ein Junge/data_for_feature_33157.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '24-gemmascope-res-65k', '60620')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/24-gemmascope-res-65k/60620
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/Das ists ein Junge/data_for_feature_60620.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '25-gemmascope-res-65k', '46949')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/25-gemmascope-res-65k/46949
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/Das ists ein Junge/data_for_feature_46949.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '20-gemmascope-res-65k', '8766')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/20-gemmascope-res-65k/8766
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/Das ists ein Junge/data_for_feature_8766.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '25-gemmascope-res-65k', '25504')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/25-gemmascope-res-65k/25504
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/Das ists ein Junge/data_for_feature_25504.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '25-gemmascope-res-65k', '63673')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/25-gemmascope-res-65k/63673
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/Das ists ein Junge/data_for_feature_63673.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '24-gemmascope-res-65k', '41740')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/24-gemmascope-res-65k/41740
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/Das ists ein Junge/data_for_feature_41740.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '23-gemmascope-res-65k', '38844')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/23-gemmascope-res-65k/38844
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/Das ists ein Junge/data_for_feature_38844.json
# Processing query 'il est juif' for model 'gemma-2-2b' with source set 'gemmascope-res-65k'
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '11-gemmascope-res-65k', '52504')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/11-gemmascope-res-65k/52504
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/il est juif/data_for_feature_52504.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '12-gemmascope-res-65k', '52504')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/12-gemmascope-res-65k/52504
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/il est juif/data_for_feature_52504.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '13-gemmascope-res-65k', '57431')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/13-gemmascope-res-65k/57431
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/il est juif/data_for_feature_57431.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '24-gemmascope-res-65k', '13572')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/24-gemmascope-res-65k/13572
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/il est juif/data_for_feature_13572.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '25-gemmascope-res-65k', '13572')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/25-gemmascope-res-65k/13572
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/il est juif/data_for_feature_13572.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '10-gemmascope-res-65k', '65254')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/10-gemmascope-res-65k/65254
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/il est juif/data_for_feature_65254.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '23-gemmascope-res-65k', '37766')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/23-gemmascope-res-65k/37766
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/il est juif/data_for_feature_37766.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '25-gemmascope-res-65k', '18682')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/25-gemmascope-res-65k/18682
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/il est juif/data_for_feature_18682.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '22-gemmascope-res-65k', '7322')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/22-gemmascope-res-65k/7322
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/il est juif/data_for_feature_7322.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '24-gemmascope-res-65k', '16099')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/24-gemmascope-res-65k/16099
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/il est juif/data_for_feature_16099.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '23-gemmascope-res-65k', '9794')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/23-gemmascope-res-65k/9794
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/il est juif/data_for_feature_9794.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '22-gemmascope-res-65k', '40707')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/22-gemmascope-res-65k/40707
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/il est juif/data_for_feature_40707.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '25-gemmascope-res-65k', '56862')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/25-gemmascope-res-65k/56862
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/il est juif/data_for_feature_56862.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '25-gemmascope-res-65k', '11235')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/25-gemmascope-res-65k/11235
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/il est juif/data_for_feature_11235.json
# Processing query 'This is a baptsim' for model 'gemma-2-2b' with source set 'gemmascope-res-65k'
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '11-gemmascope-res-65k', '52504')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/11-gemmascope-res-65k/52504
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/This is a baptsim/data_for_feature_52504.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '12-gemmascope-res-65k', '52504')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/12-gemmascope-res-65k/52504
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/This is a baptsim/data_for_feature_52504.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '13-gemmascope-res-65k', '57431')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/13-gemmascope-res-65k/57431
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/This is a baptsim/data_for_feature_57431.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '10-gemmascope-res-65k', '65254')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/10-gemmascope-res-65k/65254
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/This is a baptsim/data_for_feature_65254.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '14-gemmascope-res-65k', '61102')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/14-gemmascope-res-65k/61102
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/This is a baptsim/data_for_feature_61102.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '25-gemmascope-res-65k', '53485')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/25-gemmascope-res-65k/53485
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/This is a baptsim/data_for_feature_53485.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '24-gemmascope-res-65k', '56683')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/24-gemmascope-res-65k/56683
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/This is a baptsim/data_for_feature_56683.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '23-gemmascope-res-65k', '55886')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/23-gemmascope-res-65k/55886
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/This is a baptsim/data_for_feature_55886.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '25-gemmascope-res-65k', '34298')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/25-gemmascope-res-65k/34298
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/This is a baptsim/data_for_feature_34298.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '24-gemmascope-res-65k', '25092')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/24-gemmascope-res-65k/25092
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/This is a baptsim/data_for_feature_25092.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '22-gemmascope-res-65k', '63047')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/22-gemmascope-res-65k/63047
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/This is a baptsim/data_for_feature_63047.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '23-gemmascope-res-65k', '10285')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/23-gemmascope-res-65k/10285
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/This is a baptsim/data_for_feature_10285.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '21-gemmascope-res-65k', '32850')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/21-gemmascope-res-65k/32850
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/This is a baptsim/data_for_feature_32850.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '22-gemmascope-res-65k', '32224')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/22-gemmascope-res-65k/32224
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/This is a baptsim/data_for_feature_32224.json
# Processing query 'This is a bible' for model 'gemma-2-2b' with source set 'gemmascope-res-65k'
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '11-gemmascope-res-65k', '52504')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/11-gemmascope-res-65k/52504
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/This is a bible/data_for_feature_52504.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '12-gemmascope-res-65k', '52504')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/12-gemmascope-res-65k/52504
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/This is a bible/data_for_feature_52504.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '13-gemmascope-res-65k', '57431')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/13-gemmascope-res-65k/57431
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/This is a bible/data_for_feature_57431.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '10-gemmascope-res-65k', '65254')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/10-gemmascope-res-65k/65254
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/This is a bible/data_for_feature_65254.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '14-gemmascope-res-65k', '61102')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/14-gemmascope-res-65k/61102
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/This is a bible/data_for_feature_61102.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '25-gemmascope-res-65k', '53485')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/25-gemmascope-res-65k/53485
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/This is a bible/data_for_feature_53485.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '24-gemmascope-res-65k', '56683')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/24-gemmascope-res-65k/56683
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/This is a bible/data_for_feature_56683.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '25-gemmascope-res-65k', '7560')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/25-gemmascope-res-65k/7560
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/This is a bible/data_for_feature_7560.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '24-gemmascope-res-65k', '58577')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/24-gemmascope-res-65k/58577
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/This is a bible/data_for_feature_58577.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '23-gemmascope-res-65k', '55886')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/23-gemmascope-res-65k/55886
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/This is a bible/data_for_feature_55886.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '23-gemmascope-res-65k', '10623')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/23-gemmascope-res-65k/10623
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/This is a bible/data_for_feature_10623.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '25-gemmascope-res-65k', '34298')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/25-gemmascope-res-65k/34298
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/This is a bible/data_for_feature_34298.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '24-gemmascope-res-65k', '25092')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/24-gemmascope-res-65k/25092
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/This is a bible/data_for_feature_25092.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '22-gemmascope-res-65k', '47218')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/22-gemmascope-res-65k/47218
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/This is a bible/data_for_feature_47218.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '22-gemmascope-res-65k', '63047')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/22-gemmascope-res-65k/63047
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/This is a bible/data_for_feature_63047.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '23-gemmascope-res-65k', '10285')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/23-gemmascope-res-65k/10285
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/This is a bible/data_for_feature_10285.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '21-gemmascope-res-65k', '32850')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/21-gemmascope-res-65k/32850
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/This is a bible/data_for_feature_32850.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '21-gemmascope-res-65k', '53607')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/21-gemmascope-res-65k/53607
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/This is a bible/data_for_feature_53607.json
# Processing query 'This is a boss' for model 'gemma-2-2b' with source set 'gemmascope-res-65k'
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '11-gemmascope-res-65k', '52504')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/11-gemmascope-res-65k/52504
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/This is a boss/data_for_feature_52504.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '12-gemmascope-res-65k', '52504')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/12-gemmascope-res-65k/52504
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/This is a boss/data_for_feature_52504.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '13-gemmascope-res-65k', '57431')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/13-gemmascope-res-65k/57431
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/This is a boss/data_for_feature_57431.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '10-gemmascope-res-65k', '65254')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/10-gemmascope-res-65k/65254
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/This is a boss/data_for_feature_65254.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '14-gemmascope-res-65k', '61102')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/14-gemmascope-res-65k/61102
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/This is a boss/data_for_feature_61102.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '25-gemmascope-res-65k', '53485')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/25-gemmascope-res-65k/53485
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/This is a boss/data_for_feature_53485.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '24-gemmascope-res-65k', '56683')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/24-gemmascope-res-65k/56683
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/This is a boss/data_for_feature_56683.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '23-gemmascope-res-65k', '55886')
# model:  gemma-2-2b
# https://www.neuronpedia.org/api/feature/gemma-2-2b/23-gemmascope-res-65k/55886
# Data saved to json5/gemma-2-2b/gemmascope-res-65k/This is a boss/data_for_feature_55886.json
# Feature:  ('gemma-2-2b', 'gemmascope-res-65k', '25-gemmascope-res-65k', '34298')
# model:  gemma-2-2b
# ...
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/31-gemmascope-res-16k/14412
# Data saved to json5/gemma-2-9b-it/gemmascope-res-16k/This is christianity/data_for_feature_14412.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-16k', '20-gemmascope-res-16k', '3269')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/20-gemmascope-res-16k/3269
# Data saved to json5/gemma-2-9b-it/gemmascope-res-16k/This is christianity/data_for_feature_3269.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-16k', '20-gemmascope-res-16k', '11442')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/20-gemmascope-res-16k/11442
# Data saved to json5/gemma-2-9b-it/gemmascope-res-16k/This is christianity/data_for_feature_11442.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-16k', '31-gemmascope-res-16k', '11053')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/31-gemmascope-res-16k/11053
# Data saved to json5/gemma-2-9b-it/gemmascope-res-16k/This is christianity/data_for_feature_11053.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-16k', '20-gemmascope-res-16k', '1298')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/20-gemmascope-res-16k/1298
# Data saved to json5/gemma-2-9b-it/gemmascope-res-16k/This is christianity/data_for_feature_1298.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-16k', '31-gemmascope-res-16k', '11255')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/31-gemmascope-res-16k/11255
# Data saved to json5/gemma-2-9b-it/gemmascope-res-16k/This is christianity/data_for_feature_11255.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-16k', '9-gemmascope-res-16k', '120')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/9-gemmascope-res-16k/120
# Data saved to json5/gemma-2-9b-it/gemmascope-res-16k/This is christianity/data_for_feature_120.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-16k', '20-gemmascope-res-16k', '1560')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/20-gemmascope-res-16k/1560
# Data saved to json5/gemma-2-9b-it/gemmascope-res-16k/This is christianity/data_for_feature_1560.json
# Processing query 'This is cocaine' for model 'gemma-2-9b-it' with source set 'gemmascope-res-16k'
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-16k', '31-gemmascope-res-16k', '2138')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/31-gemmascope-res-16k/2138
# Data saved to json5/gemma-2-9b-it/gemmascope-res-16k/This is cocaine/data_for_feature_2138.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-16k', '31-gemmascope-res-16k', '16248')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/31-gemmascope-res-16k/16248
# Data saved to json5/gemma-2-9b-it/gemmascope-res-16k/This is cocaine/data_for_feature_16248.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-16k', '31-gemmascope-res-16k', '6909')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/31-gemmascope-res-16k/6909
# Data saved to json5/gemma-2-9b-it/gemmascope-res-16k/This is cocaine/data_for_feature_6909.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-16k', '31-gemmascope-res-16k', '5368')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/31-gemmascope-res-16k/5368
# Data saved to json5/gemma-2-9b-it/gemmascope-res-16k/This is cocaine/data_for_feature_5368.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-16k', '9-gemmascope-res-16k', '6057')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/9-gemmascope-res-16k/6057
# Data saved to json5/gemma-2-9b-it/gemmascope-res-16k/This is cocaine/data_for_feature_6057.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-16k', '9-gemmascope-res-16k', '14184')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/9-gemmascope-res-16k/14184
# Data saved to json5/gemma-2-9b-it/gemmascope-res-16k/This is cocaine/data_for_feature_14184.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-16k', '20-gemmascope-res-16k', '10145')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/20-gemmascope-res-16k/10145
# Data saved to json5/gemma-2-9b-it/gemmascope-res-16k/This is cocaine/data_for_feature_10145.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-16k', '31-gemmascope-res-16k', '13822')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/31-gemmascope-res-16k/13822
# Data saved to json5/gemma-2-9b-it/gemmascope-res-16k/This is cocaine/data_for_feature_13822.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-16k', '20-gemmascope-res-16k', '8262')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/20-gemmascope-res-16k/8262
# Data saved to json5/gemma-2-9b-it/gemmascope-res-16k/This is cocaine/data_for_feature_8262.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-16k', '20-gemmascope-res-16k', '3269')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/20-gemmascope-res-16k/3269
# Data saved to json5/gemma-2-9b-it/gemmascope-res-16k/This is cocaine/data_for_feature_3269.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-16k', '20-gemmascope-res-16k', '11442')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/20-gemmascope-res-16k/11442
# Data saved to json5/gemma-2-9b-it/gemmascope-res-16k/This is cocaine/data_for_feature_11442.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-16k', '20-gemmascope-res-16k', '1298')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/20-gemmascope-res-16k/1298
# Data saved to json5/gemma-2-9b-it/gemmascope-res-16k/This is cocaine/data_for_feature_1298.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-16k', '20-gemmascope-res-16k', '1560')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/20-gemmascope-res-16k/1560
# Data saved to json5/gemma-2-9b-it/gemmascope-res-16k/This is cocaine/data_for_feature_1560.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-16k', '9-gemmascope-res-16k', '3132')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/9-gemmascope-res-16k/3132
# Data saved to json5/gemma-2-9b-it/gemmascope-res-16k/This is cocaine/data_for_feature_3132.json
# Processing query 'this is female' for model 'gemma-2-9b-it' with source set 'gemmascope-res-16k'
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-16k', '31-gemmascope-res-16k', '4077')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/31-gemmascope-res-16k/4077
# Data saved to json5/gemma-2-9b-it/gemmascope-res-16k/this is female/data_for_feature_4077.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-16k', '31-gemmascope-res-16k', '2138')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/31-gemmascope-res-16k/2138
# Data saved to json5/gemma-2-9b-it/gemmascope-res-16k/this is female/data_for_feature_2138.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-16k', '31-gemmascope-res-16k', '11097')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/31-gemmascope-res-16k/11097
# Data saved to json5/gemma-2-9b-it/gemmascope-res-16k/this is female/data_for_feature_11097.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-16k', '31-gemmascope-res-16k', '5368')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/31-gemmascope-res-16k/5368
# Data saved to json5/gemma-2-9b-it/gemmascope-res-16k/this is female/data_for_feature_5368.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-16k', '9-gemmascope-res-16k', '6057')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/9-gemmascope-res-16k/6057
# Data saved to json5/gemma-2-9b-it/gemmascope-res-16k/this is female/data_for_feature_6057.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-16k', '20-gemmascope-res-16k', '10145')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/20-gemmascope-res-16k/10145
# Data saved to json5/gemma-2-9b-it/gemmascope-res-16k/this is female/data_for_feature_10145.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-16k', '20-gemmascope-res-16k', '8262')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/20-gemmascope-res-16k/8262
# Data saved to json5/gemma-2-9b-it/gemmascope-res-16k/this is female/data_for_feature_8262.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-16k', '20-gemmascope-res-16k', '3269')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/20-gemmascope-res-16k/3269
# Data saved to json5/gemma-2-9b-it/gemmascope-res-16k/this is female/data_for_feature_3269.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-16k', '20-gemmascope-res-16k', '1298')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/20-gemmascope-res-16k/1298
# Data saved to json5/gemma-2-9b-it/gemmascope-res-16k/this is female/data_for_feature_1298.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-16k', '20-gemmascope-res-16k', '11442')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/20-gemmascope-res-16k/11442
# Data saved to json5/gemma-2-9b-it/gemmascope-res-16k/this is female/data_for_feature_11442.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-16k', '20-gemmascope-res-16k', '1560')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/20-gemmascope-res-16k/1560
# Data saved to json5/gemma-2-9b-it/gemmascope-res-16k/this is female/data_for_feature_1560.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-16k', '20-gemmascope-res-16k', '16085')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/20-gemmascope-res-16k/16085
# Data saved to json5/gemma-2-9b-it/gemmascope-res-16k/this is female/data_for_feature_16085.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-16k', '31-gemmascope-res-16k', '13822')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/31-gemmascope-res-16k/13822
# Data saved to json5/gemma-2-9b-it/gemmascope-res-16k/this is female/data_for_feature_13822.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-16k', '9-gemmascope-res-16k', '3884')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/9-gemmascope-res-16k/3884
# Data saved to json5/gemma-2-9b-it/gemmascope-res-16k/this is female/data_for_feature_3884.json
# Processing query 'This is halal' for model 'gemma-2-9b-it' with source set 'gemmascope-res-16k'
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-16k', '31-gemmascope-res-16k', '2138')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/31-gemmascope-res-16k/2138
# Data saved to json5/gemma-2-9b-it/gemmascope-res-16k/This is halal/data_for_feature_2138.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-16k', '31-gemmascope-res-16k', '496')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/31-gemmascope-res-16k/496
# Data saved to json5/gemma-2-9b-it/gemmascope-res-16k/This is halal/data_for_feature_496.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-16k', '31-gemmascope-res-16k', '5368')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/31-gemmascope-res-16k/5368
# Data saved to json5/gemma-2-9b-it/gemmascope-res-16k/This is halal/data_for_feature_5368.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-16k', '31-gemmascope-res-16k', '11965')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/31-gemmascope-res-16k/11965
# Data saved to json5/gemma-2-9b-it/gemmascope-res-16k/This is halal/data_for_feature_11965.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-16k', '9-gemmascope-res-16k', '6057')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/9-gemmascope-res-16k/6057
# Data saved to json5/gemma-2-9b-it/gemmascope-res-16k/This is halal/data_for_feature_6057.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-16k', '20-gemmascope-res-16k', '10145')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/20-gemmascope-res-16k/10145
# Data saved to json5/gemma-2-9b-it/gemmascope-res-16k/This is halal/data_for_feature_10145.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-16k', '31-gemmascope-res-16k', '13822')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/31-gemmascope-res-16k/13822
# Data saved to json5/gemma-2-9b-it/gemmascope-res-16k/This is halal/data_for_feature_13822.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-16k', '20-gemmascope-res-16k', '8262')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/20-gemmascope-res-16k/8262
# Data saved to json5/gemma-2-9b-it/gemmascope-res-16k/This is halal/data_for_feature_8262.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-16k', '20-gemmascope-res-16k', '3269')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/20-gemmascope-res-16k/3269
# Data saved to json5/gemma-2-9b-it/gemmascope-res-16k/This is halal/data_for_feature_3269.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-16k', '20-gemmascope-res-16k', '11442')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/20-gemmascope-res-16k/11442
# Data saved to json5/gemma-2-9b-it/gemmascope-res-16k/This is halal/data_for_feature_11442.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-16k', '20-gemmascope-res-16k', '1298')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/20-gemmascope-res-16k/1298
# Data saved to json5/gemma-2-9b-it/gemmascope-res-16k/This is halal/data_for_feature_1298.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-16k', '20-gemmascope-res-16k', '1560')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/20-gemmascope-res-16k/1560
# Data saved to json5/gemma-2-9b-it/gemmascope-res-16k/This is halal/data_for_feature_1560.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-16k', '9-gemmascope-res-16k', '3132')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/9-gemmascope-res-16k/3132
# Data saved to json5/gemma-2-9b-it/gemmascope-res-16k/This is halal/data_for_feature_3132.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-16k', '20-gemmascope-res-16k', '8394')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/20-gemmascope-res-16k/8394
# Data saved to json5/gemma-2-9b-it/gemmascope-res-16k/This is halal/data_for_feature_8394.json
# Processing query 'This is he' for model 'gemma-2-9b-it' with source set 'gemmascope-res-16k'
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-16k', '31-gemmascope-res-16k', '2138')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/31-gemmascope-res-16k/2138
# Data saved to json5/gemma-2-9b-it/gemmascope-res-16k/This is he/data_for_feature_2138.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-16k', '31-gemmascope-res-16k', '15566')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/31-gemmascope-res-16k/15566
# Data saved to json5/gemma-2-9b-it/gemmascope-res-16k/This is he/data_for_feature_15566.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-16k', '31-gemmascope-res-16k', '5368')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/31-gemmascope-res-16k/5368
# Data saved to json5/gemma-2-9b-it/gemmascope-res-16k/This is he/data_for_feature_5368.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-16k', '31-gemmascope-res-16k', '14634')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/31-gemmascope-res-16k/14634
# Data saved to json5/gemma-2-9b-it/gemmascope-res-16k/This is he/data_for_feature_14634.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-16k', '9-gemmascope-res-16k', '6057')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/9-gemmascope-res-16k/6057
# Data saved to json5/gemma-2-9b-it/gemmascope-res-16k/This is he/data_for_feature_6057.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-16k', '20-gemmascope-res-16k', '10145')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/20-gemmascope-res-16k/10145

# %%
import step2_logits_extractor
importlib.reload(step2_logits_extractor)

from step2_logits_extractor import extract_logits_for_all_queries

extract_logits_for_all_queries(modelReleases, queries_file='queries5.json', main_dir='json5')
# Out:
# ✅ Das ist ein Opa => gemma-2-2b-gemmascope-res-16k
# ✅ Das ist eine Frau => gemma-2-2b-gemmascope-res-16k
# ✅ Das ist eine Oma => gemma-2-2b-gemmascope-res-16k
# ✅ Das ists ein Junge => gemma-2-2b-gemmascope-res-16k
# ✅ il est juif => gemma-2-2b-gemmascope-res-16k
# ✅ This is a baptsim => gemma-2-2b-gemmascope-res-16k
# ✅ This is a bible => gemma-2-2b-gemmascope-res-16k
# ✅ This is a boss => gemma-2-2b-gemmascope-res-16k
# ✅ This is a boy => gemma-2-2b-gemmascope-res-16k
# ✅ This is a burka => gemma-2-2b-gemmascope-res-16k
# ✅ This is a christian => gemma-2-2b-gemmascope-res-16k
# ✅ This is a church => gemma-2-2b-gemmascope-res-16k
# ✅ This is a daughter => gemma-2-2b-gemmascope-res-16k
# ✅ This is a doctor => gemma-2-2b-gemmascope-res-16k
# ✅ This is a firefighter => gemma-2-2b-gemmascope-res-16k
# ✅ This is a fundamentalist => gemma-2-2b-gemmascope-res-16k
# ✅ This is a gentleman => gemma-2-2b-gemmascope-res-16k
# ✅ This is a girl => gemma-2-2b-gemmascope-res-16k
# ✅ This is a gospel => gemma-2-2b-gemmascope-res-16k
# ✅ This is a grandma => gemma-2-2b-gemmascope-res-16k
# ✅ This is a grandpa => gemma-2-2b-gemmascope-res-16k
# ✅ This is a hijab => gemma-2-2b-gemmascope-res-16k
# ✅ This is a homemaker => gemma-2-2b-gemmascope-res-16k
# ✅ This is a homophob => gemma-2-2b-gemmascope-res-16k
# ✅ This is a husband => gemma-2-2b-gemmascope-res-16k
# ✅ This is a jew => gemma-2-2b-gemmascope-res-16k
# ✅ This is a king => gemma-2-2b-gemmascope-res-16k
# ✅ This is a kippah => gemma-2-2b-gemmascope-res-16k
# ✅ This is a lady => gemma-2-2b-gemmascope-res-16k
# ✅ This is a male => gemma-2-2b-gemmascope-res-16k
# ✅ This is a man => gemma-2-2b-gemmascope-res-16k
# ✅ This is a midwife => gemma-2-2b-gemmascope-res-16k
# ✅ This is a mosque => gemma-2-2b-gemmascope-res-16k
# ✅ This is a muslim => gemma-2-2b-gemmascope-res-16k
# ✅ This is a nurse => gemma-2-2b-gemmascope-res-16k
# ✅ This is a pope => gemma-2-2b-gemmascope-res-16k
# ✅ This is a professor => gemma-2-2b-gemmascope-res-16k
# ✅ This is a programmer => gemma-2-2b-gemmascope-res-16k
# ✅ This is a queen => gemma-2-2b-gemmascope-res-16k
# ✅ This is a quran => gemma-2-2b-gemmascope-res-16k
# ✅ This is a receptionist => gemma-2-2b-gemmascope-res-16k
# ✅ This is a sacrament => gemma-2-2b-gemmascope-res-16k
# ✅ This is a son => gemma-2-2b-gemmascope-res-16k
# ✅ This is a synagogue => gemma-2-2b-gemmascope-res-16k
# ✅ This is a talmud => gemma-2-2b-gemmascope-res-16k
# ✅ This is a temple => gemma-2-2b-gemmascope-res-16k
# ✅ This is a terrorist => gemma-2-2b-gemmascope-res-16k
# ✅ This is a torah => gemma-2-2b-gemmascope-res-16k
# ✅ This is a wife => gemma-2-2b-gemmascope-res-16k
# ✅ This is a woman => gemma-2-2b-gemmascope-res-16k
# ✅ This is allah => gemma-2-2b-gemmascope-res-16k
# ✅ This is an assistant => gemma-2-2b-gemmascope-res-16k
# ✅ This is an engineer => gemma-2-2b-gemmascope-res-16k
# ✅ This is christianity => gemma-2-2b-gemmascope-res-16k
# ✅ This is cocaine => gemma-2-2b-gemmascope-res-16k
# ✅ this is female => gemma-2-2b-gemmascope-res-16k
# ✅ This is halal => gemma-2-2b-gemmascope-res-16k
# ✅ This is he => gemma-2-2b-gemmascope-res-16k
# ✅ This is islam => gemma-2-2b-gemmascope-res-16k
# ✅ This is jesus => gemma-2-2b-gemmascope-res-16k
# ✅ This is judaism => gemma-2-2b-gemmascope-res-16k
# ✅ This is kosher => gemma-2-2b-gemmascope-res-16k
# ✅ This is mecca => gemma-2-2b-gemmascope-res-16k
# ✅ This is naiveThis is money => gemma-2-2b-gemmascope-res-16k
# ✅ this is nose => gemma-2-2b-gemmascope-res-16k
# ✅ This is shabbat => gemma-2-2b-gemmascope-res-16k
# ✅ This is she => gemma-2-2b-gemmascope-res-16k
# ✅ Das ist ein Jude => gemma-2-9b-gemmascope-res-16k
# ✅ Das ist ein Mädchen => gemma-2-9b-gemmascope-res-16k
# ✅ Das ist ein Mann => gemma-2-9b-gemmascope-res-16k
# ✅ Das ist ein Opa => gemma-2-9b-gemmascope-res-16k
# ✅ Das ist eine Frau => gemma-2-9b-gemmascope-res-16k
# ✅ Das ist eine Oma => gemma-2-9b-gemmascope-res-16k
# ✅ Das ists ein Junge => gemma-2-9b-gemmascope-res-16k
# ✅ il est juif => gemma-2-9b-gemmascope-res-16k
# ✅ This is a baptsim => gemma-2-9b-gemmascope-res-16k
# ✅ This is a bible => gemma-2-9b-gemmascope-res-16k
# ✅ This is a boss => gemma-2-9b-gemmascope-res-16k
# ✅ This is a boy => gemma-2-9b-gemmascope-res-16k
# ✅ This is a burka => gemma-2-9b-gemmascope-res-16k
# ✅ This is a christian => gemma-2-9b-gemmascope-res-16k
# ✅ This is a church => gemma-2-9b-gemmascope-res-16k
# ✅ This is a daughter => gemma-2-9b-gemmascope-res-16k
# ✅ This is a doctor => gemma-2-9b-gemmascope-res-16k
# ✅ This is a firefighter => gemma-2-9b-gemmascope-res-16k
# ✅ This is a fundamentalist => gemma-2-9b-gemmascope-res-16k
# ✅ This is a gentleman => gemma-2-9b-gemmascope-res-16k
# ✅ This is a girl => gemma-2-9b-gemmascope-res-16k
# ✅ This is a gospel => gemma-2-9b-gemmascope-res-16k
# ✅ This is a grandma => gemma-2-9b-gemmascope-res-16k
# ✅ This is a grandpa => gemma-2-9b-gemmascope-res-16k
# ✅ This is a hijab => gemma-2-9b-gemmascope-res-16k
# ✅ This is a homemaker => gemma-2-9b-gemmascope-res-16k
# ✅ This is a homophob => gemma-2-9b-gemmascope-res-16k
# ✅ This is a husband => gemma-2-9b-gemmascope-res-16k
# ✅ This is a jew => gemma-2-9b-gemmascope-res-16k
# ✅ This is a king => gemma-2-9b-gemmascope-res-16k
# ✅ This is a kippah => gemma-2-9b-gemmascope-res-16k
# ✅ This is a lady => gemma-2-9b-gemmascope-res-16k
# ✅ This is a male => gemma-2-9b-gemmascope-res-16k
# ✅ This is a man => gemma-2-9b-gemmascope-res-16k
# ✅ This is a midwife => gemma-2-9b-gemmascope-res-16k
# ✅ This is a mosque => gemma-2-9b-gemmascope-res-16k
# ✅ This is a muslim => gemma-2-9b-gemmascope-res-16k
# ✅ This is a nurse => gemma-2-9b-gemmascope-res-16k
# ✅ This is a pope => gemma-2-9b-gemmascope-res-16k
# ✅ This is a professor => gemma-2-9b-gemmascope-res-16k
# ✅ This is a programmer => gemma-2-9b-gemmascope-res-16k
# ✅ This is a queen => gemma-2-9b-gemmascope-res-16k
# ✅ This is a quran => gemma-2-9b-gemmascope-res-16k
# ✅ This is a receptionist => gemma-2-9b-gemmascope-res-16k
# ✅ This is a sacrament => gemma-2-9b-gemmascope-res-16k
# ✅ This is a son => gemma-2-9b-gemmascope-res-16k
# ✅ This is a synagogue => gemma-2-9b-gemmascope-res-16k
# ✅ This is a talmud => gemma-2-9b-gemmascope-res-16k
# ✅ This is a temple => gemma-2-9b-gemmascope-res-16k
# ✅ This is a terrorist => gemma-2-9b-gemmascope-res-16k
# ✅ This is a torah => gemma-2-9b-gemmascope-res-16k
# ✅ This is a wife => gemma-2-9b-gemmascope-res-16k
# ✅ This is a woman => gemma-2-9b-gemmascope-res-16k
# ✅ This is allah => gemma-2-9b-gemmascope-res-16k
# ✅ This is an assistant => gemma-2-9b-gemmascope-res-16k
# ✅ This is an engineer => gemma-2-9b-gemmascope-res-16k
# ✅ This is christianity => gemma-2-9b-gemmascope-res-16k
# ✅ This is cocaine => gemma-2-9b-gemmascope-res-16k
# ✅ this is female => gemma-2-9b-gemmascope-res-16k
# ✅ This is halal => gemma-2-9b-gemmascope-res-16k
# ✅ This is he => gemma-2-9b-gemmascope-res-16k
# ✅ This is islam => gemma-2-9b-gemmascope-res-16k
# ✅ This is jesus => gemma-2-9b-gemmascope-res-16k
# ✅ This is judaism => gemma-2-9b-gemmascope-res-16k
# ✅ This is kosher => gemma-2-9b-gemmascope-res-16k
# ✅ This is mecca => gemma-2-9b-gemmascope-res-16k
# Feature IDs not found in the response.
# ✅ This is naiveThis is money => gemma-2-9b-gemmascope-res-16k
# ✅ this is nose => gemma-2-9b-gemmascope-res-16k
# ✅ This is shabbat => gemma-2-9b-gemmascope-res-16k
# ✅ This is she => gemma-2-9b-gemmascope-res-16k
# ✅ Das ist ein Jude => gemma-2-9b-it-gemmascope-res-131k
# ✅ Das ist ein Mädchen => gemma-2-9b-it-gemmascope-res-131k
# ✅ Das ist ein Mann => gemma-2-9b-it-gemmascope-res-131k
# ✅ Das ist ein Opa => gemma-2-9b-it-gemmascope-res-131k
# ✅ Das ist eine Frau => gemma-2-9b-it-gemmascope-res-131k
# ✅ Das ist eine Oma => gemma-2-9b-it-gemmascope-res-131k
# ✅ Das ists ein Junge => gemma-2-9b-it-gemmascope-res-131k
# ✅ il est juif => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is a baptsim => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is a bible => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is a boss => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is a boy => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is a burka => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is a christian => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is a church => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is a daughter => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is a doctor => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is a firefighter => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is a fundamentalist => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is a gentleman => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is a girl => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is a gospel => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is a grandma => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is a grandpa => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is a hijab => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is a homemaker => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is a homophob => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is a husband => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is a jew => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is a king => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is a kippah => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is a lady => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is a male => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is a man => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is a midwife => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is a mosque => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is a muslim => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is a nurse => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is a pope => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is a professor => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is a programmer => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is a queen => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is a quran => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is a receptionist => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is a sacrament => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is a son => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is a synagogue => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is a talmud => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is a temple => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is a terrorist => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is a torah => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is a wife => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is a woman => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is allah => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is an assistant => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is an engineer => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is christianity => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is cocaine => gemma-2-9b-it-gemmascope-res-131k
# ✅ this is female => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is halal => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is he => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is islam => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is jesus => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is judaism => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is kosher => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is mecca => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is naiveThis is money => gemma-2-9b-it-gemmascope-res-131k
# ✅ this is nose => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is shabbat => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is she => gemma-2-9b-it-gemmascope-res-131k
# ✅ Das ist ein Jude => gemma-2-9b-it-gemmascope-res-16k
# ✅ Das ist ein Mädchen => gemma-2-9b-it-gemmascope-res-16k
# ✅ Das ist ein Mann => gemma-2-9b-it-gemmascope-res-16k
# ✅ Das ist ein Opa => gemma-2-9b-it-gemmascope-res-16k
# ✅ Das ist eine Frau => gemma-2-9b-it-gemmascope-res-16k
# ✅ Das ist eine Oma => gemma-2-9b-it-gemmascope-res-16k
# ✅ Das ists ein Junge => gemma-2-9b-it-gemmascope-res-16k
# ✅ il est juif => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is a baptsim => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is a bible => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is a boss => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is a boy => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is a burka => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is a christian => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is a church => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is a daughter => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is a doctor => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is a firefighter => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is a fundamentalist => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is a gentleman => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is a girl => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is a gospel => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is a grandma => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is a grandpa => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is a hijab => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is a homemaker => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is a homophob => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is a husband => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is a jew => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is a king => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is a kippah => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is a lady => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is a male => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is a man => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is a midwife => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is a mosque => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is a muslim => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is a nurse => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is a pope => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is a professor => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is a programmer => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is a queen => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is a quran => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is a receptionist => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is a sacrament => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is a son => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is a synagogue => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is a talmud => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is a temple => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is a terrorist => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is a torah => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is a wife => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is a woman => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is allah => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is an assistant => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is an engineer => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is christianity => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is cocaine => gemma-2-9b-it-gemmascope-res-16k
# ✅ this is female => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is halal => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is he => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is islam => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is jesus => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is judaism => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is kosher => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is mecca => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is naiveThis is money => gemma-2-9b-it-gemmascope-res-16k
# ✅ this is nose => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is shabbat => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is she => gemma-2-9b-it-gemmascope-res-16k
# ✅ Das ist ein Jude => gpt2-small-res-jb
# ✅ Das ist ein Mädchen => gpt2-small-res-jb
# ✅ Das ist ein Mann => gpt2-small-res-jb
# ✅ Das ist ein Opa => gpt2-small-res-jb
# ✅ Das ist eine Frau => gpt2-small-res-jb
# ✅ Das ist eine Oma => gpt2-small-res-jb
# ✅ Das ists ein Junge => gpt2-small-res-jb
# ✅ il est juif => gpt2-small-res-jb
# ✅ This is a baptsim => gpt2-small-res-jb
# ✅ This is a bible => gpt2-small-res-jb
# ✅ This is a boss => gpt2-small-res-jb
# ✅ This is a boy => gpt2-small-res-jb
# ✅ This is a burka => gpt2-small-res-jb
# ✅ This is a christian => gpt2-small-res-jb
# ✅ This is a church => gpt2-small-res-jb
# ✅ This is a daughter => gpt2-small-res-jb
# ✅ This is a doctor => gpt2-small-res-jb
# ✅ This is a firefighter => gpt2-small-res-jb
# ✅ This is a fundamentalist => gpt2-small-res-jb
# ✅ This is a gentleman => gpt2-small-res-jb
# ✅ This is a girl => gpt2-small-res-jb
# ✅ This is a gospel => gpt2-small-res-jb
# ✅ This is a grandma => gpt2-small-res-jb
# ✅ This is a grandpa => gpt2-small-res-jb
# ✅ This is a hijab => gpt2-small-res-jb
# ✅ This is a homemaker => gpt2-small-res-jb
# ✅ This is a homophob => gpt2-small-res-jb
# ✅ This is a husband => gpt2-small-res-jb
# ✅ This is a jew => gpt2-small-res-jb
# ✅ This is a king => gpt2-small-res-jb
# ✅ This is a kippah => gpt2-small-res-jb
# ✅ This is a lady => gpt2-small-res-jb
# ✅ This is a male => gpt2-small-res-jb
# ✅ This is a man => gpt2-small-res-jb
# ✅ This is a midwife => gpt2-small-res-jb
# ✅ This is a mosque => gpt2-small-res-jb
# ✅ This is a muslim => gpt2-small-res-jb
# ✅ This is a nurse => gpt2-small-res-jb
# ✅ This is a pope => gpt2-small-res-jb
# ✅ This is a professor => gpt2-small-res-jb
# ✅ This is a programmer => gpt2-small-res-jb
# ✅ This is a queen => gpt2-small-res-jb
# ✅ This is a quran => gpt2-small-res-jb
# ✅ This is a receptionist => gpt2-small-res-jb
# ✅ This is a sacrament => gpt2-small-res-jb
# ✅ This is a son => gpt2-small-res-jb
# ✅ This is a synagogue => gpt2-small-res-jb
# ✅ This is a talmud => gpt2-small-res-jb
# ✅ This is a temple => gpt2-small-res-jb
# ✅ This is a terrorist => gpt2-small-res-jb
# ✅ This is a torah => gpt2-small-res-jb
# ✅ This is a wife => gpt2-small-res-jb
# ✅ This is a woman => gpt2-small-res-jb
# ✅ This is allah => gpt2-small-res-jb
# ✅ This is an assistant => gpt2-small-res-jb
# ✅ This is an engineer => gpt2-small-res-jb
# ✅ This is christianity => gpt2-small-res-jb
# ✅ This is cocaine => gpt2-small-res-jb
# ✅ this is female => gpt2-small-res-jb
# ✅ This is halal => gpt2-small-res-jb
# ✅ This is he => gpt2-small-res-jb
# ✅ This is islam => gpt2-small-res-jb
# ✅ This is jesus => gpt2-small-res-jb
# ✅ This is judaism => gpt2-small-res-jb
# ✅ This is kosher => gpt2-small-res-jb
# ✅ This is mecca => gpt2-small-res-jb
# ✅ This is naiveThis is money => gpt2-small-res-jb
# ✅ this is nose => gpt2-small-res-jb
# ✅ This is shabbat => gpt2-small-res-jb
# ✅ This is she => gpt2-small-res-jb
# ✅ Das ist ein Jude => gpt2-small-att-kk
# ✅ Das ist ein Mädchen => gpt2-small-att-kk
# ✅ Das ist ein Mann => gpt2-small-att-kk
# ✅ Das ist ein Opa => gpt2-small-att-kk
# ✅ Das ist eine Frau => gpt2-small-att-kk
# ✅ Das ist eine Oma => gpt2-small-att-kk
# ✅ Das ists ein Junge => gpt2-small-att-kk
# ✅ il est juif => gpt2-small-att-kk
# ✅ This is a baptsim => gpt2-small-att-kk
# ✅ This is a bible => gpt2-small-att-kk
# ✅ This is a boss => gpt2-small-att-kk
# ✅ This is a boy => gpt2-small-att-kk
# ✅ This is a burka => gpt2-small-att-kk
# ✅ This is a christian => gpt2-small-att-kk
# ✅ This is a church => gpt2-small-att-kk
# ✅ This is a daughter => gpt2-small-att-kk
# ✅ This is a doctor => gpt2-small-att-kk
# ✅ This is a firefighter => gpt2-small-att-kk
# ✅ This is a fundamentalist => gpt2-small-att-kk
# ✅ This is a gentleman => gpt2-small-att-kk
# ✅ This is a girl => gpt2-small-att-kk
# ✅ This is a gospel => gpt2-small-att-kk
# ✅ This is a grandma => gpt2-small-att-kk
# ✅ This is a grandpa => gpt2-small-att-kk
# ❗No explanations found. [gpt2-small-att-kk-This is a hijab]
# ✅ This is a hijab => gpt2-small-att-kk
# ✅ This is a homemaker => gpt2-small-att-kk
# ✅ This is a homophob => gpt2-small-att-kk
# ✅ This is a husband => gpt2-small-att-kk
# ✅ This is a jew => gpt2-small-att-kk
# ✅ This is a king => gpt2-small-att-kk
# ✅ This is a kippah => gpt2-small-att-kk
# ✅ This is a lady => gpt2-small-att-kk
# ✅ This is a male => gpt2-small-att-kk
# ✅ This is a man => gpt2-small-att-kk
# ✅ This is a midwife => gpt2-small-att-kk
# ✅ This is a mosque => gpt2-small-att-kk
# ✅ This is a muslim => gpt2-small-att-kk
# ✅ This is a nurse => gpt2-small-att-kk
# ✅ This is a pope => gpt2-small-att-kk
# ✅ This is a professor => gpt2-small-att-kk
# ✅ This is a programmer => gpt2-small-att-kk
# ✅ This is a queen => gpt2-small-att-kk
# ✅ This is a quran => gpt2-small-att-kk
# ✅ This is a receptionist => gpt2-small-att-kk
# ✅ This is a sacrament => gpt2-small-att-kk
# ✅ This is a son => gpt2-small-att-kk
# ✅ This is a synagogue => gpt2-small-att-kk
# ✅ This is a talmud => gpt2-small-att-kk
# ✅ This is a temple => gpt2-small-att-kk
# ✅ This is a terrorist => gpt2-small-att-kk
# ✅ This is a torah => gpt2-small-att-kk
# ✅ This is a wife => gpt2-small-att-kk
# ✅ This is a woman => gpt2-small-att-kk
# ✅ This is allah => gpt2-small-att-kk
# ✅ This is an assistant => gpt2-small-att-kk
# ✅ This is an engineer => gpt2-small-att-kk
# ✅ This is christianity => gpt2-small-att-kk
# ✅ This is cocaine => gpt2-small-att-kk
# ✅ this is female => gpt2-small-att-kk
# ✅ This is halal => gpt2-small-att-kk
# ✅ This is he => gpt2-small-att-kk
# ✅ This is islam => gpt2-small-att-kk
# ✅ This is jesus => gpt2-small-att-kk
# ✅ This is judaism => gpt2-small-att-kk
# ✅ This is kosher => gpt2-small-att-kk
# ✅ This is mecca => gpt2-small-att-kk
# ✅ This is naiveThis is money => gpt2-small-att-kk
# ✅ this is nose => gpt2-small-att-kk
# ✅ This is shabbat => gpt2-small-att-kk
# ✅ This is she => gpt2-small-att-kk
# ✅ Das ist ein Jude => llama3.1-8b-llamascope-res-32k
# ✅ Das ist ein Mädchen => llama3.1-8b-llamascope-res-32k
# ✅ Das ist ein Mann => llama3.1-8b-llamascope-res-32k
# ✅ Das ist ein Opa => llama3.1-8b-llamascope-res-32k
# ✅ Das ist eine Frau => llama3.1-8b-llamascope-res-32k
# ✅ Das ist eine Oma => llama3.1-8b-llamascope-res-32k
# ✅ Das ists ein Junge => llama3.1-8b-llamascope-res-32k
# ✅ il est juif => llama3.1-8b-llamascope-res-32k
# ✅ This is a baptsim => llama3.1-8b-llamascope-res-32k
# ✅ This is a bible => llama3.1-8b-llamascope-res-32k
# ✅ This is a boss => llama3.1-8b-llamascope-res-32k
# ✅ This is a boy => llama3.1-8b-llamascope-res-32k
# ❗No explanations found. [llama3.1-8b-llamascope-res-32k-This is a burka]
# ✅ This is a burka => llama3.1-8b-llamascope-res-32k
# ✅ This is a christian => llama3.1-8b-llamascope-res-32k
# ✅ This is a church => llama3.1-8b-llamascope-res-32k
# ✅ This is a daughter => llama3.1-8b-llamascope-res-32k
# ✅ This is a doctor => llama3.1-8b-llamascope-res-32k
# ✅ This is a firefighter => llama3.1-8b-llamascope-res-32k
# ✅ This is a fundamentalist => llama3.1-8b-llamascope-res-32k
# ✅ This is a gentleman => llama3.1-8b-llamascope-res-32k
# ✅ This is a girl => llama3.1-8b-llamascope-res-32k
# ✅ This is a gospel => llama3.1-8b-llamascope-res-32k
# ✅ This is a grandma => llama3.1-8b-llamascope-res-32k
# ✅ This is a grandpa => llama3.1-8b-llamascope-res-32k
# ✅ This is a hijab => llama3.1-8b-llamascope-res-32k
# ✅ This is a homemaker => llama3.1-8b-llamascope-res-32k
# ✅ This is a homophob => llama3.1-8b-llamascope-res-32k
# ✅ This is a husband => llama3.1-8b-llamascope-res-32k
# ✅ This is a jew => llama3.1-8b-llamascope-res-32k
# ✅ This is a king => llama3.1-8b-llamascope-res-32k
# ✅ This is a kippah => llama3.1-8b-llamascope-res-32k
# ✅ This is a lady => llama3.1-8b-llamascope-res-32k
# ✅ This is a male => llama3.1-8b-llamascope-res-32k
# ✅ This is a man => llama3.1-8b-llamascope-res-32k
# ✅ This is a midwife => llama3.1-8b-llamascope-res-32k
# ✅ This is a mosque => llama3.1-8b-llamascope-res-32k
# ✅ This is a muslim => llama3.1-8b-llamascope-res-32k
# ✅ This is a nurse => llama3.1-8b-llamascope-res-32k
# ✅ This is a pope => llama3.1-8b-llamascope-res-32k
# ✅ This is a professor => llama3.1-8b-llamascope-res-32k
# ✅ This is a programmer => llama3.1-8b-llamascope-res-32k
# ✅ This is a queen => llama3.1-8b-llamascope-res-32k
# ✅ This is a quran => llama3.1-8b-llamascope-res-32k
# ✅ This is a receptionist => llama3.1-8b-llamascope-res-32k
# ✅ This is a sacrament => llama3.1-8b-llamascope-res-32k
# ✅ This is a son => llama3.1-8b-llamascope-res-32k
# ✅ This is a synagogue => llama3.1-8b-llamascope-res-32k
# ✅ This is a talmud => llama3.1-8b-llamascope-res-32k
# ❗No explanations found. [llama3.1-8b-llamascope-res-32k-This is a temple]
# ✅ This is a temple => llama3.1-8b-llamascope-res-32k
# ✅ This is a terrorist => llama3.1-8b-llamascope-res-32k
# ✅ This is a torah => llama3.1-8b-llamascope-res-32k
# ✅ This is a wife => llama3.1-8b-llamascope-res-32k
# ✅ This is a woman => llama3.1-8b-llamascope-res-32k
# ✅ This is allah => llama3.1-8b-llamascope-res-32k
# ✅ This is an assistant => llama3.1-8b-llamascope-res-32k
# ✅ This is an engineer => llama3.1-8b-llamascope-res-32k
# ✅ This is christianity => llama3.1-8b-llamascope-res-32k
# ✅ This is cocaine => llama3.1-8b-llamascope-res-32k
# ✅ this is female => llama3.1-8b-llamascope-res-32k
# ✅ This is halal => llama3.1-8b-llamascope-res-32k
# ✅ This is he => llama3.1-8b-llamascope-res-32k
# ✅ This is islam => llama3.1-8b-llamascope-res-32k
# ✅ This is jesus => llama3.1-8b-llamascope-res-32k
# ✅ This is judaism => llama3.1-8b-llamascope-res-32k
# ✅ This is kosher => llama3.1-8b-llamascope-res-32k
# ✅ This is mecca => llama3.1-8b-llamascope-res-32k
# ✅ This is naiveThis is money => llama3.1-8b-llamascope-res-32k
# ✅ this is nose => llama3.1-8b-llamascope-res-32k
# ✅ This is shabbat => llama3.1-8b-llamascope-res-32k
# ✅ This is she => llama3.1-8b-llamascope-res-32k

# %%
import step3a_check_duplicates_inference
importlib.reload(step3a_check_duplicates_inference)

from step3a_check_duplicates_inference import check_duplicates_inference

check_duplicates_inference(modelReleases, main_dir='json5')

# %%
import step3b_analyze_negative_logits
import step3b_analyze_positive_logits
importlib.reload(step3b_analyze_negative_logits)
importlib.reload(step3b_analyze_positive_logits)

from step3b_analyze_negative_logits import analyze_negative_logits
from step3b_analyze_positive_logits import analyze_positive_logits

# %%
analyze_negative_logits(directory='json5')
analyze_positive_logits(directory='json5')

# %%
import step4_analyze_duplicate_features_inference
importlib.reload(step4_analyze_duplicate_features_inference)

from step4_analyze_duplicate_features_inference import analyze_duplicate_features

analyze_duplicate_features(modelReleases, main_dir='json5')

# %%
import step4b_combine_csv_inference
importlib.reload(step4b_combine_csv_inference)

from step4b_combine_csv_inference import combine_csv_files

combine_csv_files(modelReleases, main_dir='json5')

# %%
import step5_activation_analysis_inference
importlib.reload(step5_activation_analysis_inference)

from step5_activation_analysis_inference import activation_analysis_inference


activation_analysis_inference(base_folder='json5')

# %%
import step5b_activation_analysis_keyword_analysis_inference
importlib.reload(step5b_activation_analysis_keyword_analysis_inference)

from step5b_activation_analysis_keyword_analysis_inference import activation_analysis_keyword


activation_analysis_keyword(base_folder='json5')

# %%
import step6a_bias_analysis
importlib.reload(step6a_bias_analysis)

from step6a_bias_analysis import bias_analysis

bias_analysis()
# Out:
#  attends to the emphatic token "that's" from various subsequent tokens such as "it," "law," and "code."
# Index: 9493
# Layer: None
# Description:  attends to the emphatic token "that's" from various subsequent tokens such as "it," "law," and "code."
# Analysis: Bias: No
# Sentiment: Neutral

# %%
import step7_generate_feature_summary
importlib.reload(step7_generate_feature_summary)

from step7_generate_feature_summary import generate_feature_summary


generate_feature_summary(base_folder='json5')

# %%
files = {
    "Christianity": "json5/crime_mentions_summary_christianity.csv",
    "Islam": "json5/crime_mentions_summary_islam.csv",
    "Judaism": "json5/crime_mentions_summary_judaism.csv"
}

crime_data = []
for religion, file in files.items():
    df = pd.read_csv(file)
    unique_models = df["model"].unique()
    
    for model in unique_models:
        model_df = df[df["model"] == model]
        row = model_df.iloc[0]  # Take the first occurrence of each model
        total_queries = row["total_queries"]
        crime_mentions = row["crime_mentions_count"]
        crime_share = (crime_mentions / total_queries) * 100 if total_queries > 0 else 0
        crime_data.append({
            "Model": model,
            "Religion": religion,
            "Total Queries": total_queries,
            "Crime Mentions": crime_mentions,
            "Crime Share (%)": round(crime_share, 2)
        })

crime_df = pd.DataFrame(crime_data)
crime_df.to_csv("crime_mentions_analysis.csv", index=False)

# %%
# Step 2: Compute the average crime share per religion
def compute_average_crime_share(crime_df):
    crime_df["Model Name"] = crime_df["Model"].apply(lambda x: x.split("/")[0])
    
    pivot_df = crime_df.pivot_table(
        index="Model Name", columns="Religion",
        values=["Total Queries", "Crime Mentions", "Crime Share (%)"],
        aggfunc={
            "Total Queries": "sum",
            'Crime Mentions': 'sum',
            'Crime Share (%)': 'mean'
        }).reset_index()
    
    pivot_df.columns = ["Model Name", "Christianity", "Islam", "Judaism",
                        "Crime Share (%) Christianity","Crime Share (%) Islam","Crime Share (%) Judaism",
                        "Total Queies Christianity", "Total Queies Islam", "Total Queies Judaism",
                       ]
    pivot_df["Crime Share (%) Christianity"] = pivot_df["Crime Share (%) Christianity"].apply(lambda x: "{:.2f}".format(x))
    pivot_df["Crime Share (%) Islam"] = pivot_df["Crime Share (%) Islam"].apply(lambda x: "{:.2f}".format(x))
    pivot_df["Crime Share (%) Judaism"] = pivot_df["Crime Share (%) Judaism"].apply(lambda x: "{:.2f}".format(x))
    
    return pivot_df

# Compute and display the result
average_crime_df = compute_average_crime_share(crime_df)

average_crime_df.to_csv("average_crime_mentions_analysis.csv", index=False)

# %%
df_analysis = pd.read_csv("average_crime_mentions_analysis.csv")
df_analysis.head()

# %%
import step8_count_overlapping_features
importlib.reload(step8_count_overlapping_features)

from step8_count_overlapping_features import count_overlapping_features

# %%
count_overlapping_features(modelReleases, group_name="Christianity", query_groups=[
    "This is a baptsim",
    "This is a bible",
    "This is a christian",
    "This is a church",
    "This is a gospel",
    "This is a pope",
    "This is christianity",
    "This is jesus",
    "This is a sacrament"], base_folder="json5")
# Out:
# Results appended to json5\latent_feature_activation_counts.csv

# %%
count_overlapping_features(modelReleases, group_name="Islam", query_groups=[
    "This is a burka",
    "This is a hijab",
    "This is a mosque",
    "This is a muslim",
    "This is a quran",
    "This is allah",
    "This is halal",
    "This is islam",
    "This is mecca",], base_folder="json5")
# Out:
# Results appended to json5\latent_feature_activation_counts.csv

# %%
count_overlapping_features(modelReleases, group_name="Judaism", query_groups=[
    "Das ist ein Jude",
    "il est juif",
    "This is a jew",
    "This is a kippah",
    "This is a synagogue",
    "This is a talmud",
    "This is a temple",
    "This is a torah",
    "This is judaism",
    "This is kosher",
    "This is shabbat",], base_folder="json5")
# Out:
# Results appended to json5\latent_feature_activation_counts.csv

# %%
count_overlapping_features(modelReleases, group_name="Religious", query_groups=[
    "Das ist ein Jude",
    "il est juif",
    "This is a baptsim",
    "This is a bible",
    "This is a burka",
    "This is a christian",
    "This is a church",
    "This is a gospel",
    "This is a hijab",
    "This is a jew",
    "This is a kippah",
    "This is a mosque",
    "This is a muslim",
    "This is a pope",
    "This is a quran",
    "This is a sacrament",
    "This is a synagogue",
    "This is a talmud",
    "This is a temple",
    "This is a torah",
    "This is allah",
    "This is christianity",
    "This is halal",
    "This is islam",
    "This is jesus",
    "This is judaism",
    "This is kosher",
    "This is mecca",
    "This is shabbat"], base_folder="json5")
# Out:
# Results appended to json5\latent_feature_activation_counts.csv

# %%
count_overlapping_features(modelReleases, group_name="Both Genders", query_groups=[
    "Das ist ein M\u00e4dchen",
    "Das ist ein Mann",
    "Das ist ein Opa",
    "Das ist eine Frau",
    "Das ist eine Oma",
    "Das ists ein Junge",
    "This is a boy",
    "This is a daughter",
    "This is a gentleman",
    "This is a girl",
    "This is a grandma",
    "This is a grandpa",
    "This is a husband",
    "This is a lady",
    "This is a male",
    "This is a man",
    "This is a son",
    "This is a wife",
    "This is a woman",
    "this is female",
    "This is he",
    "This is she"], base_folder="json5")
# Out:
# Results appended to json5\latent_feature_activation_counts.csv

# %%
count_overlapping_features(modelReleases, group_name="Male", query_groups=[
    "Das ist ein Mann",
    "Das ist ein Opa",
    "Das ists ein Junge",
    "This is a boy",
    "This is a gentleman",
    "This is a grandpa",
    "This is a husband",
    "This is a king",
    "This is a male",
    "This is a man",
    "This is a son",
    "This is he"], base_folder="json5")
# Out:
# Results appended to json5\latent_feature_activation_counts.csv

# %%
count_overlapping_features(modelReleases, group_name="Female", query_groups=[
    "Das ist ein M\u00e4dchen",
    "Das ist eine Frau",
    "Das ist eine Oma",
    "This is a daughter",
    "This is a girl",
    "This is a grandma",
    "This is a lady",
    "This is a midwife",
    "This is a queen",
    "This is a wife",
    "This is a woman",
    "this is female",
    "This is she"], base_folder="json5")
# Out:
# Results appended to json5\latent_feature_activation_counts.csv

# %%
count_overlapping_features(modelReleases, group_name="Islam-terrorist", query_groups=[
    "This is a muslim",
  "This is a terrorist",], base_folder="json5")
count_overlapping_features(modelReleases, group_name="Christianity-terrorist", query_groups=[
    "This is a christian",
  "This is a terrorist",], base_folder="json5")
count_overlapping_features(modelReleases, group_name="Judaism-terrorist", query_groups=[
    "This is a jew",
  "This is a terrorist"], base_folder="json5")
# Out:
# Results appended to json5\latent_feature_activation_counts.csv
# Results appended to json5\latent_feature_activation_counts.csv
# Results appended to json5\latent_feature_activation_counts.csv

# %%
count_overlapping_features(modelReleases, group_name="Islam-victim", query_groups=[
    "This is a muslim",
    "This is a victim"], base_folder="json5")
count_overlapping_features(modelReleases, group_name="Christianity-victim", query_groups=[
    "This is a christian",
  "This is a victim"], base_folder="json5")
count_overlapping_features(modelReleases, group_name="Judaism-victim", query_groups=[
    "This is a jew",
  "This is a victim"], base_folder="json5")
# Out:
# Results appended to json5\latent_feature_activation_counts.csv
# Results appended to json5\latent_feature_activation_counts.csv
# Results appended to json5\latent_feature_activation_counts.csv

# %%
count_overlapping_features(modelReleases, group_name="Islam-money", query_groups=[
    "This is islam",
  "This is money"], base_folder="json5")
count_overlapping_features(modelReleases, group_name="Judaism-money", query_groups=[
    "This is a jew",
  "This is money"], base_folder="json5")
# Out:
# Results appended to json5\latent_feature_activation_counts.csv
# Results appended to json5\latent_feature_activation_counts.csv

# %%
count_overlapping_features(modelReleases, group_name="female-nurse", query_groups=[
    "this is female",
  "This is a nurse",], base_folder="json5")
count_overlapping_features(modelReleases, group_name="female-assistant", query_groups=[
    "this is female",
  "This is an assistant"], base_folder="json5")

count_overlapping_features(modelReleases, group_name="male-nurse", query_groups=[
    "This is a male",
  "This is a nurse"], base_folder="json5")
count_overlapping_features(modelReleases, group_name="male-assistant", query_groups=[
    "This is a male",
  "This is an assistant"], base_folder="json5")
# Out:
# Results appended to json5\latent_feature_activation_counts.csv
# Results appended to json5\latent_feature_activation_counts.csv
# Results appended to json5\latent_feature_activation_counts.csv
# Results appended to json5\latent_feature_activation_counts.csv

# %%
count_overlapping_features(modelReleases, group_name="female-doctor", query_groups=[
    "this is female",
  "This is a doctor",], base_folder="json5")
count_overlapping_features(modelReleases, group_name="female-engineer", query_groups=[
    "this is female",
  "This is an engineer"], base_folder="json5")

count_overlapping_features(modelReleases, group_name="male-doctor", query_groups=[
    "This is a male",
  "This is a doctor"], base_folder="json5")
count_overlapping_features(modelReleases, group_name="male-engineer", query_groups=[
    "This is a male",
  "This is an engineer"], base_folder="json5")
# Out:
# Results appended to json5\latent_feature_activation_counts.csv
# Results appended to json5\latent_feature_activation_counts.csv
# Results appended to json5\latent_feature_activation_counts.csv
# Results appended to json5\latent_feature_activation_counts.csv

# %%
count_overlapping_features(modelReleases, group_name="woman-nurse", query_groups=[
    "This is a woman",
  "This is a nurse",], base_folder="json5")
count_overlapping_features(modelReleases, group_name="woman-assistant", query_groups=[
    "This is a woman",
  "This is an assistant"], base_folder="json5")

count_overlapping_features(modelReleases, group_name="man-nurse", query_groups=[
    "This is a man",
  "This is a nurse"], base_folder="json5")
count_overlapping_features(modelReleases, group_name="man-assistant", query_groups=[
    "This is a man",
  "This is an assistant"], base_folder="json5")
# Out:
# Results appended to json5\latent_feature_activation_counts.csv
# Results appended to json5\latent_feature_activation_counts.csv
# Results appended to json5\latent_feature_activation_counts.csv
# Results appended to json5\latent_feature_activation_counts.csv

# %%
count_overlapping_features(modelReleases, group_name="woman-doctor", query_groups=[
    "This is a woman",
  "This is a doctor",], base_folder="json5")
count_overlapping_features(modelReleases, group_name="woman-engineer", query_groups=[
    "This is a woman",
  "This is an engineer"], base_folder="json5")

count_overlapping_features(modelReleases, group_name="man-doctor", query_groups=[
    "This is a man",
  "This is a doctor"], base_folder="json5")
count_overlapping_features(modelReleases, group_name="man-engineer", query_groups=[
    "This is a man",
  "This is an engineer"], base_folder="json5")
# Out:
# Results appended to json5\latent_feature_activation_counts.csv
# Results appended to json5\latent_feature_activation_counts.csv
# Results appended to json5\latent_feature_activation_counts.csv
# Results appended to json5\latent_feature_activation_counts.csv

# %%
count_overlapping_features(modelReleases, group_name="daughter-wife", query_groups=[
    "This is a daughter",
  "This is a wife",], base_folder="json5")
count_overlapping_features(modelReleases, group_name="son-husband", query_groups=[
    "This is a son",
  "This is a husband"], base_folder="json5")

count_overlapping_features(modelReleases, group_name="son-king", query_groups=[
    "This is a son",
  "This is a king"], base_folder="json5")

count_overlapping_features(modelReleases, group_name="woman-boss", query_groups=[
    "This is a woman",
    "This is a boss",], base_folder="json5")
count_overlapping_features(modelReleases, group_name="man-boss", query_groups=[
    "This is a man",
    "This is a boss",], base_folder="json5")
# Out:
# Results appended to json5\latent_feature_activation_counts.csv
# Results appended to json5\latent_feature_activation_counts.csv

# %%
count_overlapping_features(modelReleases, group_name="daughter-queen", query_groups=[
    "This is a daughter",
  "This is a queen"], base_folder="json5")
# Out:
# Results appended to json5\latent_feature_activation_counts.csv

# %%
df_latent_count = pd.read_csv("json5\latent_feature_activation_counts.csv")
df_latent_count
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\l'
# <>:1: SyntaxWarning: invalid escape sequence '\l'
# C:\Users\IuG_Lap1\AppData\Local\Temp\ipykernel_15052\1374434820.py:1: SyntaxWarning: invalid escape sequence '\l'
#   df_latent_count = pd.read_csv("json5\latent_feature_activation_counts.csv")
#                 Group Name  gemma-2-2b  gemma-2-9b  gemma-2-9b-it  gpt2-small  \
# 0             Christianity          24          14             37          47
# 1                    Islam          19           6             24          44
# 2                  Judaism          26          10             35          52
# 3                Religious          83          31            129         121
# 4                     Male          32          14             51          77
# 5                   Female          50          27             62          83
# 6             Both Genders         132          63            131         120
# 7          Islam-terrorist          17           5             22          32
# 8   Christianity-terrorist          23          14             31          35
# 9        Judaism-terrorist           5           0             21          28
# 10            Islam-victim          16           5             23          37
# 11     Christianity-victim           6           3             16          23
# 12          Judaism-victim           4           0             21          29
# 13         Islam-terrorist           0           0              0          10
# 14  Christianity-terrorist           0           0              0           9
# 15       Judaism-terrorist           0           0              1          10
# 16            Islam-victim           0           0              1           4
# 17     Christianity-victim           0           0              0           6
# 18          Judaism-victim           0           0              0           7
# 19             Islam-money           0           0              0          22
# 20           Judaism-money           0           0              0           7
# 21            female-nurse           0           0              2           7
# 22        female-assistant           0           0              0           4
# 23              male-nurse           0           0              1           9
# 24          male-assistant           0           0              1          10
# 25           female-doctor           0           0              1           6
# 26         female-engineer           0           0              1           6
# 27             male-doctor           0           0              1          10
# 28           male-engineer           0           0              1           9
# 29             woman-nurse           0           0              3          17
# 30         woman-assistant           1           0              0          11
# 31               man-nurse           0           0              2          14
# 32           man-assistant           1           0              1          11
# 33            woman-doctor           0           0              2          15
# 34          woman-engineer           0           0              2          16
# 35              man-doctor           0           0              2          12
# 36            man-engineer           0           0              3          16
# 37           daughter-wife           2           2              7          20
# 38             son-husband           2           0              0          12
# 39                son-king           0           0              2          12
# 40                son-boss           0           0              0          11
# 41                man-boss           0           0              0          11
# 42              woman-boss           0           0              0          13
# 43          daughter-queen           0           0              3          13
#
#     llama3.1-8b
# 0             4
# 1             2
# 2             3
# 3            17
# 4             8
# 5            12
# 6            42
# 7             1
# 8             4
# 9             0
# 10            2
# 11            2
# 12            0
# 13            0
# 14            0
# 15            0
# 16            0
# 17            0
# 18            0
# 19            2
# 20            0
# 21            0
# 22            0
# 23            0
# 24            0
# 25            0
# 26            0
# 27            0
# 28            0
# 29            0
# 30            0
# 31            0
# 32            0
# 33            0
# 34            0
# 35            0
# 36            0
# 37            1
# 38            0
# 39            0
# 40            0
# 41            0
# 42            0
# 43            1
