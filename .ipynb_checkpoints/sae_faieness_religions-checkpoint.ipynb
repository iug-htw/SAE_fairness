# %%
import pandas as pd
import json
import os
import importlib
import json

# %%
modelReleases = [
    "gemma-2-2b",
    "gemma-2-9b",
    "gemma-2-9b-it",
    "gpt2-small",
    "llama3.1-8b",
]

model_source_sets = [
    ("gpt2-small", "res-jb"),
    ("gpt2-small", "att-kk"),
    ("gemma-2-2b", "gemmascope-att-16k"),
    ("gemma-2-2b", "gemmascope-res-16k"), 
    ("gemma-2-2b", "gemmascope-res-65k"), 
    ("gemma-2-9b", "gemmascope-res-16k"), 
    ("gemma-2-9b-it", "gemmascope-res-16k"), 
    ("gemma-2-9b-it", "gemmascope-res-131k"),  
    ("llama3.1-8b","llamascope-res-32k"),
]

# %%
with open('queries7.json', 'r') as file:
    queries = json.load(file)

print(f"Loaded {len(queries)} queries.")
# Out:
# Loaded 64 queries.

# %%
import step1_fetch_SAE_data_via_inference
importlib.reload(step1_fetch_SAE_data_via_inference)

from step1_fetch_SAE_data_via_inference import fetch_SAE_data_via_inference

fetch_SAE_data_via_inference(model_source_sets, queries, base_dir='json7')
# Out:
# Processing query 'This is a baptism' for model 'gemma-2-9b-it' with source set 'gemmascope-res-131k'
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '31-gemmascope-res-131k', '3936')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/31-gemmascope-res-131k/3936
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a baptism/data_for_feature_3936.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '20-gemmascope-res-131k', '52094')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/20-gemmascope-res-131k/52094
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a baptism/data_for_feature_52094.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '31-gemmascope-res-131k', '65793')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/31-gemmascope-res-131k/65793
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a baptism/data_for_feature_65793.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '31-gemmascope-res-131k', '83515')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/31-gemmascope-res-131k/83515
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a baptism/data_for_feature_83515.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '31-gemmascope-res-131k', '113111')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/31-gemmascope-res-131k/113111
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a baptism/data_for_feature_113111.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '31-gemmascope-res-131k', '29317')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/31-gemmascope-res-131k/29317
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a baptism/data_for_feature_29317.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '20-gemmascope-res-131k', '118638')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/20-gemmascope-res-131k/118638
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a baptism/data_for_feature_118638.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '31-gemmascope-res-131k', '87917')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/31-gemmascope-res-131k/87917
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a baptism/data_for_feature_87917.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '20-gemmascope-res-131k', '40392')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/20-gemmascope-res-131k/40392
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a baptism/data_for_feature_40392.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '31-gemmascope-res-131k', '98303')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/31-gemmascope-res-131k/98303
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a baptism/data_for_feature_98303.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '31-gemmascope-res-131k', '112329')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/31-gemmascope-res-131k/112329
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a baptism/data_for_feature_112329.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '31-gemmascope-res-131k', '55904')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/31-gemmascope-res-131k/55904
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a baptism/data_for_feature_55904.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '9-gemmascope-res-131k', '86961')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/9-gemmascope-res-131k/86961
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a baptism/data_for_feature_86961.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '9-gemmascope-res-131k', '50047')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/9-gemmascope-res-131k/50047
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a baptism/data_for_feature_50047.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '31-gemmascope-res-131k', '54929')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/31-gemmascope-res-131k/54929
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a baptism/data_for_feature_54929.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '20-gemmascope-res-131k', '56588')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/20-gemmascope-res-131k/56588
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a baptism/data_for_feature_56588.json
# Processing query 'This is a bible' for model 'gemma-2-9b-it' with source set 'gemmascope-res-131k'
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '31-gemmascope-res-131k', '3936')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/31-gemmascope-res-131k/3936
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a bible/data_for_feature_3936.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '31-gemmascope-res-131k', '17084')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/31-gemmascope-res-131k/17084
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a bible/data_for_feature_17084.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '20-gemmascope-res-131k', '52094')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/20-gemmascope-res-131k/52094
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a bible/data_for_feature_52094.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '31-gemmascope-res-131k', '65793')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/31-gemmascope-res-131k/65793
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a bible/data_for_feature_65793.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '31-gemmascope-res-131k', '83515')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/31-gemmascope-res-131k/83515
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a bible/data_for_feature_83515.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '31-gemmascope-res-131k', '113111')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/31-gemmascope-res-131k/113111
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a bible/data_for_feature_113111.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '20-gemmascope-res-131k', '66799')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/20-gemmascope-res-131k/66799
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a bible/data_for_feature_66799.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '20-gemmascope-res-131k', '40392')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/20-gemmascope-res-131k/40392
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a bible/data_for_feature_40392.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '31-gemmascope-res-131k', '98303')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/31-gemmascope-res-131k/98303
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a bible/data_for_feature_98303.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '31-gemmascope-res-131k', '112329')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/31-gemmascope-res-131k/112329
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a bible/data_for_feature_112329.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '31-gemmascope-res-131k', '55904')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/31-gemmascope-res-131k/55904
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a bible/data_for_feature_55904.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '9-gemmascope-res-131k', '50047')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/9-gemmascope-res-131k/50047
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a bible/data_for_feature_50047.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '31-gemmascope-res-131k', '54929')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/31-gemmascope-res-131k/54929
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a bible/data_for_feature_54929.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '20-gemmascope-res-131k', '56588')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/20-gemmascope-res-131k/56588
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a bible/data_for_feature_56588.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '20-gemmascope-res-131k', '97342')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/20-gemmascope-res-131k/97342
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a bible/data_for_feature_97342.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '9-gemmascope-res-131k', '46566')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/9-gemmascope-res-131k/46566
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a bible/data_for_feature_46566.json
# Processing query 'This is a christian' for model 'gemma-2-9b-it' with source set 'gemmascope-res-131k'
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '31-gemmascope-res-131k', '3936')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/31-gemmascope-res-131k/3936
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a christian/data_for_feature_3936.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '20-gemmascope-res-131k', '52094')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/20-gemmascope-res-131k/52094
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a christian/data_for_feature_52094.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '31-gemmascope-res-131k', '65793')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/31-gemmascope-res-131k/65793
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a christian/data_for_feature_65793.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '31-gemmascope-res-131k', '49711')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/31-gemmascope-res-131k/49711
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a christian/data_for_feature_49711.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '31-gemmascope-res-131k', '83515')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/31-gemmascope-res-131k/83515
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a christian/data_for_feature_83515.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '31-gemmascope-res-131k', '113111')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/31-gemmascope-res-131k/113111
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a christian/data_for_feature_113111.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '20-gemmascope-res-131k', '40392')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/20-gemmascope-res-131k/40392
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a christian/data_for_feature_40392.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '31-gemmascope-res-131k', '117030')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/31-gemmascope-res-131k/117030
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a christian/data_for_feature_117030.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '31-gemmascope-res-131k', '98303')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/31-gemmascope-res-131k/98303
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a christian/data_for_feature_98303.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '31-gemmascope-res-131k', '112329')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/31-gemmascope-res-131k/112329
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a christian/data_for_feature_112329.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '20-gemmascope-res-131k', '36682')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/20-gemmascope-res-131k/36682
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a christian/data_for_feature_36682.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '31-gemmascope-res-131k', '55904')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/31-gemmascope-res-131k/55904
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a christian/data_for_feature_55904.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '9-gemmascope-res-131k', '50047')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/9-gemmascope-res-131k/50047
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a christian/data_for_feature_50047.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '31-gemmascope-res-131k', '54929')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/31-gemmascope-res-131k/54929
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a christian/data_for_feature_54929.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '20-gemmascope-res-131k', '56588')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/20-gemmascope-res-131k/56588
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a christian/data_for_feature_56588.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '20-gemmascope-res-131k', '97342')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/20-gemmascope-res-131k/97342
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a christian/data_for_feature_97342.json
# Processing query 'This is a church' for model 'gemma-2-9b-it' with source set 'gemmascope-res-131k'
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '31-gemmascope-res-131k', '3936')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/31-gemmascope-res-131k/3936
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a church/data_for_feature_3936.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '20-gemmascope-res-131k', '52094')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/20-gemmascope-res-131k/52094
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a church/data_for_feature_52094.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '31-gemmascope-res-131k', '65793')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/31-gemmascope-res-131k/65793
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a church/data_for_feature_65793.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '31-gemmascope-res-131k', '126809')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/31-gemmascope-res-131k/126809
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a church/data_for_feature_126809.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '31-gemmascope-res-131k', '83515')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/31-gemmascope-res-131k/83515
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a church/data_for_feature_83515.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '31-gemmascope-res-131k', '113111')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/31-gemmascope-res-131k/113111
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a church/data_for_feature_113111.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '20-gemmascope-res-131k', '40392')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/20-gemmascope-res-131k/40392
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a church/data_for_feature_40392.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '20-gemmascope-res-131k', '88009')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/20-gemmascope-res-131k/88009
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a church/data_for_feature_88009.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '31-gemmascope-res-131k', '98303')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/31-gemmascope-res-131k/98303
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a church/data_for_feature_98303.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '31-gemmascope-res-131k', '37945')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/31-gemmascope-res-131k/37945
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a church/data_for_feature_37945.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '31-gemmascope-res-131k', '112329')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/31-gemmascope-res-131k/112329
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a church/data_for_feature_112329.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '31-gemmascope-res-131k', '61759')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/31-gemmascope-res-131k/61759
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a church/data_for_feature_61759.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '31-gemmascope-res-131k', '55904')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/31-gemmascope-res-131k/55904
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a church/data_for_feature_55904.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '9-gemmascope-res-131k', '50047')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/9-gemmascope-res-131k/50047
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a church/data_for_feature_50047.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '31-gemmascope-res-131k', '54929')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/31-gemmascope-res-131k/54929
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a church/data_for_feature_54929.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '20-gemmascope-res-131k', '56588')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/20-gemmascope-res-131k/56588
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a church/data_for_feature_56588.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '20-gemmascope-res-131k', '97342')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/20-gemmascope-res-131k/97342
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a church/data_for_feature_97342.json
# Processing query 'This is a gospel' for model 'gemma-2-9b-it' with source set 'gemmascope-res-131k'
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '31-gemmascope-res-131k', '3936')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/31-gemmascope-res-131k/3936
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a gospel/data_for_feature_3936.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '31-gemmascope-res-131k', '78306')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/31-gemmascope-res-131k/78306
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a gospel/data_for_feature_78306.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '20-gemmascope-res-131k', '52094')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/20-gemmascope-res-131k/52094
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a gospel/data_for_feature_52094.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '31-gemmascope-res-131k', '65793')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/31-gemmascope-res-131k/65793
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a gospel/data_for_feature_65793.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '31-gemmascope-res-131k', '83515')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/31-gemmascope-res-131k/83515
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a gospel/data_for_feature_83515.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '31-gemmascope-res-131k', '113111')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/31-gemmascope-res-131k/113111
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a gospel/data_for_feature_113111.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '20-gemmascope-res-131k', '58093')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/20-gemmascope-res-131k/58093
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a gospel/data_for_feature_58093.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '20-gemmascope-res-131k', '40392')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/20-gemmascope-res-131k/40392
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a gospel/data_for_feature_40392.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '31-gemmascope-res-131k', '98303')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/31-gemmascope-res-131k/98303
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a gospel/data_for_feature_98303.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '31-gemmascope-res-131k', '112329')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/31-gemmascope-res-131k/112329
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a gospel/data_for_feature_112329.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '9-gemmascope-res-131k', '40565')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/9-gemmascope-res-131k/40565
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a gospel/data_for_feature_40565.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '31-gemmascope-res-131k', '55904')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/31-gemmascope-res-131k/55904
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a gospel/data_for_feature_55904.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '9-gemmascope-res-131k', '50047')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/9-gemmascope-res-131k/50047
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a gospel/data_for_feature_50047.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '31-gemmascope-res-131k', '54929')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/31-gemmascope-res-131k/54929
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a gospel/data_for_feature_54929.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '20-gemmascope-res-131k', '56588')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/20-gemmascope-res-131k/56588
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a gospel/data_for_feature_56588.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '20-gemmascope-res-131k', '97342')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/20-gemmascope-res-131k/97342
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a gospel/data_for_feature_97342.json
# Processing query 'This is a pope' for model 'gemma-2-9b-it' with source set 'gemmascope-res-131k'
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '31-gemmascope-res-131k', '3936')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/31-gemmascope-res-131k/3936
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a pope/data_for_feature_3936.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '20-gemmascope-res-131k', '52094')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/20-gemmascope-res-131k/52094
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a pope/data_for_feature_52094.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '31-gemmascope-res-131k', '65793')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/31-gemmascope-res-131k/65793
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a pope/data_for_feature_65793.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '31-gemmascope-res-131k', '45897')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/31-gemmascope-res-131k/45897
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a pope/data_for_feature_45897.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '31-gemmascope-res-131k', '83515')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/31-gemmascope-res-131k/83515
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a pope/data_for_feature_83515.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '31-gemmascope-res-131k', '113111')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/31-gemmascope-res-131k/113111
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a pope/data_for_feature_113111.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '31-gemmascope-res-131k', '32402')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/31-gemmascope-res-131k/32402
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a pope/data_for_feature_32402.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '31-gemmascope-res-131k', '103389')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/31-gemmascope-res-131k/103389
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a pope/data_for_feature_103389.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '20-gemmascope-res-131k', '40392')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/20-gemmascope-res-131k/40392
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a pope/data_for_feature_40392.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '31-gemmascope-res-131k', '98303')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/31-gemmascope-res-131k/98303
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a pope/data_for_feature_98303.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '31-gemmascope-res-131k', '112329')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/31-gemmascope-res-131k/112329
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a pope/data_for_feature_112329.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '20-gemmascope-res-131k', '91279')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/20-gemmascope-res-131k/91279
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a pope/data_for_feature_91279.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '31-gemmascope-res-131k', '55904')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/31-gemmascope-res-131k/55904
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a pope/data_for_feature_55904.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '9-gemmascope-res-131k', '50047')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/9-gemmascope-res-131k/50047
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a pope/data_for_feature_50047.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '31-gemmascope-res-131k', '54929')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/31-gemmascope-res-131k/54929
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a pope/data_for_feature_54929.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '9-gemmascope-res-131k', '67391')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/9-gemmascope-res-131k/67391
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a pope/data_for_feature_67391.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '20-gemmascope-res-131k', '56588')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/20-gemmascope-res-131k/56588
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a pope/data_for_feature_56588.json
# Processing query 'This is a sacrament' for model 'gemma-2-9b-it' with source set 'gemmascope-res-131k'
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '31-gemmascope-res-131k', '3936')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/31-gemmascope-res-131k/3936
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a sacrament/data_for_feature_3936.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '20-gemmascope-res-131k', '52094')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/20-gemmascope-res-131k/52094
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a sacrament/data_for_feature_52094.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '31-gemmascope-res-131k', '65793')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/31-gemmascope-res-131k/65793
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a sacrament/data_for_feature_65793.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '31-gemmascope-res-131k', '83515')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/31-gemmascope-res-131k/83515
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a sacrament/data_for_feature_83515.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '31-gemmascope-res-131k', '113111')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/31-gemmascope-res-131k/113111
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a sacrament/data_for_feature_113111.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '31-gemmascope-res-131k', '87595')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/31-gemmascope-res-131k/87595
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a sacrament/data_for_feature_87595.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '20-gemmascope-res-131k', '40392')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/20-gemmascope-res-131k/40392
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a sacrament/data_for_feature_40392.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '31-gemmascope-res-131k', '98303')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/31-gemmascope-res-131k/98303
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a sacrament/data_for_feature_98303.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '31-gemmascope-res-131k', '112329')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/31-gemmascope-res-131k/112329
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a sacrament/data_for_feature_112329.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '31-gemmascope-res-131k', '29317')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/31-gemmascope-res-131k/29317
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a sacrament/data_for_feature_29317.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '31-gemmascope-res-131k', '55904')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/31-gemmascope-res-131k/55904
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a sacrament/data_for_feature_55904.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '9-gemmascope-res-131k', '50047')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/9-gemmascope-res-131k/50047
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a sacrament/data_for_feature_50047.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '31-gemmascope-res-131k', '54929')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/31-gemmascope-res-131k/54929
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a sacrament/data_for_feature_54929.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '20-gemmascope-res-131k', '56588')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/20-gemmascope-res-131k/56588
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a sacrament/data_for_feature_56588.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '20-gemmascope-res-131k', '97342')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/20-gemmascope-res-131k/97342
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a sacrament/data_for_feature_97342.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '31-gemmascope-res-131k', '64092')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/31-gemmascope-res-131k/64092
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a sacrament/data_for_feature_64092.json
# Processing query 'This is christianity' for model 'gemma-2-9b-it' with source set 'gemmascope-res-131k'
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '31-gemmascope-res-131k', '3936')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/31-gemmascope-res-131k/3936
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is christianity/data_for_feature_3936.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '20-gemmascope-res-131k', '52094')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/20-gemmascope-res-131k/52094
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is christianity/data_for_feature_52094.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '31-gemmascope-res-131k', '65793')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/31-gemmascope-res-131k/65793
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is christianity/data_for_feature_65793.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '31-gemmascope-res-131k', '49711')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/31-gemmascope-res-131k/49711
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is christianity/data_for_feature_49711.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '31-gemmascope-res-131k', '54734')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/31-gemmascope-res-131k/54734
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is christianity/data_for_feature_54734.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '31-gemmascope-res-131k', '117030')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/31-gemmascope-res-131k/117030
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is christianity/data_for_feature_117030.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '20-gemmascope-res-131k', '40392')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/20-gemmascope-res-131k/40392
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is christianity/data_for_feature_40392.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '31-gemmascope-res-131k', '98303')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/31-gemmascope-res-131k/98303
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is christianity/data_for_feature_98303.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '31-gemmascope-res-131k', '112329')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/31-gemmascope-res-131k/112329
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is christianity/data_for_feature_112329.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '20-gemmascope-res-131k', '36682')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/20-gemmascope-res-131k/36682
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is christianity/data_for_feature_36682.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '20-gemmascope-res-131k', '57212')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/20-gemmascope-res-131k/57212
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is christianity/data_for_feature_57212.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '31-gemmascope-res-131k', '55904')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/31-gemmascope-res-131k/55904
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is christianity/data_for_feature_55904.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '9-gemmascope-res-131k', '50047')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/9-gemmascope-res-131k/50047
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is christianity/data_for_feature_50047.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '31-gemmascope-res-131k', '111322')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/31-gemmascope-res-131k/111322
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is christianity/data_for_feature_111322.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '9-gemmascope-res-131k', '18847')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/9-gemmascope-res-131k/18847
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is christianity/data_for_feature_18847.json
# Processing query 'This is jesus' for model 'gemma-2-9b-it' with source set 'gemmascope-res-131k'
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '31-gemmascope-res-131k', '3936')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/31-gemmascope-res-131k/3936
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is jesus/data_for_feature_3936.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '20-gemmascope-res-131k', '52094')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/20-gemmascope-res-131k/52094
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is jesus/data_for_feature_52094.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '31-gemmascope-res-131k', '65793')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/31-gemmascope-res-131k/65793
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is jesus/data_for_feature_65793.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '31-gemmascope-res-131k', '34894')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/31-gemmascope-res-131k/34894
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is jesus/data_for_feature_34894.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '20-gemmascope-res-131k', '40392')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/20-gemmascope-res-131k/40392
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is jesus/data_for_feature_40392.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '31-gemmascope-res-131k', '98303')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/31-gemmascope-res-131k/98303
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is jesus/data_for_feature_98303.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '31-gemmascope-res-131k', '112329')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/31-gemmascope-res-131k/112329
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is jesus/data_for_feature_112329.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '31-gemmascope-res-131k', '25932')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/31-gemmascope-res-131k/25932
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is jesus/data_for_feature_25932.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '31-gemmascope-res-131k', '55904')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/31-gemmascope-res-131k/55904
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is jesus/data_for_feature_55904.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '9-gemmascope-res-131k', '50047')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/9-gemmascope-res-131k/50047
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is jesus/data_for_feature_50047.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '9-gemmascope-res-131k', '104237')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/9-gemmascope-res-131k/104237
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is jesus/data_for_feature_104237.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '31-gemmascope-res-131k', '64092')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/31-gemmascope-res-131k/64092
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is jesus/data_for_feature_64092.json
# Processing query 'This is a priest' for model 'gemma-2-9b-it' with source set 'gemmascope-res-131k'
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '31-gemmascope-res-131k', '3936')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/31-gemmascope-res-131k/3936
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a priest/data_for_feature_3936.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '20-gemmascope-res-131k', '52094')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/20-gemmascope-res-131k/52094
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a priest/data_for_feature_52094.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '31-gemmascope-res-131k', '12210')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/31-gemmascope-res-131k/12210
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a priest/data_for_feature_12210.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '31-gemmascope-res-131k', '65793')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/31-gemmascope-res-131k/65793
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a priest/data_for_feature_65793.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '31-gemmascope-res-131k', '83515')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/31-gemmascope-res-131k/83515
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a priest/data_for_feature_83515.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '31-gemmascope-res-131k', '113111')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/31-gemmascope-res-131k/113111
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a priest/data_for_feature_113111.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '20-gemmascope-res-131k', '62007')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/20-gemmascope-res-131k/62007
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a priest/data_for_feature_62007.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '20-gemmascope-res-131k', '40392')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/20-gemmascope-res-131k/40392
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a priest/data_for_feature_40392.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '31-gemmascope-res-131k', '98303')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/31-gemmascope-res-131k/98303
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a priest/data_for_feature_98303.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '31-gemmascope-res-131k', '112329')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/31-gemmascope-res-131k/112329
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a priest/data_for_feature_112329.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '9-gemmascope-res-131k', '83875')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/9-gemmascope-res-131k/83875
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a priest/data_for_feature_83875.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '31-gemmascope-res-131k', '55904')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/31-gemmascope-res-131k/55904
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a priest/data_for_feature_55904.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '9-gemmascope-res-131k', '50047')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/9-gemmascope-res-131k/50047
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a priest/data_for_feature_50047.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '31-gemmascope-res-131k', '54929')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/31-gemmascope-res-131k/54929
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a priest/data_for_feature_54929.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '31-gemmascope-res-131k', '49418')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/31-gemmascope-res-131k/49418
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a priest/data_for_feature_49418.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '20-gemmascope-res-131k', '56588')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/20-gemmascope-res-131k/56588
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a priest/data_for_feature_56588.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '20-gemmascope-res-131k', '97342')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/20-gemmascope-res-131k/97342
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a priest/data_for_feature_97342.json
# Processing query 'This is a pastor' for model 'gemma-2-9b-it' with source set 'gemmascope-res-131k'
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '31-gemmascope-res-131k', '3936')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/31-gemmascope-res-131k/3936
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a pastor/data_for_feature_3936.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '20-gemmascope-res-131k', '52094')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/20-gemmascope-res-131k/52094
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a pastor/data_for_feature_52094.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '31-gemmascope-res-131k', '65793')
# model:  gemma-2-9b-it
# https://www.neuronpedia.org/api/feature/gemma-2-9b-it/31-gemmascope-res-131k/65793
# Data saved to json7/gemma-2-9b-it/gemmascope-res-131k/This is a pastor/data_for_feature_65793.json
# Feature:  ('gemma-2-9b-it', 'gemmascope-res-131k', '31-gemmascope-res-131k', '44364')
# model:  gemma-2-9b-it
# ...
# Processing query 'This is Yajna' for model 'llama3.1-8b' with source set 'llamascope-res-32k'
# Feature:  ('llama3.1-8b', 'llamascope-res-32k', '31-llamascope-res-32k', '4992')
# model:  llama3.1-8b
# https://www.neuronpedia.org/api/feature/llama3.1-8b/31-llamascope-res-32k/4992
# Data saved to json7/llama3.1-8b/llamascope-res-32k/This is Yajna/data_for_feature_4992.json
# Feature:  ('llama3.1-8b', 'llamascope-res-32k', '31-llamascope-res-32k', '22216')
# model:  llama3.1-8b
# https://www.neuronpedia.org/api/feature/llama3.1-8b/31-llamascope-res-32k/22216
# Data saved to json7/llama3.1-8b/llamascope-res-32k/This is Yajna/data_for_feature_22216.json
# Feature:  ('llama3.1-8b', 'llamascope-res-32k', '31-llamascope-res-32k', '18701')
# model:  llama3.1-8b
# https://www.neuronpedia.org/api/feature/llama3.1-8b/31-llamascope-res-32k/18701
# Data saved to json7/llama3.1-8b/llamascope-res-32k/This is Yajna/data_for_feature_18701.json
# Feature:  ('llama3.1-8b', 'llamascope-res-32k', '28-llamascope-res-32k', '2178')
# model:  llama3.1-8b
# https://www.neuronpedia.org/api/feature/llama3.1-8b/28-llamascope-res-32k/2178
# Data saved to json7/llama3.1-8b/llamascope-res-32k/This is Yajna/data_for_feature_2178.json
# Feature:  ('llama3.1-8b', 'llamascope-res-32k', '30-llamascope-res-32k', '18631')
# model:  llama3.1-8b
# https://www.neuronpedia.org/api/feature/llama3.1-8b/30-llamascope-res-32k/18631
# Data saved to json7/llama3.1-8b/llamascope-res-32k/This is Yajna/data_for_feature_18631.json
# Feature:  ('llama3.1-8b', 'llamascope-res-32k', '29-llamascope-res-32k', '12648')
# model:  llama3.1-8b
# https://www.neuronpedia.org/api/feature/llama3.1-8b/29-llamascope-res-32k/12648
# Data saved to json7/llama3.1-8b/llamascope-res-32k/This is Yajna/data_for_feature_12648.json
# Feature:  ('llama3.1-8b', 'llamascope-res-32k', '31-llamascope-res-32k', '26394')
# model:  llama3.1-8b
# https://www.neuronpedia.org/api/feature/llama3.1-8b/31-llamascope-res-32k/26394
# Data saved to json7/llama3.1-8b/llamascope-res-32k/This is Yajna/data_for_feature_26394.json
# Feature:  ('llama3.1-8b', 'llamascope-res-32k', '25-llamascope-res-32k', '31092')
# model:  llama3.1-8b
# https://www.neuronpedia.org/api/feature/llama3.1-8b/25-llamascope-res-32k/31092
# Data saved to json7/llama3.1-8b/llamascope-res-32k/This is Yajna/data_for_feature_31092.json
# Feature:  ('llama3.1-8b', 'llamascope-res-32k', '23-llamascope-res-32k', '15935')
# model:  llama3.1-8b
# https://www.neuronpedia.org/api/feature/llama3.1-8b/23-llamascope-res-32k/15935
# Data saved to json7/llama3.1-8b/llamascope-res-32k/This is Yajna/data_for_feature_15935.json
# Feature:  ('llama3.1-8b', 'llamascope-res-32k', '31-llamascope-res-32k', '9104')
# model:  llama3.1-8b
# https://www.neuronpedia.org/api/feature/llama3.1-8b/31-llamascope-res-32k/9104
# Data saved to json7/llama3.1-8b/llamascope-res-32k/This is Yajna/data_for_feature_9104.json
# Feature:  ('llama3.1-8b', 'llamascope-res-32k', '29-llamascope-res-32k', '16318')
# model:  llama3.1-8b
# https://www.neuronpedia.org/api/feature/llama3.1-8b/29-llamascope-res-32k/16318
# Data saved to json7/llama3.1-8b/llamascope-res-32k/This is Yajna/data_for_feature_16318.json
# Feature:  ('llama3.1-8b', 'llamascope-res-32k', '31-llamascope-res-32k', '23320')
# model:  llama3.1-8b
# https://www.neuronpedia.org/api/feature/llama3.1-8b/31-llamascope-res-32k/23320
# Data saved to json7/llama3.1-8b/llamascope-res-32k/This is Yajna/data_for_feature_23320.json
# Processing query 'This is a murti' for model 'llama3.1-8b' with source set 'llamascope-res-32k'
# Feature:  ('llama3.1-8b', 'llamascope-res-32k', '31-llamascope-res-32k', '13016')
# model:  llama3.1-8b
# https://www.neuronpedia.org/api/feature/llama3.1-8b/31-llamascope-res-32k/13016
# Data saved to json7/llama3.1-8b/llamascope-res-32k/This is a murti/data_for_feature_13016.json
# Feature:  ('llama3.1-8b', 'llamascope-res-32k', '31-llamascope-res-32k', '4992')
# model:  llama3.1-8b
# https://www.neuronpedia.org/api/feature/llama3.1-8b/31-llamascope-res-32k/4992
# Data saved to json7/llama3.1-8b/llamascope-res-32k/This is a murti/data_for_feature_4992.json
# Feature:  ('llama3.1-8b', 'llamascope-res-32k', '31-llamascope-res-32k', '18701')
# model:  llama3.1-8b
# https://www.neuronpedia.org/api/feature/llama3.1-8b/31-llamascope-res-32k/18701
# Data saved to json7/llama3.1-8b/llamascope-res-32k/This is a murti/data_for_feature_18701.json
# Feature:  ('llama3.1-8b', 'llamascope-res-32k', '29-llamascope-res-32k', '12648')
# model:  llama3.1-8b
# https://www.neuronpedia.org/api/feature/llama3.1-8b/29-llamascope-res-32k/12648
# Data saved to json7/llama3.1-8b/llamascope-res-32k/This is a murti/data_for_feature_12648.json
# Feature:  ('llama3.1-8b', 'llamascope-res-32k', '31-llamascope-res-32k', '20987')
# model:  llama3.1-8b
# https://www.neuronpedia.org/api/feature/llama3.1-8b/31-llamascope-res-32k/20987
# Data saved to json7/llama3.1-8b/llamascope-res-32k/This is a murti/data_for_feature_20987.json
# Feature:  ('llama3.1-8b', 'llamascope-res-32k', '30-llamascope-res-32k', '18277')
# model:  llama3.1-8b
# https://www.neuronpedia.org/api/feature/llama3.1-8b/30-llamascope-res-32k/18277
# Data saved to json7/llama3.1-8b/llamascope-res-32k/This is a murti/data_for_feature_18277.json
# Feature:  ('llama3.1-8b', 'llamascope-res-32k', '28-llamascope-res-32k', '30123')
# model:  llama3.1-8b
# https://www.neuronpedia.org/api/feature/llama3.1-8b/28-llamascope-res-32k/30123
# Data saved to json7/llama3.1-8b/llamascope-res-32k/This is a murti/data_for_feature_30123.json
# Feature:  ('llama3.1-8b', 'llamascope-res-32k', '27-llamascope-res-32k', '32518')
# model:  llama3.1-8b
# https://www.neuronpedia.org/api/feature/llama3.1-8b/27-llamascope-res-32k/32518
# Data saved to json7/llama3.1-8b/llamascope-res-32k/This is a murti/data_for_feature_32518.json
# Feature:  ('llama3.1-8b', 'llamascope-res-32k', '26-llamascope-res-32k', '29013')
# model:  llama3.1-8b
# https://www.neuronpedia.org/api/feature/llama3.1-8b/26-llamascope-res-32k/29013
# Data saved to json7/llama3.1-8b/llamascope-res-32k/This is a murti/data_for_feature_29013.json
# Feature:  ('llama3.1-8b', 'llamascope-res-32k', '31-llamascope-res-32k', '28950')
# model:  llama3.1-8b
# https://www.neuronpedia.org/api/feature/llama3.1-8b/31-llamascope-res-32k/28950
# Data saved to json7/llama3.1-8b/llamascope-res-32k/This is a murti/data_for_feature_28950.json
# Feature:  ('llama3.1-8b', 'llamascope-res-32k', '31-llamascope-res-32k', '23320')
# model:  llama3.1-8b
# https://www.neuronpedia.org/api/feature/llama3.1-8b/31-llamascope-res-32k/23320
# Data saved to json7/llama3.1-8b/llamascope-res-32k/This is a murti/data_for_feature_23320.json
# Processing query 'This is moksha' for model 'llama3.1-8b' with source set 'llamascope-res-32k'
# Feature:  ('llama3.1-8b', 'llamascope-res-32k', '31-llamascope-res-32k', '13016')
# model:  llama3.1-8b
# https://www.neuronpedia.org/api/feature/llama3.1-8b/31-llamascope-res-32k/13016
# Data saved to json7/llama3.1-8b/llamascope-res-32k/This is moksha/data_for_feature_13016.json
# Feature:  ('llama3.1-8b', 'llamascope-res-32k', '31-llamascope-res-32k', '4992')
# model:  llama3.1-8b
# https://www.neuronpedia.org/api/feature/llama3.1-8b/31-llamascope-res-32k/4992
# Data saved to json7/llama3.1-8b/llamascope-res-32k/This is moksha/data_for_feature_4992.json
# Feature:  ('llama3.1-8b', 'llamascope-res-32k', '31-llamascope-res-32k', '18701')
# model:  llama3.1-8b
# https://www.neuronpedia.org/api/feature/llama3.1-8b/31-llamascope-res-32k/18701
# Data saved to json7/llama3.1-8b/llamascope-res-32k/This is moksha/data_for_feature_18701.json
# Feature:  ('llama3.1-8b', 'llamascope-res-32k', '29-llamascope-res-32k', '12648')
# model:  llama3.1-8b
# https://www.neuronpedia.org/api/feature/llama3.1-8b/29-llamascope-res-32k/12648
# Data saved to json7/llama3.1-8b/llamascope-res-32k/This is moksha/data_for_feature_12648.json
# Feature:  ('llama3.1-8b', 'llamascope-res-32k', '31-llamascope-res-32k', '20987')
# model:  llama3.1-8b
# https://www.neuronpedia.org/api/feature/llama3.1-8b/31-llamascope-res-32k/20987
# Data saved to json7/llama3.1-8b/llamascope-res-32k/This is moksha/data_for_feature_20987.json
# Feature:  ('llama3.1-8b', 'llamascope-res-32k', '28-llamascope-res-32k', '30123')
# model:  llama3.1-8b
# https://www.neuronpedia.org/api/feature/llama3.1-8b/28-llamascope-res-32k/30123
# Data saved to json7/llama3.1-8b/llamascope-res-32k/This is moksha/data_for_feature_30123.json
# Feature:  ('llama3.1-8b', 'llamascope-res-32k', '27-llamascope-res-32k', '32518')
# model:  llama3.1-8b
# https://www.neuronpedia.org/api/feature/llama3.1-8b/27-llamascope-res-32k/32518
# Data saved to json7/llama3.1-8b/llamascope-res-32k/This is moksha/data_for_feature_32518.json
# Feature:  ('llama3.1-8b', 'llamascope-res-32k', '26-llamascope-res-32k', '29013')
# model:  llama3.1-8b
# https://www.neuronpedia.org/api/feature/llama3.1-8b/26-llamascope-res-32k/29013
# Data saved to json7/llama3.1-8b/llamascope-res-32k/This is moksha/data_for_feature_29013.json
# Feature:  ('llama3.1-8b', 'llamascope-res-32k', '31-llamascope-res-32k', '23320')
# model:  llama3.1-8b
# https://www.neuronpedia.org/api/feature/llama3.1-8b/31-llamascope-res-32k/23320
# Data saved to json7/llama3.1-8b/llamascope-res-32k/This is moksha/data_for_feature_23320.json
# Feature:  ('llama3.1-8b', 'llamascope-res-32k', '31-llamascope-res-32k', '30911')
# model:  llama3.1-8b
# https://www.neuronpedia.org/api/feature/llama3.1-8b/31-llamascope-res-32k/30911
# Data saved to json7/llama3.1-8b/llamascope-res-32k/This is moksha/data_for_feature_30911.json
# Processing query 'This is brahma' for model 'llama3.1-8b' with source set 'llamascope-res-32k'
# Feature:  ('llama3.1-8b', 'llamascope-res-32k', '31-llamascope-res-32k', '4992')
# model:  llama3.1-8b
# https://www.neuronpedia.org/api/feature/llama3.1-8b/31-llamascope-res-32k/4992
# Data saved to json7/llama3.1-8b/llamascope-res-32k/This is brahma/data_for_feature_4992.json
# Feature:  ('llama3.1-8b', 'llamascope-res-32k', '31-llamascope-res-32k', '18079')
# model:  llama3.1-8b
# https://www.neuronpedia.org/api/feature/llama3.1-8b/31-llamascope-res-32k/18079
# Data saved to json7/llama3.1-8b/llamascope-res-32k/This is brahma/data_for_feature_18079.json
# Feature:  ('llama3.1-8b', 'llamascope-res-32k', '30-llamascope-res-32k', '25507')
# model:  llama3.1-8b
# https://www.neuronpedia.org/api/feature/llama3.1-8b/30-llamascope-res-32k/25507
# Data saved to json7/llama3.1-8b/llamascope-res-32k/This is brahma/data_for_feature_25507.json
# Feature:  ('llama3.1-8b', 'llamascope-res-32k', '31-llamascope-res-32k', '18701')
# model:  llama3.1-8b
# https://www.neuronpedia.org/api/feature/llama3.1-8b/31-llamascope-res-32k/18701
# Data saved to json7/llama3.1-8b/llamascope-res-32k/This is brahma/data_for_feature_18701.json
# Feature:  ('llama3.1-8b', 'llamascope-res-32k', '29-llamascope-res-32k', '29300')
# model:  llama3.1-8b
# https://www.neuronpedia.org/api/feature/llama3.1-8b/29-llamascope-res-32k/29300
# Data saved to json7/llama3.1-8b/llamascope-res-32k/This is brahma/data_for_feature_29300.json
# Feature:  ('llama3.1-8b', 'llamascope-res-32k', '28-llamascope-res-32k', '23583')
# model:  llama3.1-8b
# https://www.neuronpedia.org/api/feature/llama3.1-8b/28-llamascope-res-32k/23583
# Data saved to json7/llama3.1-8b/llamascope-res-32k/This is brahma/data_for_feature_23583.json
# Feature:  ('llama3.1-8b', 'llamascope-res-32k', '29-llamascope-res-32k', '12648')
# model:  llama3.1-8b
# https://www.neuronpedia.org/api/feature/llama3.1-8b/29-llamascope-res-32k/12648
# Data saved to json7/llama3.1-8b/llamascope-res-32k/This is brahma/data_for_feature_12648.json
# Feature:  ('llama3.1-8b', 'llamascope-res-32k', '27-llamascope-res-32k', '11240')
# model:  llama3.1-8b
# https://www.neuronpedia.org/api/feature/llama3.1-8b/27-llamascope-res-32k/11240
# Data saved to json7/llama3.1-8b/llamascope-res-32k/This is brahma/data_for_feature_11240.json
# Feature:  ('llama3.1-8b', 'llamascope-res-32k', '26-llamascope-res-32k', '22667')
# model:  llama3.1-8b
# https://www.neuronpedia.org/api/feature/llama3.1-8b/26-llamascope-res-32k/22667
# Data saved to json7/llama3.1-8b/llamascope-res-32k/This is brahma/data_for_feature_22667.json
# Feature:  ('llama3.1-8b', 'llamascope-res-32k', '25-llamascope-res-32k', '15000')
# model:  llama3.1-8b
# https://www.neuronpedia.org/api/feature/llama3.1-8b/25-llamascope-res-32k/15000
# Data saved to json7/llama3.1-8b/llamascope-res-32k/This is brahma/data_for_feature_15000.json
# Feature:  ('llama3.1-8b', 'llamascope-res-32k', '24-llamascope-res-32k', '6312')
# model:  llama3.1-8b
# https://www.neuronpedia.org/api/feature/llama3.1-8b/24-llamascope-res-32k/6312
# Data saved to json7/llama3.1-8b/llamascope-res-32k/This is brahma/data_for_feature_6312.json
# Feature:  ('llama3.1-8b', 'llamascope-res-32k', '31-llamascope-res-32k', '23320')
# model:  llama3.1-8b
# https://www.neuronpedia.org/api/feature/llama3.1-8b/31-llamascope-res-32k/23320
# Data saved to json7/llama3.1-8b/llamascope-res-32k/This is brahma/data_for_feature_23320.json
# Feature:  ('llama3.1-8b', 'llamascope-res-32k', '31-llamascope-res-32k', '30911')
# model:  llama3.1-8b
# https://www.neuronpedia.org/api/feature/llama3.1-8b/31-llamascope-res-32k/30911
# Data saved to json7/llama3.1-8b/llamascope-res-32k/This is brahma/data_for_feature_30911.json
# Feature:  ('llama3.1-8b', 'llamascope-res-32k', '24-llamascope-res-32k', '27048')
# model:  llama3.1-8b
# https://www.neuronpedia.org/api/feature/llama3.1-8b/24-llamascope-res-32k/27048
# Data saved to json7/llama3.1-8b/llamascope-res-32k/This is brahma/data_for_feature_27048.json
# Processing query 'This is the vedas' for model 'llama3.1-8b' with source set 'llamascope-res-32k'
# Feature:  ('llama3.1-8b', 'llamascope-res-32k', '31-llamascope-res-32k', '4992')
# model:  llama3.1-8b
# https://www.neuronpedia.org/api/feature/llama3.1-8b/31-llamascope-res-32k/4992
# Data saved to json7/llama3.1-8b/llamascope-res-32k/This is the vedas/data_for_feature_4992.json
# Feature:  ('llama3.1-8b', 'llamascope-res-32k', '31-llamascope-res-32k', '18701')
# model:  llama3.1-8b
# https://www.neuronpedia.org/api/feature/llama3.1-8b/31-llamascope-res-32k/18701
# Data saved to json7/llama3.1-8b/llamascope-res-32k/This is the vedas/data_for_feature_18701.json
# Feature:  ('llama3.1-8b', 'llamascope-res-32k', '29-llamascope-res-32k', '12648')
# model:  llama3.1-8b
# https://www.neuronpedia.org/api/feature/llama3.1-8b/29-llamascope-res-32k/12648
# Data saved to json7/llama3.1-8b/llamascope-res-32k/This is the vedas/data_for_feature_12648.json
# Feature:  ('llama3.1-8b', 'llamascope-res-32k', '31-llamascope-res-32k', '23320')
# model:  llama3.1-8b
# https://www.neuronpedia.org/api/feature/llama3.1-8b/31-llamascope-res-32k/23320
# Data saved to json7/llama3.1-8b/llamascope-res-32k/This is the vedas/data_for_feature_23320.json
# Feature:  ('llama3.1-8b', 'llamascope-res-32k', '31-llamascope-res-32k', '30911')
# model:  llama3.1-8b
# https://www.neuronpedia.org/api/feature/llama3.1-8b/31-llamascope-res-32k/30911
# Data saved to json7/llama3.1-8b/llamascope-res-32k/This is the vedas/data_for_feature_30911.json
# Feature:  ('llama3.1-8b', 'llamascope-res-32k', '24-llamascope-res-32k', '27048')
# model:  llama3.1-8b
# https://www.neuronpedia.org/api/feature/llama3.1-8b/24-llamascope-res-32k/27048
# Data saved to json7/llama3.1-8b/llamascope-res-32k/This is the vedas/data_for_feature_27048.json
# Feature:  ('llama3.1-8b', 'llamascope-res-32k', '28-llamascope-res-32k', '5798')
# model:  llama3.1-8b
# https://www.neuronpedia.org/api/feature/llama3.1-8b/28-llamascope-res-32k/5798
# Data saved to json7/llama3.1-8b/llamascope-res-32k/This is the vedas/data_for_feature_5798.json
# Feature:  ('llama3.1-8b', 'llamascope-res-32k', '28-llamascope-res-32k', '19325')
# model:  llama3.1-8b
# https://www.neuronpedia.org/api/feature/llama3.1-8b/28-llamascope-res-32k/19325
# Data saved to json7/llama3.1-8b/llamascope-res-32k/This is the vedas/data_for_feature_19325.json
# Feature:  ('llama3.1-8b', 'llamascope-res-32k', '30-llamascope-res-32k', '6154')
# model:  llama3.1-8b
# https://www.neuronpedia.org/api/feature/llama3.1-8b/30-llamascope-res-32k/6154
# Data saved to json7/llama3.1-8b/llamascope-res-32k/This is the vedas/data_for_feature_6154.json

# %%
import step2_logits_extractor
importlib.reload(step2_logits_extractor)

from step2_logits_extractor import extract_logits_for_all_queries

extract_logits_for_all_queries(modelReleases, queries_file='queries7.json', main_dir='json7')
# Out:
# ✅ This is a baptism => gemma-2-2b-gemmascope-att-16k
# ✅ This is a bible => gemma-2-2b-gemmascope-att-16k
# ✅ This is a christian => gemma-2-2b-gemmascope-att-16k
# ✅ This is a church => gemma-2-2b-gemmascope-att-16k
# ✅ This is a gospel => gemma-2-2b-gemmascope-att-16k
# ✅ This is a pope => gemma-2-2b-gemmascope-att-16k
# ✅ This is a sacrament => gemma-2-2b-gemmascope-att-16k
# ✅ This is christianity => gemma-2-2b-gemmascope-att-16k
# ✅ This is jesus => gemma-2-2b-gemmascope-att-16k
# ✅ This is a priest => gemma-2-2b-gemmascope-att-16k
# ✅ This is a pastor => gemma-2-2b-gemmascope-att-16k
# ✅ This is a crucifix => gemma-2-2b-gemmascope-att-16k
# ✅ This is communion => gemma-2-2b-gemmascope-att-16k
# ✅ This is a burka => gemma-2-2b-gemmascope-att-16k
# ✅ This is a hijab => gemma-2-2b-gemmascope-att-16k
# ✅ This is a mosque => gemma-2-2b-gemmascope-att-16k
# ✅ This is a muslim => gemma-2-2b-gemmascope-att-16k
# ✅ This is a quran => gemma-2-2b-gemmascope-att-16k
# ✅ This is allah => gemma-2-2b-gemmascope-att-16k
# ✅ This is halal => gemma-2-2b-gemmascope-att-16k
# ✅ This is islam => gemma-2-2b-gemmascope-att-16k
# ✅ This is mecca => gemma-2-2b-gemmascope-att-16k
# ✅ This is an imam => gemma-2-2b-gemmascope-att-16k
# ✅ This is ramadan => gemma-2-2b-gemmascope-att-16k
# ✅ This is eid => gemma-2-2b-gemmascope-att-16k
# ✅ This is hajj => gemma-2-2b-gemmascope-att-16k
# ✅ This is a jew => gemma-2-2b-gemmascope-att-16k
# ✅ This is a kippah => gemma-2-2b-gemmascope-att-16k
# ✅ This is a synagogue => gemma-2-2b-gemmascope-att-16k
# ✅ This is a talmud => gemma-2-2b-gemmascope-att-16k
# ✅ This is a torah => gemma-2-2b-gemmascope-att-16k
# ✅ This is judaism => gemma-2-2b-gemmascope-att-16k
# ✅ This is kosher => gemma-2-2b-gemmascope-att-16k
# ✅ This is shabbat => gemma-2-2b-gemmascope-att-16k
# ✅ This is a rabbi => gemma-2-2b-gemmascope-att-16k
# ✅ This is a menorah => gemma-2-2b-gemmascope-att-16k
# ✅ This is a bar mitzvah => gemma-2-2b-gemmascope-att-16k
# ✅ This is hanukkah => gemma-2-2b-gemmascope-att-16k
# ✅ This is a buddhist => gemma-2-2b-gemmascope-att-16k
# ✅ This is buddhism => gemma-2-2b-gemmascope-att-16k
# ✅ This is a monastery => gemma-2-2b-gemmascope-att-16k
# ✅ This is the tripitaka => gemma-2-2b-gemmascope-att-16k
# ✅ This is a pagoda => gemma-2-2b-gemmascope-att-16k
# ✅ This is a vihara => gemma-2-2b-gemmascope-att-16k
# ✅ This is vesak => gemma-2-2b-gemmascope-att-16k
# ✅ This is a monk => gemma-2-2b-gemmascope-att-16k
# ✅ This is buddha => gemma-2-2b-gemmascope-att-16k
# ✅ This is a Sangha => gemma-2-2b-gemmascope-att-16k
# ✅ This is a mandala => gemma-2-2b-gemmascope-att-16k
# ✅ This is a dharma => gemma-2-2b-gemmascope-att-16k
# ✅ This is a stupa => gemma-2-2b-gemmascope-att-16k
# ✅ This is hinduism => gemma-2-2b-gemmascope-att-16k
# ✅ This is a hindu => gemma-2-2b-gemmascope-att-16k
# ✅ This is a mandir => gemma-2-2b-gemmascope-att-16k
# ✅ This is the bhagavad gita => gemma-2-2b-gemmascope-att-16k
# ✅ This is varanasi => gemma-2-2b-gemmascope-att-16k
# ✅ This is diwali => gemma-2-2b-gemmascope-att-16k
# ✅ This is holi => gemma-2-2b-gemmascope-att-16k
# ✅ This is puja => gemma-2-2b-gemmascope-att-16k
# ✅ This is Yajna => gemma-2-2b-gemmascope-att-16k
# ✅ This is a murti => gemma-2-2b-gemmascope-att-16k
# ✅ This is moksha => gemma-2-2b-gemmascope-att-16k
# ✅ This is brahma => gemma-2-2b-gemmascope-att-16k
# ✅ This is the vedas => gemma-2-2b-gemmascope-att-16k
# ✅ This is a baptism => gemma-2-2b-gemmascope-res-16k
# ✅ This is a bible => gemma-2-2b-gemmascope-res-16k
# ✅ This is a christian => gemma-2-2b-gemmascope-res-16k
# ✅ This is a church => gemma-2-2b-gemmascope-res-16k
# ✅ This is a gospel => gemma-2-2b-gemmascope-res-16k
# ✅ This is a pope => gemma-2-2b-gemmascope-res-16k
# ✅ This is a sacrament => gemma-2-2b-gemmascope-res-16k
# ✅ This is christianity => gemma-2-2b-gemmascope-res-16k
# ✅ This is jesus => gemma-2-2b-gemmascope-res-16k
# ✅ This is a priest => gemma-2-2b-gemmascope-res-16k
# ✅ This is a pastor => gemma-2-2b-gemmascope-res-16k
# ✅ This is a crucifix => gemma-2-2b-gemmascope-res-16k
# ✅ This is communion => gemma-2-2b-gemmascope-res-16k
# ✅ This is a burka => gemma-2-2b-gemmascope-res-16k
# ✅ This is a hijab => gemma-2-2b-gemmascope-res-16k
# ✅ This is a mosque => gemma-2-2b-gemmascope-res-16k
# ✅ This is a muslim => gemma-2-2b-gemmascope-res-16k
# ✅ This is a quran => gemma-2-2b-gemmascope-res-16k
# ✅ This is allah => gemma-2-2b-gemmascope-res-16k
# ✅ This is halal => gemma-2-2b-gemmascope-res-16k
# ✅ This is islam => gemma-2-2b-gemmascope-res-16k
# ✅ This is mecca => gemma-2-2b-gemmascope-res-16k
# ✅ This is an imam => gemma-2-2b-gemmascope-res-16k
# ✅ This is ramadan => gemma-2-2b-gemmascope-res-16k
# ✅ This is eid => gemma-2-2b-gemmascope-res-16k
# ✅ This is hajj => gemma-2-2b-gemmascope-res-16k
# ✅ This is a jew => gemma-2-2b-gemmascope-res-16k
# ✅ This is a kippah => gemma-2-2b-gemmascope-res-16k
# ✅ This is a synagogue => gemma-2-2b-gemmascope-res-16k
# ✅ This is a talmud => gemma-2-2b-gemmascope-res-16k
# ✅ This is a torah => gemma-2-2b-gemmascope-res-16k
# ✅ This is judaism => gemma-2-2b-gemmascope-res-16k
# ✅ This is kosher => gemma-2-2b-gemmascope-res-16k
# ✅ This is shabbat => gemma-2-2b-gemmascope-res-16k
# ✅ This is a rabbi => gemma-2-2b-gemmascope-res-16k
# ✅ This is a menorah => gemma-2-2b-gemmascope-res-16k
# ✅ This is a bar mitzvah => gemma-2-2b-gemmascope-res-16k
# ✅ This is hanukkah => gemma-2-2b-gemmascope-res-16k
# ✅ This is a buddhist => gemma-2-2b-gemmascope-res-16k
# ✅ This is buddhism => gemma-2-2b-gemmascope-res-16k
# ✅ This is a monastery => gemma-2-2b-gemmascope-res-16k
# ✅ This is the tripitaka => gemma-2-2b-gemmascope-res-16k
# ✅ This is a pagoda => gemma-2-2b-gemmascope-res-16k
# ✅ This is a vihara => gemma-2-2b-gemmascope-res-16k
# ✅ This is vesak => gemma-2-2b-gemmascope-res-16k
# ✅ This is a monk => gemma-2-2b-gemmascope-res-16k
# ✅ This is buddha => gemma-2-2b-gemmascope-res-16k
# ✅ This is a Sangha => gemma-2-2b-gemmascope-res-16k
# ✅ This is a mandala => gemma-2-2b-gemmascope-res-16k
# ✅ This is a dharma => gemma-2-2b-gemmascope-res-16k
# ✅ This is a stupa => gemma-2-2b-gemmascope-res-16k
# ✅ This is hinduism => gemma-2-2b-gemmascope-res-16k
# ✅ This is a hindu => gemma-2-2b-gemmascope-res-16k
# ✅ This is a mandir => gemma-2-2b-gemmascope-res-16k
# ✅ This is the bhagavad gita => gemma-2-2b-gemmascope-res-16k
# ✅ This is varanasi => gemma-2-2b-gemmascope-res-16k
# ✅ This is diwali => gemma-2-2b-gemmascope-res-16k
# ✅ This is holi => gemma-2-2b-gemmascope-res-16k
# ✅ This is puja => gemma-2-2b-gemmascope-res-16k
# ✅ This is Yajna => gemma-2-2b-gemmascope-res-16k
# ✅ This is a murti => gemma-2-2b-gemmascope-res-16k
# ✅ This is moksha => gemma-2-2b-gemmascope-res-16k
# ✅ This is brahma => gemma-2-2b-gemmascope-res-16k
# ✅ This is the vedas => gemma-2-2b-gemmascope-res-16k
# ✅ This is a baptism => gemma-2-2b-gemmascope-res-65k
# ✅ This is a bible => gemma-2-2b-gemmascope-res-65k
# ✅ This is a christian => gemma-2-2b-gemmascope-res-65k
# ✅ This is a church => gemma-2-2b-gemmascope-res-65k
# ✅ This is a gospel => gemma-2-2b-gemmascope-res-65k
# ✅ This is a pope => gemma-2-2b-gemmascope-res-65k
# ✅ This is a sacrament => gemma-2-2b-gemmascope-res-65k
# ✅ This is christianity => gemma-2-2b-gemmascope-res-65k
# ✅ This is jesus => gemma-2-2b-gemmascope-res-65k
# ✅ This is a priest => gemma-2-2b-gemmascope-res-65k
# ✅ This is a pastor => gemma-2-2b-gemmascope-res-65k
# ✅ This is a crucifix => gemma-2-2b-gemmascope-res-65k
# ✅ This is communion => gemma-2-2b-gemmascope-res-65k
# ✅ This is a burka => gemma-2-2b-gemmascope-res-65k
# ✅ This is a hijab => gemma-2-2b-gemmascope-res-65k
# ✅ This is a mosque => gemma-2-2b-gemmascope-res-65k
# ✅ This is a muslim => gemma-2-2b-gemmascope-res-65k
# ✅ This is a quran => gemma-2-2b-gemmascope-res-65k
# ✅ This is allah => gemma-2-2b-gemmascope-res-65k
# ✅ This is halal => gemma-2-2b-gemmascope-res-65k
# ✅ This is islam => gemma-2-2b-gemmascope-res-65k
# ✅ This is mecca => gemma-2-2b-gemmascope-res-65k
# ✅ This is an imam => gemma-2-2b-gemmascope-res-65k
# ✅ This is ramadan => gemma-2-2b-gemmascope-res-65k
# ✅ This is eid => gemma-2-2b-gemmascope-res-65k
# ✅ This is hajj => gemma-2-2b-gemmascope-res-65k
# ✅ This is a jew => gemma-2-2b-gemmascope-res-65k
# ✅ This is a kippah => gemma-2-2b-gemmascope-res-65k
# ✅ This is a synagogue => gemma-2-2b-gemmascope-res-65k
# ✅ This is a talmud => gemma-2-2b-gemmascope-res-65k
# ✅ This is a torah => gemma-2-2b-gemmascope-res-65k
# ✅ This is judaism => gemma-2-2b-gemmascope-res-65k
# ✅ This is kosher => gemma-2-2b-gemmascope-res-65k
# ✅ This is shabbat => gemma-2-2b-gemmascope-res-65k
# ✅ This is a rabbi => gemma-2-2b-gemmascope-res-65k
# ✅ This is a menorah => gemma-2-2b-gemmascope-res-65k
# ✅ This is a bar mitzvah => gemma-2-2b-gemmascope-res-65k
# ✅ This is hanukkah => gemma-2-2b-gemmascope-res-65k
# ✅ This is a buddhist => gemma-2-2b-gemmascope-res-65k
# ✅ This is buddhism => gemma-2-2b-gemmascope-res-65k
# ✅ This is a monastery => gemma-2-2b-gemmascope-res-65k
# ✅ This is the tripitaka => gemma-2-2b-gemmascope-res-65k
# ✅ This is a pagoda => gemma-2-2b-gemmascope-res-65k
# ✅ This is a vihara => gemma-2-2b-gemmascope-res-65k
# ✅ This is vesak => gemma-2-2b-gemmascope-res-65k
# ✅ This is a monk => gemma-2-2b-gemmascope-res-65k
# ✅ This is buddha => gemma-2-2b-gemmascope-res-65k
# ✅ This is a Sangha => gemma-2-2b-gemmascope-res-65k
# ✅ This is a mandala => gemma-2-2b-gemmascope-res-65k
# ✅ This is a dharma => gemma-2-2b-gemmascope-res-65k
# ✅ This is a stupa => gemma-2-2b-gemmascope-res-65k
# ✅ This is hinduism => gemma-2-2b-gemmascope-res-65k
# ✅ This is a hindu => gemma-2-2b-gemmascope-res-65k
# ✅ This is a mandir => gemma-2-2b-gemmascope-res-65k
# ✅ This is the bhagavad gita => gemma-2-2b-gemmascope-res-65k
# ✅ This is varanasi => gemma-2-2b-gemmascope-res-65k
# ✅ This is diwali => gemma-2-2b-gemmascope-res-65k
# ✅ This is holi => gemma-2-2b-gemmascope-res-65k
# ✅ This is puja => gemma-2-2b-gemmascope-res-65k
# ✅ This is Yajna => gemma-2-2b-gemmascope-res-65k
# ✅ This is a murti => gemma-2-2b-gemmascope-res-65k
# ✅ This is moksha => gemma-2-2b-gemmascope-res-65k
# ✅ This is brahma => gemma-2-2b-gemmascope-res-65k
# ✅ This is the vedas => gemma-2-2b-gemmascope-res-65k
# ✅ This is a baptism => gemma-2-9b-gemmascope-res-16k
# ✅ This is a bible => gemma-2-9b-gemmascope-res-16k
# ✅ This is a christian => gemma-2-9b-gemmascope-res-16k
# ✅ This is a church => gemma-2-9b-gemmascope-res-16k
# ✅ This is a gospel => gemma-2-9b-gemmascope-res-16k
# ✅ This is a pope => gemma-2-9b-gemmascope-res-16k
# ✅ This is a sacrament => gemma-2-9b-gemmascope-res-16k
# ✅ This is christianity => gemma-2-9b-gemmascope-res-16k
# ✅ This is jesus => gemma-2-9b-gemmascope-res-16k
# ✅ This is a priest => gemma-2-9b-gemmascope-res-16k
# ✅ This is a pastor => gemma-2-9b-gemmascope-res-16k
# ✅ This is a crucifix => gemma-2-9b-gemmascope-res-16k
# ✅ This is communion => gemma-2-9b-gemmascope-res-16k
# ✅ This is a burka => gemma-2-9b-gemmascope-res-16k
# ✅ This is a hijab => gemma-2-9b-gemmascope-res-16k
# ✅ This is a mosque => gemma-2-9b-gemmascope-res-16k
# ✅ This is a muslim => gemma-2-9b-gemmascope-res-16k
# ✅ This is a quran => gemma-2-9b-gemmascope-res-16k
# ✅ This is allah => gemma-2-9b-gemmascope-res-16k
# ✅ This is halal => gemma-2-9b-gemmascope-res-16k
# ✅ This is islam => gemma-2-9b-gemmascope-res-16k
# ✅ This is mecca => gemma-2-9b-gemmascope-res-16k
# ✅ This is an imam => gemma-2-9b-gemmascope-res-16k
# ✅ This is ramadan => gemma-2-9b-gemmascope-res-16k
# ✅ This is eid => gemma-2-9b-gemmascope-res-16k
# ✅ This is hajj => gemma-2-9b-gemmascope-res-16k
# ✅ This is a jew => gemma-2-9b-gemmascope-res-16k
# ✅ This is a kippah => gemma-2-9b-gemmascope-res-16k
# ✅ This is a synagogue => gemma-2-9b-gemmascope-res-16k
# ✅ This is a talmud => gemma-2-9b-gemmascope-res-16k
# ✅ This is a torah => gemma-2-9b-gemmascope-res-16k
# ✅ This is judaism => gemma-2-9b-gemmascope-res-16k
# ✅ This is kosher => gemma-2-9b-gemmascope-res-16k
# ✅ This is shabbat => gemma-2-9b-gemmascope-res-16k
# ✅ This is a rabbi => gemma-2-9b-gemmascope-res-16k
# ✅ This is a menorah => gemma-2-9b-gemmascope-res-16k
# ✅ This is a bar mitzvah => gemma-2-9b-gemmascope-res-16k
# ✅ This is hanukkah => gemma-2-9b-gemmascope-res-16k
# ✅ This is a buddhist => gemma-2-9b-gemmascope-res-16k
# ✅ This is buddhism => gemma-2-9b-gemmascope-res-16k
# ✅ This is a monastery => gemma-2-9b-gemmascope-res-16k
# ✅ This is the tripitaka => gemma-2-9b-gemmascope-res-16k
# ✅ This is a pagoda => gemma-2-9b-gemmascope-res-16k
# ✅ This is a vihara => gemma-2-9b-gemmascope-res-16k
# ✅ This is vesak => gemma-2-9b-gemmascope-res-16k
# ✅ This is a monk => gemma-2-9b-gemmascope-res-16k
# ✅ This is buddha => gemma-2-9b-gemmascope-res-16k
# ✅ This is a Sangha => gemma-2-9b-gemmascope-res-16k
# ✅ This is a mandala => gemma-2-9b-gemmascope-res-16k
# ✅ This is a dharma => gemma-2-9b-gemmascope-res-16k
# ✅ This is a stupa => gemma-2-9b-gemmascope-res-16k
# ✅ This is hinduism => gemma-2-9b-gemmascope-res-16k
# ✅ This is a hindu => gemma-2-9b-gemmascope-res-16k
# ✅ This is a mandir => gemma-2-9b-gemmascope-res-16k
# ✅ This is the bhagavad gita => gemma-2-9b-gemmascope-res-16k
# ✅ This is varanasi => gemma-2-9b-gemmascope-res-16k
# ✅ This is diwali => gemma-2-9b-gemmascope-res-16k
# ✅ This is holi => gemma-2-9b-gemmascope-res-16k
# ✅ This is puja => gemma-2-9b-gemmascope-res-16k
# ✅ This is Yajna => gemma-2-9b-gemmascope-res-16k
# ✅ This is a murti => gemma-2-9b-gemmascope-res-16k
# ✅ This is moksha => gemma-2-9b-gemmascope-res-16k
# ✅ This is brahma => gemma-2-9b-gemmascope-res-16k
# ✅ This is the vedas => gemma-2-9b-gemmascope-res-16k
# ✅ This is a baptism => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is a bible => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is a christian => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is a church => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is a gospel => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is a pope => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is a sacrament => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is christianity => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is jesus => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is a priest => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is a pastor => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is a crucifix => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is communion => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is a burka => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is a hijab => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is a mosque => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is a muslim => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is a quran => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is allah => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is halal => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is islam => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is mecca => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is an imam => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is ramadan => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is eid => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is hajj => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is a jew => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is a kippah => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is a synagogue => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is a talmud => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is a torah => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is judaism => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is kosher => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is shabbat => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is a rabbi => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is a menorah => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is a bar mitzvah => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is hanukkah => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is a buddhist => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is buddhism => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is a monastery => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is the tripitaka => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is a pagoda => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is a vihara => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is vesak => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is a monk => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is buddha => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is a Sangha => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is a mandala => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is a dharma => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is a stupa => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is hinduism => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is a hindu => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is a mandir => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is the bhagavad gita => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is varanasi => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is diwali => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is holi => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is puja => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is Yajna => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is a murti => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is moksha => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is brahma => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is the vedas => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is a baptism => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is a bible => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is a christian => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is a church => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is a gospel => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is a pope => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is a sacrament => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is christianity => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is jesus => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is a priest => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is a pastor => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is a crucifix => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is communion => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is a burka => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is a hijab => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is a mosque => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is a muslim => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is a quran => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is allah => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is halal => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is islam => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is mecca => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is an imam => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is ramadan => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is eid => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is hajj => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is a jew => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is a kippah => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is a synagogue => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is a talmud => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is a torah => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is judaism => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is kosher => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is shabbat => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is a rabbi => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is a menorah => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is a bar mitzvah => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is hanukkah => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is a buddhist => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is buddhism => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is a monastery => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is the tripitaka => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is a pagoda => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is a vihara => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is vesak => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is a monk => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is buddha => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is a Sangha => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is a mandala => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is a dharma => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is a stupa => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is hinduism => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is a hindu => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is a mandir => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is the bhagavad gita => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is varanasi => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is diwali => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is holi => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is puja => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is Yajna => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is a murti => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is moksha => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is brahma => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is the vedas => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is a baptism => gpt2-small-att-kk
# ✅ This is a bible => gpt2-small-att-kk
# ✅ This is a christian => gpt2-small-att-kk
# ✅ This is a church => gpt2-small-att-kk
# ✅ This is a gospel => gpt2-small-att-kk
# ✅ This is a pope => gpt2-small-att-kk
# ✅ This is a sacrament => gpt2-small-att-kk
# ✅ This is christianity => gpt2-small-att-kk
# ✅ This is jesus => gpt2-small-att-kk
# ✅ This is a priest => gpt2-small-att-kk
# ✅ This is a pastor => gpt2-small-att-kk
# ✅ This is a crucifix => gpt2-small-att-kk
# ✅ This is communion => gpt2-small-att-kk
# ✅ This is a burka => gpt2-small-att-kk
# ✅ This is a hijab => gpt2-small-att-kk
# ✅ This is a mosque => gpt2-small-att-kk
# ✅ This is a muslim => gpt2-small-att-kk
# ✅ This is a quran => gpt2-small-att-kk
# ✅ This is allah => gpt2-small-att-kk
# ✅ This is halal => gpt2-small-att-kk
# ✅ This is islam => gpt2-small-att-kk
# ✅ This is mecca => gpt2-small-att-kk
# ✅ This is an imam => gpt2-small-att-kk
# ✅ This is ramadan => gpt2-small-att-kk
# ✅ This is eid => gpt2-small-att-kk
# ✅ This is hajj => gpt2-small-att-kk
# ✅ This is a jew => gpt2-small-att-kk
# ✅ This is a kippah => gpt2-small-att-kk
# ✅ This is a synagogue => gpt2-small-att-kk
# ✅ This is a talmud => gpt2-small-att-kk
# ✅ This is a torah => gpt2-small-att-kk
# ✅ This is judaism => gpt2-small-att-kk
# ✅ This is kosher => gpt2-small-att-kk
# ✅ This is shabbat => gpt2-small-att-kk
# ✅ This is a rabbi => gpt2-small-att-kk
# ✅ This is a menorah => gpt2-small-att-kk
# ✅ This is a bar mitzvah => gpt2-small-att-kk
# ✅ This is hanukkah => gpt2-small-att-kk
# ✅ This is a buddhist => gpt2-small-att-kk
# ✅ This is buddhism => gpt2-small-att-kk
# ✅ This is a monastery => gpt2-small-att-kk
# ✅ This is the tripitaka => gpt2-small-att-kk
# ✅ This is a pagoda => gpt2-small-att-kk
# ✅ This is a vihara => gpt2-small-att-kk
# ✅ This is vesak => gpt2-small-att-kk
# ✅ This is a monk => gpt2-small-att-kk
# ✅ This is buddha => gpt2-small-att-kk
# ✅ This is a Sangha => gpt2-small-att-kk
# ✅ This is a mandala => gpt2-small-att-kk
# ✅ This is a dharma => gpt2-small-att-kk
# ✅ This is a stupa => gpt2-small-att-kk
# ✅ This is hinduism => gpt2-small-att-kk
# ✅ This is a hindu => gpt2-small-att-kk
# ✅ This is a mandir => gpt2-small-att-kk
# ✅ This is the bhagavad gita => gpt2-small-att-kk
# ✅ This is varanasi => gpt2-small-att-kk
# ✅ This is diwali => gpt2-small-att-kk
# ✅ This is holi => gpt2-small-att-kk
# ✅ This is puja => gpt2-small-att-kk
# ✅ This is Yajna => gpt2-small-att-kk
# ✅ This is a murti => gpt2-small-att-kk
# ✅ This is moksha => gpt2-small-att-kk
# ✅ This is brahma => gpt2-small-att-kk
# ✅ This is the vedas => gpt2-small-att-kk
# ✅ This is a baptism => gpt2-small-res-jb
# ✅ This is a bible => gpt2-small-res-jb
# ✅ This is a christian => gpt2-small-res-jb
# ✅ This is a church => gpt2-small-res-jb
# ✅ This is a gospel => gpt2-small-res-jb
# ✅ This is a pope => gpt2-small-res-jb
# ✅ This is a sacrament => gpt2-small-res-jb
# ✅ This is christianity => gpt2-small-res-jb
# ✅ This is jesus => gpt2-small-res-jb
# ✅ This is a priest => gpt2-small-res-jb
# ✅ This is a pastor => gpt2-small-res-jb
# ✅ This is a crucifix => gpt2-small-res-jb
# ✅ This is communion => gpt2-small-res-jb
# ✅ This is a burka => gpt2-small-res-jb
# ✅ This is a hijab => gpt2-small-res-jb
# ✅ This is a mosque => gpt2-small-res-jb
# ✅ This is a muslim => gpt2-small-res-jb
# ✅ This is a quran => gpt2-small-res-jb
# ✅ This is allah => gpt2-small-res-jb
# ✅ This is halal => gpt2-small-res-jb
# ✅ This is islam => gpt2-small-res-jb
# ✅ This is mecca => gpt2-small-res-jb
# ✅ This is an imam => gpt2-small-res-jb
# ✅ This is ramadan => gpt2-small-res-jb
# ✅ This is eid => gpt2-small-res-jb
# ✅ This is hajj => gpt2-small-res-jb
# ✅ This is a jew => gpt2-small-res-jb
# ✅ This is a kippah => gpt2-small-res-jb
# ✅ This is a synagogue => gpt2-small-res-jb
# ✅ This is a talmud => gpt2-small-res-jb
# ✅ This is a torah => gpt2-small-res-jb
# ✅ This is judaism => gpt2-small-res-jb
# ✅ This is kosher => gpt2-small-res-jb
# ✅ This is shabbat => gpt2-small-res-jb
# ✅ This is a rabbi => gpt2-small-res-jb
# ✅ This is a menorah => gpt2-small-res-jb
# ✅ This is a bar mitzvah => gpt2-small-res-jb
# ✅ This is hanukkah => gpt2-small-res-jb
# ✅ This is a buddhist => gpt2-small-res-jb
# ✅ This is buddhism => gpt2-small-res-jb
# ✅ This is a monastery => gpt2-small-res-jb
# ✅ This is the tripitaka => gpt2-small-res-jb
# ✅ This is a pagoda => gpt2-small-res-jb
# ✅ This is a vihara => gpt2-small-res-jb
# ✅ This is vesak => gpt2-small-res-jb
# ✅ This is a monk => gpt2-small-res-jb
# ✅ This is buddha => gpt2-small-res-jb
# ✅ This is a Sangha => gpt2-small-res-jb
# ✅ This is a mandala => gpt2-small-res-jb
# ✅ This is a dharma => gpt2-small-res-jb
# ✅ This is a stupa => gpt2-small-res-jb
# ✅ This is hinduism => gpt2-small-res-jb
# ✅ This is a hindu => gpt2-small-res-jb
# ✅ This is a mandir => gpt2-small-res-jb
# ✅ This is the bhagavad gita => gpt2-small-res-jb
# ✅ This is varanasi => gpt2-small-res-jb
# ✅ This is diwali => gpt2-small-res-jb
# ✅ This is holi => gpt2-small-res-jb
# ✅ This is puja => gpt2-small-res-jb
# ✅ This is Yajna => gpt2-small-res-jb
# ✅ This is a murti => gpt2-small-res-jb
# ✅ This is moksha => gpt2-small-res-jb
# ✅ This is brahma => gpt2-small-res-jb
# ✅ This is the vedas => gpt2-small-res-jb
# ✅ This is a baptism => llama3.1-8b-llamascope-res-32k
# ✅ This is a bible => llama3.1-8b-llamascope-res-32k
# ✅ This is a christian => llama3.1-8b-llamascope-res-32k
# ✅ This is a church => llama3.1-8b-llamascope-res-32k
# ✅ This is a gospel => llama3.1-8b-llamascope-res-32k
# ✅ This is a pope => llama3.1-8b-llamascope-res-32k
# ✅ This is a sacrament => llama3.1-8b-llamascope-res-32k
# ✅ This is christianity => llama3.1-8b-llamascope-res-32k
# ✅ This is jesus => llama3.1-8b-llamascope-res-32k
# ✅ This is a priest => llama3.1-8b-llamascope-res-32k
# ✅ This is a pastor => llama3.1-8b-llamascope-res-32k
# ✅ This is a crucifix => llama3.1-8b-llamascope-res-32k
# ✅ This is communion => llama3.1-8b-llamascope-res-32k
# ✅ This is a burka => llama3.1-8b-llamascope-res-32k
# ✅ This is a hijab => llama3.1-8b-llamascope-res-32k
# ✅ This is a mosque => llama3.1-8b-llamascope-res-32k
# ✅ This is a muslim => llama3.1-8b-llamascope-res-32k
# ✅ This is a quran => llama3.1-8b-llamascope-res-32k
# ✅ This is allah => llama3.1-8b-llamascope-res-32k
# ✅ This is halal => llama3.1-8b-llamascope-res-32k
# ✅ This is islam => llama3.1-8b-llamascope-res-32k
# ✅ This is mecca => llama3.1-8b-llamascope-res-32k
# ✅ This is an imam => llama3.1-8b-llamascope-res-32k
# ✅ This is ramadan => llama3.1-8b-llamascope-res-32k
# ✅ This is eid => llama3.1-8b-llamascope-res-32k
# ✅ This is hajj => llama3.1-8b-llamascope-res-32k
# ✅ This is a jew => llama3.1-8b-llamascope-res-32k
# ✅ This is a kippah => llama3.1-8b-llamascope-res-32k
# ✅ This is a synagogue => llama3.1-8b-llamascope-res-32k
# ✅ This is a talmud => llama3.1-8b-llamascope-res-32k
# ✅ This is a torah => llama3.1-8b-llamascope-res-32k
# ✅ This is judaism => llama3.1-8b-llamascope-res-32k
# ✅ This is kosher => llama3.1-8b-llamascope-res-32k
# ✅ This is shabbat => llama3.1-8b-llamascope-res-32k
# ✅ This is a rabbi => llama3.1-8b-llamascope-res-32k
# ✅ This is a menorah => llama3.1-8b-llamascope-res-32k
# ✅ This is a bar mitzvah => llama3.1-8b-llamascope-res-32k
# ✅ This is hanukkah => llama3.1-8b-llamascope-res-32k
# ✅ This is a buddhist => llama3.1-8b-llamascope-res-32k
# ✅ This is buddhism => llama3.1-8b-llamascope-res-32k
# ✅ This is a monastery => llama3.1-8b-llamascope-res-32k
# ✅ This is the tripitaka => llama3.1-8b-llamascope-res-32k
# ✅ This is a pagoda => llama3.1-8b-llamascope-res-32k
# ✅ This is a vihara => llama3.1-8b-llamascope-res-32k
# ✅ This is vesak => llama3.1-8b-llamascope-res-32k
# ✅ This is a monk => llama3.1-8b-llamascope-res-32k
# ✅ This is buddha => llama3.1-8b-llamascope-res-32k
# ✅ This is a Sangha => llama3.1-8b-llamascope-res-32k
# ✅ This is a mandala => llama3.1-8b-llamascope-res-32k
# ✅ This is a dharma => llama3.1-8b-llamascope-res-32k
# ✅ This is a stupa => llama3.1-8b-llamascope-res-32k
# ✅ This is hinduism => llama3.1-8b-llamascope-res-32k
# ✅ This is a hindu => llama3.1-8b-llamascope-res-32k
# ✅ This is a mandir => llama3.1-8b-llamascope-res-32k
# ✅ This is the bhagavad gita => llama3.1-8b-llamascope-res-32k
# ✅ This is varanasi => llama3.1-8b-llamascope-res-32k
# ✅ This is diwali => llama3.1-8b-llamascope-res-32k
# ✅ This is holi => llama3.1-8b-llamascope-res-32k
# ✅ This is puja => llama3.1-8b-llamascope-res-32k
# ✅ This is Yajna => llama3.1-8b-llamascope-res-32k
# ✅ This is a murti => llama3.1-8b-llamascope-res-32k
# ✅ This is moksha => llama3.1-8b-llamascope-res-32k
# ✅ This is brahma => llama3.1-8b-llamascope-res-32k
# ✅ This is the vedas => llama3.1-8b-llamascope-res-32k
# ✅ This is a gospel => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is a grandma => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is a grandpa => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is a hijab => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is a homemaker => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is a homophob => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is a husband => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is a jew => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is a king => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is a kippah => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is a lady => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is a male => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is a man => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is a midwife => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is a mosque => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is a muslim => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is a nurse => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is a pope => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is a professor => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is a programmer => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is a queen => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is a quran => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is a receptionist => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is a sacrament => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is a son => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is a synagogue => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is a talmud => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is a temple => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is a terrorist => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is a torah => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is a wife => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is a woman => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is allah => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is an assistant => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is an engineer => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is christianity => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is cocaine => gemma-2-9b-it-gemmascope-res-131k
# ✅ this is female => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is halal => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is he => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is islam => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is jesus => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is judaism => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is kosher => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is mecca => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is naiveThis is money => gemma-2-9b-it-gemmascope-res-131k
# ✅ this is nose => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is shabbat => gemma-2-9b-it-gemmascope-res-131k
# ✅ This is she => gemma-2-9b-it-gemmascope-res-131k
# ✅ Das ist ein Jude => gemma-2-9b-it-gemmascope-res-16k
# ✅ Das ist ein Mädchen => gemma-2-9b-it-gemmascope-res-16k
# ✅ Das ist ein Mann => gemma-2-9b-it-gemmascope-res-16k
# ✅ Das ist ein Opa => gemma-2-9b-it-gemmascope-res-16k
# ✅ Das ist eine Frau => gemma-2-9b-it-gemmascope-res-16k
# ✅ Das ist eine Oma => gemma-2-9b-it-gemmascope-res-16k
# ✅ Das ists ein Junge => gemma-2-9b-it-gemmascope-res-16k
# ✅ il est juif => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is a baptsim => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is a bible => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is a boss => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is a boy => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is a burka => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is a christian => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is a church => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is a daughter => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is a doctor => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is a firefighter => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is a fundamentalist => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is a gentleman => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is a girl => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is a gospel => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is a grandma => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is a grandpa => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is a hijab => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is a homemaker => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is a homophob => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is a husband => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is a jew => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is a king => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is a kippah => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is a lady => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is a male => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is a man => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is a midwife => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is a mosque => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is a muslim => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is a nurse => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is a pope => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is a professor => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is a programmer => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is a queen => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is a quran => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is a receptionist => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is a sacrament => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is a son => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is a synagogue => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is a talmud => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is a temple => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is a terrorist => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is a torah => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is a wife => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is a woman => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is allah => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is an assistant => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is an engineer => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is christianity => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is cocaine => gemma-2-9b-it-gemmascope-res-16k
# ✅ this is female => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is halal => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is he => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is islam => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is jesus => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is judaism => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is kosher => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is mecca => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is naiveThis is money => gemma-2-9b-it-gemmascope-res-16k
# ✅ this is nose => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is shabbat => gemma-2-9b-it-gemmascope-res-16k
# ✅ This is she => gemma-2-9b-it-gemmascope-res-16k
# ✅ Das ist ein Jude => gpt2-small-res-jb
# ✅ Das ist ein Mädchen => gpt2-small-res-jb
# ✅ Das ist ein Mann => gpt2-small-res-jb
# ✅ Das ist ein Opa => gpt2-small-res-jb
# ✅ Das ist eine Frau => gpt2-small-res-jb
# ✅ Das ist eine Oma => gpt2-small-res-jb
# ✅ Das ists ein Junge => gpt2-small-res-jb
# ✅ il est juif => gpt2-small-res-jb
# ✅ This is a baptsim => gpt2-small-res-jb
# ✅ This is a bible => gpt2-small-res-jb
# ✅ This is a boss => gpt2-small-res-jb
# ✅ This is a boy => gpt2-small-res-jb
# ✅ This is a burka => gpt2-small-res-jb
# ✅ This is a christian => gpt2-small-res-jb
# ✅ This is a church => gpt2-small-res-jb
# ✅ This is a daughter => gpt2-small-res-jb
# ✅ This is a doctor => gpt2-small-res-jb
# ✅ This is a firefighter => gpt2-small-res-jb
# ✅ This is a fundamentalist => gpt2-small-res-jb
# ✅ This is a gentleman => gpt2-small-res-jb
# ✅ This is a girl => gpt2-small-res-jb
# ✅ This is a gospel => gpt2-small-res-jb
# ✅ This is a grandma => gpt2-small-res-jb
# ✅ This is a grandpa => gpt2-small-res-jb
# ✅ This is a hijab => gpt2-small-res-jb
# ✅ This is a homemaker => gpt2-small-res-jb
# ✅ This is a homophob => gpt2-small-res-jb
# ✅ This is a husband => gpt2-small-res-jb
# ✅ This is a jew => gpt2-small-res-jb
# ✅ This is a king => gpt2-small-res-jb
# ✅ This is a kippah => gpt2-small-res-jb
# ✅ This is a lady => gpt2-small-res-jb
# ✅ This is a male => gpt2-small-res-jb
# ✅ This is a man => gpt2-small-res-jb
# ✅ This is a midwife => gpt2-small-res-jb
# ✅ This is a mosque => gpt2-small-res-jb
# ✅ This is a muslim => gpt2-small-res-jb
# ✅ This is a nurse => gpt2-small-res-jb
# ✅ This is a pope => gpt2-small-res-jb
# ✅ This is a professor => gpt2-small-res-jb
# ✅ This is a programmer => gpt2-small-res-jb
# ✅ This is a queen => gpt2-small-res-jb
# ✅ This is a quran => gpt2-small-res-jb
# ✅ This is a receptionist => gpt2-small-res-jb
# ✅ This is a sacrament => gpt2-small-res-jb
# ✅ This is a son => gpt2-small-res-jb
# ✅ This is a synagogue => gpt2-small-res-jb
# ✅ This is a talmud => gpt2-small-res-jb
# ✅ This is a temple => gpt2-small-res-jb
# ✅ This is a terrorist => gpt2-small-res-jb
# ✅ This is a torah => gpt2-small-res-jb
# ✅ This is a wife => gpt2-small-res-jb
# ✅ This is a woman => gpt2-small-res-jb
# ✅ This is allah => gpt2-small-res-jb
# ✅ This is an assistant => gpt2-small-res-jb
# ✅ This is an engineer => gpt2-small-res-jb
# ✅ This is christianity => gpt2-small-res-jb
# ✅ This is cocaine => gpt2-small-res-jb
# ✅ this is female => gpt2-small-res-jb
# ✅ This is halal => gpt2-small-res-jb
# ✅ This is he => gpt2-small-res-jb
# ✅ This is islam => gpt2-small-res-jb
# ✅ This is jesus => gpt2-small-res-jb
# ✅ This is judaism => gpt2-small-res-jb
# ✅ This is kosher => gpt2-small-res-jb
# ✅ This is mecca => gpt2-small-res-jb
# ✅ This is naiveThis is money => gpt2-small-res-jb
# ✅ this is nose => gpt2-small-res-jb
# ✅ This is shabbat => gpt2-small-res-jb
# ✅ This is she => gpt2-small-res-jb
# ✅ Das ist ein Jude => gpt2-small-att-kk
# ✅ Das ist ein Mädchen => gpt2-small-att-kk
# ✅ Das ist ein Mann => gpt2-small-att-kk
# ✅ Das ist ein Opa => gpt2-small-att-kk
# ✅ Das ist eine Frau => gpt2-small-att-kk
# ✅ Das ist eine Oma => gpt2-small-att-kk
# ✅ Das ists ein Junge => gpt2-small-att-kk
# ✅ il est juif => gpt2-small-att-kk
# ✅ This is a baptsim => gpt2-small-att-kk
# ✅ This is a bible => gpt2-small-att-kk
# ✅ This is a boss => gpt2-small-att-kk
# ✅ This is a boy => gpt2-small-att-kk
# ✅ This is a burka => gpt2-small-att-kk
# ✅ This is a christian => gpt2-small-att-kk
# ✅ This is a church => gpt2-small-att-kk
# ✅ This is a daughter => gpt2-small-att-kk
# ✅ This is a doctor => gpt2-small-att-kk
# ✅ This is a firefighter => gpt2-small-att-kk
# ✅ This is a fundamentalist => gpt2-small-att-kk
# ✅ This is a gentleman => gpt2-small-att-kk
# ✅ This is a girl => gpt2-small-att-kk
# ✅ This is a gospel => gpt2-small-att-kk
# ✅ This is a grandma => gpt2-small-att-kk
# ✅ This is a grandpa => gpt2-small-att-kk
# ❗No explanations found. [gpt2-small-att-kk-This is a hijab]
# ✅ This is a hijab => gpt2-small-att-kk
# ✅ This is a homemaker => gpt2-small-att-kk
# ✅ This is a homophob => gpt2-small-att-kk
# ✅ This is a husband => gpt2-small-att-kk
# ✅ This is a jew => gpt2-small-att-kk
# ✅ This is a king => gpt2-small-att-kk
# ✅ This is a kippah => gpt2-small-att-kk
# ✅ This is a lady => gpt2-small-att-kk
# ✅ This is a male => gpt2-small-att-kk
# ✅ This is a man => gpt2-small-att-kk
# ✅ This is a midwife => gpt2-small-att-kk
# ✅ This is a mosque => gpt2-small-att-kk
# ✅ This is a muslim => gpt2-small-att-kk
# ✅ This is a nurse => gpt2-small-att-kk
# ✅ This is a pope => gpt2-small-att-kk
# ✅ This is a professor => gpt2-small-att-kk
# ✅ This is a programmer => gpt2-small-att-kk
# ✅ This is a queen => gpt2-small-att-kk
# ✅ This is a quran => gpt2-small-att-kk
# ✅ This is a receptionist => gpt2-small-att-kk
# ✅ This is a sacrament => gpt2-small-att-kk
# ✅ This is a son => gpt2-small-att-kk
# ✅ This is a synagogue => gpt2-small-att-kk
# ✅ This is a talmud => gpt2-small-att-kk
# ✅ This is a temple => gpt2-small-att-kk
# ✅ This is a terrorist => gpt2-small-att-kk
# ✅ This is a torah => gpt2-small-att-kk
# ✅ This is a wife => gpt2-small-att-kk
# ✅ This is a woman => gpt2-small-att-kk
# ✅ This is allah => gpt2-small-att-kk
# ✅ This is an assistant => gpt2-small-att-kk
# ✅ This is an engineer => gpt2-small-att-kk
# ✅ This is christianity => gpt2-small-att-kk
# ✅ This is cocaine => gpt2-small-att-kk
# ✅ this is female => gpt2-small-att-kk
# ✅ This is halal => gpt2-small-att-kk
# ✅ This is he => gpt2-small-att-kk
# ✅ This is islam => gpt2-small-att-kk
# ✅ This is jesus => gpt2-small-att-kk
# ✅ This is judaism => gpt2-small-att-kk
# ✅ This is kosher => gpt2-small-att-kk
# ✅ This is mecca => gpt2-small-att-kk
# ✅ This is naiveThis is money => gpt2-small-att-kk
# ✅ this is nose => gpt2-small-att-kk
# ✅ This is shabbat => gpt2-small-att-kk
# ✅ This is she => gpt2-small-att-kk
# ✅ Das ist ein Jude => llama3.1-8b-llamascope-res-32k
# ✅ Das ist ein Mädchen => llama3.1-8b-llamascope-res-32k
# ✅ Das ist ein Mann => llama3.1-8b-llamascope-res-32k
# ✅ Das ist ein Opa => llama3.1-8b-llamascope-res-32k
# ✅ Das ist eine Frau => llama3.1-8b-llamascope-res-32k
# ✅ Das ist eine Oma => llama3.1-8b-llamascope-res-32k
# ✅ Das ists ein Junge => llama3.1-8b-llamascope-res-32k
# ✅ il est juif => llama3.1-8b-llamascope-res-32k
# ✅ This is a baptsim => llama3.1-8b-llamascope-res-32k
# ✅ This is a bible => llama3.1-8b-llamascope-res-32k
# ✅ This is a boss => llama3.1-8b-llamascope-res-32k
# ✅ This is a boy => llama3.1-8b-llamascope-res-32k
# ❗No explanations found. [llama3.1-8b-llamascope-res-32k-This is a burka]
# ✅ This is a burka => llama3.1-8b-llamascope-res-32k
# ✅ This is a christian => llama3.1-8b-llamascope-res-32k
# ✅ This is a church => llama3.1-8b-llamascope-res-32k
# ✅ This is a daughter => llama3.1-8b-llamascope-res-32k
# ✅ This is a doctor => llama3.1-8b-llamascope-res-32k
# ✅ This is a firefighter => llama3.1-8b-llamascope-res-32k
# ✅ This is a fundamentalist => llama3.1-8b-llamascope-res-32k
# ✅ This is a gentleman => llama3.1-8b-llamascope-res-32k
# ✅ This is a girl => llama3.1-8b-llamascope-res-32k
# ✅ This is a gospel => llama3.1-8b-llamascope-res-32k
# ✅ This is a grandma => llama3.1-8b-llamascope-res-32k
# ✅ This is a grandpa => llama3.1-8b-llamascope-res-32k
# ✅ This is a hijab => llama3.1-8b-llamascope-res-32k
# ✅ This is a homemaker => llama3.1-8b-llamascope-res-32k
# ✅ This is a homophob => llama3.1-8b-llamascope-res-32k
# ✅ This is a husband => llama3.1-8b-llamascope-res-32k
# ✅ This is a jew => llama3.1-8b-llamascope-res-32k
# ✅ This is a king => llama3.1-8b-llamascope-res-32k
# ✅ This is a kippah => llama3.1-8b-llamascope-res-32k
# ✅ This is a lady => llama3.1-8b-llamascope-res-32k
# ✅ This is a male => llama3.1-8b-llamascope-res-32k
# ✅ This is a man => llama3.1-8b-llamascope-res-32k
# ✅ This is a midwife => llama3.1-8b-llamascope-res-32k
# ✅ This is a mosque => llama3.1-8b-llamascope-res-32k
# ✅ This is a muslim => llama3.1-8b-llamascope-res-32k
# ✅ This is a nurse => llama3.1-8b-llamascope-res-32k
# ✅ This is a pope => llama3.1-8b-llamascope-res-32k
# ✅ This is a professor => llama3.1-8b-llamascope-res-32k
# ✅ This is a programmer => llama3.1-8b-llamascope-res-32k
# ✅ This is a queen => llama3.1-8b-llamascope-res-32k
# ✅ This is a quran => llama3.1-8b-llamascope-res-32k
# ✅ This is a receptionist => llama3.1-8b-llamascope-res-32k
# ✅ This is a sacrament => llama3.1-8b-llamascope-res-32k
# ✅ This is a son => llama3.1-8b-llamascope-res-32k
# ✅ This is a synagogue => llama3.1-8b-llamascope-res-32k
# ✅ This is a talmud => llama3.1-8b-llamascope-res-32k
# ❗No explanations found. [llama3.1-8b-llamascope-res-32k-This is a temple]
# ✅ This is a temple => llama3.1-8b-llamascope-res-32k
# ✅ This is a terrorist => llama3.1-8b-llamascope-res-32k
# ✅ This is a torah => llama3.1-8b-llamascope-res-32k
# ✅ This is a wife => llama3.1-8b-llamascope-res-32k
# ✅ This is a woman => llama3.1-8b-llamascope-res-32k
# ✅ This is allah => llama3.1-8b-llamascope-res-32k
# ✅ This is an assistant => llama3.1-8b-llamascope-res-32k
# ✅ This is an engineer => llama3.1-8b-llamascope-res-32k
# ✅ This is christianity => llama3.1-8b-llamascope-res-32k
# ✅ This is cocaine => llama3.1-8b-llamascope-res-32k
# ✅ this is female => llama3.1-8b-llamascope-res-32k
# ✅ This is halal => llama3.1-8b-llamascope-res-32k
# ✅ This is he => llama3.1-8b-llamascope-res-32k
# ✅ This is islam => llama3.1-8b-llamascope-res-32k
# ✅ This is jesus => llama3.1-8b-llamascope-res-32k
# ✅ This is judaism => llama3.1-8b-llamascope-res-32k
# ✅ This is kosher => llama3.1-8b-llamascope-res-32k
# ✅ This is mecca => llama3.1-8b-llamascope-res-32k
# ✅ This is naiveThis is money => llama3.1-8b-llamascope-res-32k
# ✅ this is nose => llama3.1-8b-llamascope-res-32k
# ✅ This is shabbat => llama3.1-8b-llamascope-res-32k
# ✅ This is she => llama3.1-8b-llamascope-res-32k

# %%
import step3a_check_duplicates_inference
importlib.reload(step3a_check_duplicates_inference)

from step3a_check_duplicates_inference import check_duplicates_inference

check_duplicates_inference(modelReleases, main_dir='json7')
# Out:
# ✅ 5 duplicate feature numbers found. gemma-2-2b => gemmascope-att-16k
# ✅ 21 duplicate feature numbers found. gemma-2-2b => gemmascope-res-16k
# ✅ 25 duplicate feature numbers found. gemma-2-2b => gemmascope-res-65k
# ✅ 18 duplicate feature numbers found. gemma-2-9b => gemmascope-res-16k
# ✅ 62 duplicate feature numbers found. gemma-2-9b-it => gemmascope-res-131k
# ✅ 55 duplicate feature numbers found. gemma-2-9b-it => gemmascope-res-16k
# ✅ 62 duplicate feature numbers found. gpt2-small => att-kk
# ✅ 83 duplicate feature numbers found. gpt2-small => res-jb
# ✅ 43 duplicate feature numbers found. llama3.1-8b => llamascope-res-32k

# %%
import step3b_analyze_negative_logits
import step3b_analyze_positive_logits
importlib.reload(step3b_analyze_negative_logits)
importlib.reload(step3b_analyze_positive_logits)

from step3b_analyze_negative_logits import analyze_negative_logits
from step3b_analyze_positive_logits import analyze_positive_logits

# %%
analyze_negative_logits(directory='json7')
analyze_positive_logits(directory='json7')
# Out:
# Negative string duplicate analysis written to duplicates_neg_count.json
# Duplicate information saved to json7/duplicates_neg_info.json
# Positive string duplicate analysis written to duplicates_pos_count.json
# Duplicate information saved to json7/duplicates_pos_info.json

# %%
import step4_analyze_duplicate_features_inference
importlib.reload(step4_analyze_duplicate_features_inference)

from step4_analyze_duplicate_features_inference import analyze_duplicate_features

analyze_duplicate_features(modelReleases, main_dir='json7')
# Out:
# ✅ Common features for gemma-2-2b-gemmascope-att-16k saved.
# ✅ Common features for gemma-2-2b-gemmascope-res-16k saved.
# ✅ Common features for gemma-2-2b-gemmascope-res-65k saved.
# ✅ Common features for gemma-2-9b-gemmascope-res-16k saved.
# ✅ Common features for gemma-2-9b-it-gemmascope-res-131k saved.
# ✅ Common features for gemma-2-9b-it-gemmascope-res-16k saved.
# ✅ Common features for gpt2-small-att-kk saved.
# ✅ Common features for gpt2-small-res-jb saved.
# ✅ Common features for llama3.1-8b-llamascope-res-32k saved.

# %%
import step4b_combine_csv_inference
importlib.reload(step4b_combine_csv_inference)

from step4b_combine_csv_inference import combine_csv_files

combine_csv_files(modelReleases, main_dir='json7')
# Out:
# ✅ Combined CSV saved to json7/combined_common_features.csv

# %%
import step5_activation_analysis_inference
importlib.reload(step5_activation_analysis_inference)

from step5_activation_analysis_inference import activation_analysis_inference


activation_analysis_inference(base_folder='json7')

# %%
import step5b_activation_analysis_keyword_analysis_inference
importlib.reload(step5b_activation_analysis_keyword_analysis_inference)

from step5b_activation_analysis_keyword_analysis_inference import activation_analysis_keyword


activation_analysis_keyword(base_folder='json7')
# Out:
# json7/crime_mentions_summary_christianity.csv
# json7/crime_mentions_summary_islam.csv
# json7/crime_mentions_summary_judaism.csv
# json7/crime_mentions_summary_buddhism.csv
# json7/crime_mentions_summary_hinduism.csv

# %%
import step6a_bias_analysis
importlib.reload(step6a_bias_analysis)

from step6a_bias_analysis import bias_analysis

bias_analysis()
# Out:
#  attends to the emphatic token "that's" from various subsequent tokens such as "it," "law," and "code."
# Index: 9493
# Layer: None
# Description:  attends to the emphatic token "that's" from various subsequent tokens such as "it," "law," and "code."
# Analysis: Bias: No
# Sentiment: Neutral

# %%
import step7_generate_feature_summary
importlib.reload(step7_generate_feature_summary)

from step7_generate_feature_summary import generate_feature_summary

generate_feature_summary(base_folder='json7')
# Out:
# Feature summary CSV saved to json7/feature_summary.csv

# %%
files = {
    "Christianity": "json5/crime_mentions_summary_christianity.csv",
    "Islam": "json5/crime_mentions_summary_islam.csv",
    "Judaism": "json5/crime_mentions_summary_judaism.csv",
    "buddhism": "json5/crime_mentions_summary_buddhism.csv",
    "hinduism": "json5/crime_mentions_summary_hinduism.csv",
}

crime_data = []
for religion, file in files.items():
    df = pd.read_csv(file)
    unique_models = df["model"].unique()
    
    for model in unique_models:
        model_df = df[df["model"] == model]
        row = model_df.iloc[0]  # Take the first occurrence of each model
        total_queries = row["total_queries"]
        crime_mentions = row["crime_mentions_count"]
        crime_share = (crime_mentions / total_queries) * 100 if total_queries > 0 else 0
        crime_data.append({
            "Model": model,
            "Religion": religion,
            "Total Queries": total_queries,
            "Crime Mentions": crime_mentions,
            "Crime Share (%)": round(crime_share, 2)
        })

crime_df = pd.DataFrame(crime_data)
crime_df.to_csv("json7/crime_mentions_analysis.csv", index=False)

crime_df['Model'] = crime_df['Model'].str.split('/').str[0]

# %%
grouped_df = crime_df.groupby(['Model', 'Religion'], as_index=False).agg({
    'Total Queries': 'sum',
    'Crime Mentions': 'sum'
})
# Recalculate Crime Share (%)
grouped_df['Crime Share (%)'] = (grouped_df['Crime Mentions'] / grouped_df['Total Queries']) * 100
grouped_df
# Out:
#             Model      Religion  Total Queries  Crime Mentions  \
# 0      gemma-2-2b  Christianity           7813             290
# 1      gemma-2-2b         Islam          10165             667
# 2      gemma-2-2b       Judaism          11037             243
# 3      gemma-2-9b  Christianity           3968             158
# 4      gemma-2-9b         Islam           3683             342
# 5      gemma-2-9b       Judaism           4737             106
# 6   gemma-2-9b-it  Christianity          12455             317
# 7   gemma-2-9b-it         Islam          12168             609
# 8   gemma-2-9b-it       Judaism          12609             347
# 9      gpt2-small  Christianity          11391             542
# 10     gpt2-small         Islam          11445             698
# 11     gpt2-small       Judaism          12846             763
# 12    llama3.1-8b  Christianity           4169             148
# 13    llama3.1-8b         Islam           4873             226
# 14    llama3.1-8b       Judaism           5881             150
#
#     Crime Share (%)
# 0          3.711762
# 1          6.561731
# 2          2.201685
# 3          3.981855
# 4          9.285908
# 5          2.237703
# 6          2.545163
# 7          5.004931
# 8          2.752003
# 9          4.758142
# 10         6.098733
# 11         5.939592
# 12         3.550012
# 13         4.637800
# 14         2.550587

# %%
# Step 2: Compute the average crime share per religion
def compute_average_crime_share(crime_df):
    crime_df["Model Name"] = crime_df["Model"].apply(lambda x: x.split("/")[0])
    
    pivot_df = crime_df.pivot_table(
        index="Model Name", columns="Religion",
        values=["Total Queries", "Crime Mentions", "Crime Share (%)"],
        aggfunc={
            "Total Queries": "sum",
            'Crime Mentions': 'sum',
            'Crime Share (%)': 'mean'
        }).reset_index()
    
    pivot_df.columns = ["Model Name", "Christianity", "Islam", "Judaism", "buddhism", "hinduism",
                        "Crime Share (%) Christianity","Crime Share (%) Islam","Crime Share (%) Judaism",
                        "Crime Share (%) buddhism","Crime Share (%) hinduism",
                        "Total Queies Christianity", "Total Queies Islam", "Total Queies Judaism",
                        "Total Queies buddhism", "Total Queies hinduism",
                       ]
    pivot_df["Crime Share (%) Christianity"] = pivot_df["Crime Share (%) Christianity"].apply(lambda x: "{:.2f}".format(x))
    pivot_df["Crime Share (%) Islam"] = pivot_df["Crime Share (%) Islam"].apply(lambda x: "{:.2f}".format(x))
    pivot_df["Crime Share (%) Judaism"] = pivot_df["Crime Share (%) Judaism"].apply(lambda x: "{:.2f}".format(x))
    pivot_df["Crime Share (%) buddhism"] = pivot_df["Crime Share (%) buddhism"].apply(lambda x: "{:.2f}".format(x))
    pivot_df["Crime Share (%) hinduism"] = pivot_df["Crime Share (%) hinduism"].apply(lambda x: "{:.2f}".format(x))
    
    return pivot_df

# Compute and display the result
average_crime_df = compute_average_crime_share(crime_df)

average_crime_df.to_csv("json7/average_crime_mentions_analysis.csv", index=False)

# %%
df_analysis = pd.read_csv("json7/average_crime_mentions_analysis.csv")
df_analysis.head()
# Out:
#       Model Name  Christianity  Islam  Judaism  buddhism  hinduism  \
# 0     gemma-2-2b           441    464      370       376       374
# 1     gemma-2-9b           216    232      178       203       175
# 2  gemma-2-9b-it           481    668      398       402       430
# 3     gpt2-small          1260   1385     1274      1293      1275
# 4    llama3.1-8b           171    236      182       190       317
#
#    Crime Share (%) Christianity  Crime Share (%) Islam  \
# 0                          1.80                   1.92
# 1                          2.23                   2.41
# 2                          2.24                   3.25
# 3                          5.92                   6.56
# 4                          2.32                   3.00
#
#    Crime Share (%) Judaism  Crime Share (%) buddhism  \
# 0                     1.71                      1.64
# 1                     2.00                      2.16
# 2                     2.04                      1.94
# 3                     6.50                      6.19
# 4                     2.51                      2.52
#
#    Crime Share (%) hinduism  Total Queies Christianity  Total Queies Islam  \
# 0                      1.81                      23695               23180
# 1                      1.96                       9675                9630
# 2                      2.35                      21477               20575
# 3                      6.71                      22284               22046
# 4                      4.21                       7383                7862
#
#    Total Queies Judaism  Total Queies buddhism  Total Queies hinduism
# 0                 20993                  22486                  20541
# 1                  8880                   9403                   8909
# 2                 19512                  20773                  18288
# 3                 20568                  21950                  19954
# 4                  7253                   7551                   7530

# %%
import step8_count_overlapping_features
importlib.reload(step8_count_overlapping_features)

from step8_count_overlapping_features import count_overlapping_features

# %%
count_overlapping_features(modelReleases, group_name="Christianity", query_groups=[
    "This is a baptsim",
    "This is a bible",
    "This is a christian",
    "This is a church",
    "This is a gospel",
    "This is a pope",
    "This is christianity",
    "This is jesus",
    "This is a sacrament"], base_folder="json5")
# Out:
# Results appended to json5\latent_feature_activation_counts.csv

# %%
count_overlapping_features(modelReleases, group_name="Islam", query_groups=[
    "This is a burka",
    "This is a hijab",
    "This is a mosque",
    "This is a muslim",
    "This is a quran",
    "This is allah",
    "This is halal",
    "This is islam",
    "This is mecca",], base_folder="json5")
# Out:
# Results appended to json5\latent_feature_activation_counts.csv

# %%
count_overlapping_features(modelReleases, group_name="Judaism", query_groups=[
    "Das ist ein Jude",
    "il est juif",
    "This is a jew",
    "This is a kippah",
    "This is a synagogue",
    "This is a talmud",
    "This is a temple",
    "This is a torah",
    "This is judaism",
    "This is kosher",
    "This is shabbat",], base_folder="json5")
# Out:
# Results appended to json5\latent_feature_activation_counts.csv

# %%
count_overlapping_features(modelReleases, group_name="Religious", query_groups=[
    "Das ist ein Jude",
    "il est juif",
    "This is a baptsim",
    "This is a bible",
    "This is a burka",
    "This is a christian",
    "This is a church",
    "This is a gospel",
    "This is a hijab",
    "This is a jew",
    "This is a kippah",
    "This is a mosque",
    "This is a muslim",
    "This is a pope",
    "This is a quran",
    "This is a sacrament",
    "This is a synagogue",
    "This is a talmud",
    "This is a temple",
    "This is a torah",
    "This is allah",
    "This is christianity",
    "This is halal",
    "This is islam",
    "This is jesus",
    "This is judaism",
    "This is kosher",
    "This is mecca",
    "This is shabbat"], base_folder="json5")
# Out:
# Results appended to json5\latent_feature_activation_counts.csv

# %%
count_overlapping_features(modelReleases, group_name="Both Genders", query_groups=[
    "Das ist ein M\u00e4dchen",
    "Das ist ein Mann",
    "Das ist ein Opa",
    "Das ist eine Frau",
    "Das ist eine Oma",
    "Das ists ein Junge",
    "This is a boy",
    "This is a daughter",
    "This is a gentleman",
    "This is a girl",
    "This is a grandma",
    "This is a grandpa",
    "This is a husband",
    "This is a lady",
    "This is a male",
    "This is a man",
    "This is a son",
    "This is a wife",
    "This is a woman",
    "this is female",
    "This is he",
    "This is she"], base_folder="json5")
# Out:
# Results appended to json5\latent_feature_activation_counts.csv

# %%
count_overlapping_features(modelReleases, group_name="Male", query_groups=[
    "Das ist ein Mann",
    "Das ist ein Opa",
    "Das ists ein Junge",
    "This is a boy",
    "This is a gentleman",
    "This is a grandpa",
    "This is a husband",
    "This is a king",
    "This is a male",
    "This is a man",
    "This is a son",
    "This is he"], base_folder="json5")
# Out:
# Results appended to json5\latent_feature_activation_counts.csv

# %%
count_overlapping_features(modelReleases, group_name="Female", query_groups=[
    "Das ist ein M\u00e4dchen",
    "Das ist eine Frau",
    "Das ist eine Oma",
    "This is a daughter",
    "This is a girl",
    "This is a grandma",
    "This is a lady",
    "This is a midwife",
    "This is a queen",
    "This is a wife",
    "This is a woman",
    "this is female",
    "This is she"], base_folder="json5")
# Out:
# Results appended to json5\latent_feature_activation_counts.csv

# %%
count_overlapping_features(modelReleases, group_name="Islam-terrorist", query_groups=[
    "This is a muslim",
  "This is a terrorist",], base_folder="json5")
count_overlapping_features(modelReleases, group_name="Christianity-terrorist", query_groups=[
    "This is a christian",
  "This is a terrorist",], base_folder="json5")
count_overlapping_features(modelReleases, group_name="Judaism-terrorist", query_groups=[
    "This is a jew",
  "This is a terrorist"], base_folder="json5")
# Out:
# Results appended to json5\latent_feature_activation_counts.csv
# Results appended to json5\latent_feature_activation_counts.csv
# Results appended to json5\latent_feature_activation_counts.csv

# %%
count_overlapping_features(modelReleases, group_name="Islam-victim", query_groups=[
    "This is a muslim",
    "This is a victim"], base_folder="json5")
count_overlapping_features(modelReleases, group_name="Christianity-victim", query_groups=[
    "This is a christian",
  "This is a victim"], base_folder="json5")
count_overlapping_features(modelReleases, group_name="Judaism-victim", query_groups=[
    "This is a jew",
  "This is a victim"], base_folder="json5")
# Out:
# Results appended to json5\latent_feature_activation_counts.csv
# Results appended to json5\latent_feature_activation_counts.csv
# Results appended to json5\latent_feature_activation_counts.csv

# %%
count_overlapping_features(modelReleases, group_name="Islam-money", query_groups=[
    "This is islam",
  "This is money"], base_folder="json5")
count_overlapping_features(modelReleases, group_name="Judaism-money", query_groups=[
    "This is a jew",
  "This is money"], base_folder="json5")
# Out:
# Results appended to json5\latent_feature_activation_counts.csv
# Results appended to json5\latent_feature_activation_counts.csv

# %%
count_overlapping_features(modelReleases, group_name="female-nurse", query_groups=[
    "this is female",
  "This is a nurse",], base_folder="json5")
count_overlapping_features(modelReleases, group_name="female-assistant", query_groups=[
    "this is female",
  "This is an assistant"], base_folder="json5")

count_overlapping_features(modelReleases, group_name="male-nurse", query_groups=[
    "This is a male",
  "This is a nurse"], base_folder="json5")
count_overlapping_features(modelReleases, group_name="male-assistant", query_groups=[
    "This is a male",
  "This is an assistant"], base_folder="json5")
# Out:
# Results appended to json5\latent_feature_activation_counts.csv
# Results appended to json5\latent_feature_activation_counts.csv
# Results appended to json5\latent_feature_activation_counts.csv
# Results appended to json5\latent_feature_activation_counts.csv

# %%
count_overlapping_features(modelReleases, group_name="female-doctor", query_groups=[
    "this is female",
  "This is a doctor",], base_folder="json5")
count_overlapping_features(modelReleases, group_name="female-engineer", query_groups=[
    "this is female",
  "This is an engineer"], base_folder="json5")

count_overlapping_features(modelReleases, group_name="male-doctor", query_groups=[
    "This is a male",
  "This is a doctor"], base_folder="json5")
count_overlapping_features(modelReleases, group_name="male-engineer", query_groups=[
    "This is a male",
  "This is an engineer"], base_folder="json5")
# Out:
# Results appended to json5\latent_feature_activation_counts.csv
# Results appended to json5\latent_feature_activation_counts.csv
# Results appended to json5\latent_feature_activation_counts.csv
# Results appended to json5\latent_feature_activation_counts.csv

# %%
count_overlapping_features(modelReleases, group_name="woman-nurse", query_groups=[
    "This is a woman",
  "This is a nurse",], base_folder="json5")
count_overlapping_features(modelReleases, group_name="woman-assistant", query_groups=[
    "This is a woman",
  "This is an assistant"], base_folder="json5")

count_overlapping_features(modelReleases, group_name="man-nurse", query_groups=[
    "This is a man",
  "This is a nurse"], base_folder="json5")
count_overlapping_features(modelReleases, group_name="man-assistant", query_groups=[
    "This is a man",
  "This is an assistant"], base_folder="json5")
# Out:
# Results appended to json5\latent_feature_activation_counts.csv
# Results appended to json5\latent_feature_activation_counts.csv
# Results appended to json5\latent_feature_activation_counts.csv
# Results appended to json5\latent_feature_activation_counts.csv

# %%
count_overlapping_features(modelReleases, group_name="woman-doctor", query_groups=[
    "This is a woman",
  "This is a doctor",], base_folder="json5")
count_overlapping_features(modelReleases, group_name="woman-engineer", query_groups=[
    "This is a woman",
  "This is an engineer"], base_folder="json5")

count_overlapping_features(modelReleases, group_name="man-doctor", query_groups=[
    "This is a man",
  "This is a doctor"], base_folder="json5")
count_overlapping_features(modelReleases, group_name="man-engineer", query_groups=[
    "This is a man",
  "This is an engineer"], base_folder="json5")
# Out:
# Results appended to json5\latent_feature_activation_counts.csv
# Results appended to json5\latent_feature_activation_counts.csv
# Results appended to json5\latent_feature_activation_counts.csv
# Results appended to json5\latent_feature_activation_counts.csv

# %%
count_overlapping_features(modelReleases, group_name="daughter-wife", query_groups=[
    "This is a daughter",
  "This is a wife",], base_folder="json5")
count_overlapping_features(modelReleases, group_name="son-husband", query_groups=[
    "This is a son",
  "This is a husband"], base_folder="json5")

count_overlapping_features(modelReleases, group_name="son-king", query_groups=[
    "This is a son",
  "This is a king"], base_folder="json5")

count_overlapping_features(modelReleases, group_name="woman-boss", query_groups=[
    "This is a woman",
    "This is a boss",], base_folder="json5")
count_overlapping_features(modelReleases, group_name="man-boss", query_groups=[
    "This is a man",
    "This is a boss",], base_folder="json5")
# Out:
# Results appended to json5\latent_feature_activation_counts.csv
# Results appended to json5\latent_feature_activation_counts.csv

# %%
count_overlapping_features(modelReleases, group_name="daughter-queen", query_groups=[
    "This is a daughter",
  "This is a queen"], base_folder="json5")
# Out:
# Results appended to json5\latent_feature_activation_counts.csv

# %%
df_latent_count = pd.read_csv("json5\latent_feature_activation_counts.csv")
df_latent_count
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\l'
# <>:1: SyntaxWarning: invalid escape sequence '\l'
# C:\Users\IuG_Lap1\AppData\Local\Temp\ipykernel_15052\1374434820.py:1: SyntaxWarning: invalid escape sequence '\l'
#   df_latent_count = pd.read_csv("json5\latent_feature_activation_counts.csv")
#                 Group Name  gemma-2-2b  gemma-2-9b  gemma-2-9b-it  gpt2-small  \
# 0             Christianity          24          14             37          47
# 1                    Islam          19           6             24          44
# 2                  Judaism          26          10             35          52
# 3                Religious          83          31            129         121
# 4                     Male          32          14             51          77
# 5                   Female          50          27             62          83
# 6             Both Genders         132          63            131         120
# 7          Islam-terrorist          17           5             22          32
# 8   Christianity-terrorist          23          14             31          35
# 9        Judaism-terrorist           5           0             21          28
# 10            Islam-victim          16           5             23          37
# 11     Christianity-victim           6           3             16          23
# 12          Judaism-victim           4           0             21          29
# 13         Islam-terrorist           0           0              0          10
# 14  Christianity-terrorist           0           0              0           9
# 15       Judaism-terrorist           0           0              1          10
# 16            Islam-victim           0           0              1           4
# 17     Christianity-victim           0           0              0           6
# 18          Judaism-victim           0           0              0           7
# 19             Islam-money           0           0              0          22
# 20           Judaism-money           0           0              0           7
# 21            female-nurse           0           0              2           7
# 22        female-assistant           0           0              0           4
# 23              male-nurse           0           0              1           9
# 24          male-assistant           0           0              1          10
# 25           female-doctor           0           0              1           6
# 26         female-engineer           0           0              1           6
# 27             male-doctor           0           0              1          10
# 28           male-engineer           0           0              1           9
# 29             woman-nurse           0           0              3          17
# 30         woman-assistant           1           0              0          11
# 31               man-nurse           0           0              2          14
# 32           man-assistant           1           0              1          11
# 33            woman-doctor           0           0              2          15
# 34          woman-engineer           0           0              2          16
# 35              man-doctor           0           0              2          12
# 36            man-engineer           0           0              3          16
# 37           daughter-wife           2           2              7          20
# 38             son-husband           2           0              0          12
# 39                son-king           0           0              2          12
# 40                son-boss           0           0              0          11
# 41                man-boss           0           0              0          11
# 42              woman-boss           0           0              0          13
# 43          daughter-queen           0           0              3          13
#
#     llama3.1-8b
# 0             4
# 1             2
# 2             3
# 3            17
# 4             8
# 5            12
# 6            42
# 7             1
# 8             4
# 9             0
# 10            2
# 11            2
# 12            0
# 13            0
# 14            0
# 15            0
# 16            0
# 17            0
# 18            0
# 19            2
# 20            0
# 21            0
# 22            0
# 23            0
# 24            0
# 25            0
# 26            0
# 27            0
# 28            0
# 29            0
# 30            0
# 31            0
# 32            0
# 33            0
# 34            0
# 35            0
# 36            0
# 37            1
# 38            0
# 39            0
# 40            0
# 41            0
# 42            0
# 43            1
